# %%
#generate all code and results for the report in this file
import numpy as np 
import math 
from numba import njit
import random
from numba import njit
import numpy as np

@njit
def phospholipid_water_2D(L, N_total, water_fraction, head_radius_ratio,c_ratio, n_c_per_chain, area_fraction):

    n_water = int(N_total * water_fraction)
    n_phospholipid = N_total - n_water
    n_head = n_phospholipid
    n_tail = n_phospholipid

    area_water = area_fraction * (L**2) / (
        n_water + head_radius_ratio**2 * n_head + (c_ratio**2 * n_c_per_chain * n_tail)
    )

    r_water = (area_water / np.pi) ** 0.5
    r_head = head_radius_ratio * r_water
    r_carbon = c_ratio * r_water

    heads = np.zeros((n_head, 2))
    tails = np.zeros((n_tail, n_c_per_chain, 2))
    water = np.zeros((n_water, 2))

    head_count = 0
    water_count = 0

    max_tries = 100000
    tries = 0

    # ---- Insert phospholipids ----
    while head_count < n_head and tries < max_tries:

        tries += 1

        head_pos = np.empty(2)
        head_pos[0] = np.random.uniform(0.0, L)
        head_pos[1] = np.random.uniform(0.0, L)

        angle = np.random.uniform(0.0, 2*np.pi)

        tail_positions = np.zeros((n_c_per_chain, 2))

        tail_positions[0,0] = (head_pos[0] + np.cos(angle)*(r_head+r_carbon)) % L
        tail_positions[0,1] = (head_pos[1] + np.sin(angle)*(r_head+r_carbon)) % L

        for k in range(1, n_c_per_chain):

            angle += np.random.normal(0.0, np.pi/16)

            tail_positions[k,0] = (tail_positions[k-1,0] + 2*np.cos(angle)*r_carbon) % L
            tail_positions[k,1] = (tail_positions[k-1,1] + 2*np.sin(angle)*r_carbon) % L

        overlap = False

        # head-head overlap
        for i in range(head_count):

            dx = heads[i,0] - head_pos[0]
            dy = heads[i,1] - head_pos[1]

            dx -= L * np.round(dx / L)
            dy -= L * np.round(dy / L)

            dist = np.sqrt(dx*dx + dy*dy)

            if dist < 2*r_head:
                overlap = True
                break

        if overlap:
            continue

        # head-tail overlap
        for i in range(head_count):

            for k in range(n_c_per_chain):

                dx = tails[i,k,0] - head_pos[0]
                dy = tails[i,k,1] - head_pos[1]

                dx -= L*np.round(dx/L)
                dy -= L*np.round(dy/L)

                if np.sqrt(dx*dx+dy*dy) < (r_head+r_carbon):
                    overlap = True
                    break

            if overlap:
                break

        if overlap:
            continue

        # tail-head overlap
        for k in range(n_c_per_chain):

            for i in range(head_count):

                dx = heads[i,0] - tail_positions[k,0]
                dy = heads[i,1] - tail_positions[k,1]

                dx -= L*np.round(dx/L)
                dy -= L*np.round(dy/L)

                if np.sqrt(dx*dx+dy*dy) < (r_head+r_carbon):
                    overlap = True
                    break

            if overlap:
                break

        if overlap:
            continue

        # tail-tail overlap
        for k in range(n_c_per_chain):

            for i in range(head_count):

                for j in range(n_c_per_chain):

                    dx = tails[i,j,0] - tail_positions[k,0]
                    dy = tails[i,j,1] - tail_positions[k,1]

                    dx -= L*np.round(dx/L)
                    dy -= L*np.round(dy/L)

                    if np.sqrt(dx*dx+dy*dy) < 2*r_carbon:
                        overlap = True
                        break

                if overlap:
                    break
            if overlap:
                break

        if overlap:
            continue

        heads[head_count] = head_pos
        tails[head_count] = tail_positions

        head_count += 1

    tries = 0

    # ---- Insert water ----
    while water_count < n_water and tries < max_tries:

        tries += 1

        water_pos = np.empty(2)
        water_pos[0] = np.random.uniform(0.0, L)
        water_pos[1] = np.random.uniform(0.0, L)

        overlap = False

        for i in range(head_count):

            dx = heads[i,0] - water_pos[0]
            dy = heads[i,1] - water_pos[1]

            dx -= L*np.round(dx/L)
            dy -= L*np.round(dy/L)

            if np.sqrt(dx*dx+dy*dy) < (r_head+r_water):
                overlap = True
                break

        if overlap:
            continue

        for i in range(head_count):

            for k in range(n_c_per_chain):

                dx = tails[i,k,0] - water_pos[0]
                dy = tails[i,k,1] - water_pos[1]

                dx -= L*np.round(dx/L)
                dy -= L*np.round(dy/L)

                if np.sqrt(dx*dx+dy*dy) < (r_water+r_carbon):
                    overlap = True
                    break

            if overlap:
                break

        if overlap:
            continue

        for i in range(water_count):

            dx = water[i,0] - water_pos[0]
            dy = water[i,1] - water_pos[1]

            dx -= L*np.round(dx/L)
            dy -= L*np.round(dy/L)

            if np.sqrt(dx*dx+dy*dy) < 2*r_water:
                overlap = True
                break

        if overlap:
            continue

        water[water_count] = water_pos
        water_count += 1

    return heads, tails, water, r_water, r_head, r_carbon

# %%
import numpy as np
from numba import njit
#have checked and the set up works
from numba import njit
import numpy as np

@njit
def taper_value_from_P(P_value, head_radius_ratio, c_ratio, n_c_per_tail):
    """
    Estimate taper value required to produce a given 2D packing parameter.

    Parameters
    ----------
    P_value : float
        Desired packing parameter
    head_radius_ratio : float
        r_head / r_water
    c_ratio : float
        r_carbon_first / r_water
    n_c_per_tail : int
        number of carbon beads in tail

    Returns
    -------
    taper : float
        fractional reduction in carbon radius per bead
    """

    r_head = head_radius_ratio
    r_c0 = c_ratio

    # effective head diameter
    l_head = 2.0 * r_head

    # initial tail length (approx)
    l_tail = 2.0 * n_c_per_tail * r_c0

    # tail cross-sectional size implied by packing parameter
    a_tail = P_value * l_head * l_tail

    # average carbon radius implied
    r_avg = a_tail / 2.0

    # solve linear taper relation
    taper = 2.0 * (r_c0 - r_avg) / (r_c0 * (n_c_per_tail - 1))

    if taper < 0.0:
        taper = 0.0

    return taper
@njit
def make_tapered_tail_radii(r_carbon_base, taper_alpha, n_c_per_chain):
    """
    Radii decrease along the chain:
    bead 0 (nearest head) is largest,
    bead n_c_per_chain-1 (tail end) is smallest.

    taper_alpha = 0.0  -> cylindrical tail
    taper_alpha > 0.0  -> tapered tail

    Smallest radius = r_carbon_base * (1 - taper_alpha)
    so require 0 <= taper_alpha < 1.
    """
    tail_radii = np.empty(n_c_per_chain)

    if n_c_per_chain == 1:
        tail_radii[0] = r_carbon_base
        return tail_radii

    for k in range(n_c_per_chain):
        frac = k / (n_c_per_chain - 1)
        tail_radii[k] = r_carbon_base * (1.0 - taper_alpha * frac)

    return tail_radii


@njit
def phospholipid_water_2D_tapered(
    L, N_total, water_fraction,
    head_radius_ratio, c_ratio, n_c_per_chain,
    area_fraction, taper_alpha
):
    """
    taper_alpha:
        0.0  -> cylindrical tail
        0.2  -> weak taper
        0.4  -> stronger taper

    Tail beads are largest near the head and decrease in size
    toward the tail end.
    """

    n_water = int(N_total * water_fraction)
    n_phospholipid = N_total - n_water
    n_head = n_phospholipid
    n_tail = n_phospholipid

    # Total tail area contribution using the full taper profile
    sum_sq = 0.0
    if n_c_per_chain == 1:
        sum_sq = c_ratio * c_ratio
    else:
        for k in range(n_c_per_chain):
            frac = k / (n_c_per_chain - 1)
            scale = 1.0 - taper_alpha * frac
            sum_sq += (c_ratio * scale) * (c_ratio * scale)

    area_water = area_fraction * (L**2) / (
        n_water
        + head_radius_ratio**2 * n_head
        + sum_sq * n_tail
    )

    r_water = np.sqrt(area_water / np.pi)
    r_head = head_radius_ratio * r_water
    r_carbon_base = c_ratio * r_water

    tail_radii = make_tapered_tail_radii(r_carbon_base, taper_alpha, n_c_per_chain)

    heads = np.zeros((n_head, 2))
    tails = np.zeros((n_tail, n_c_per_chain, 2))
    water = np.zeros((n_water, 2))

    head_count = 0
    water_count = 0

    max_tries = 100000
    tries = 0

    # ---- Insert phospholipids ----
    while head_count < n_head and tries < max_tries:
        tries += 1

        head_pos = np.empty(2)
        head_pos[0] = np.random.uniform(0.0, L)
        head_pos[1] = np.random.uniform(0.0, L)

        angle = np.random.uniform(0.0, 2.0 * np.pi)

        tail_positions = np.zeros((n_c_per_chain, 2))

        # First bead from head
        tail_positions[0, 0] = (head_pos[0] + np.cos(angle) * (r_head + tail_radii[0])) % L
        tail_positions[0, 1] = (head_pos[1] + np.sin(angle) * (r_head + tail_radii[0])) % L

        # Remaining beads
        for k in range(1, n_c_per_chain):
            angle += np.random.normal(0.0, np.pi / 16.0)
            bond_length = tail_radii[k - 1] + tail_radii[k]

            tail_positions[k, 0] = (tail_positions[k - 1, 0] + np.cos(angle) * bond_length) % L
            tail_positions[k, 1] = (tail_positions[k - 1, 1] + np.sin(angle) * bond_length) % L

        overlap = False

        # head-head overlap
        for i in range(head_count):
            dx = heads[i, 0] - head_pos[0]
            dy = heads[i, 1] - head_pos[1]

            dx -= L * np.round(dx / L)
            dy -= L * np.round(dy / L)

            if np.sqrt(dx * dx + dy * dy) < 2.0 * r_head:
                overlap = True
                break

        if overlap:
            continue

        # head-tail overlap
        for i in range(head_count):
            for k in range(n_c_per_chain):
                dx = tails[i, k, 0] - head_pos[0]
                dy = tails[i, k, 1] - head_pos[1]

                dx -= L * np.round(dx / L)
                dy -= L * np.round(dy / L)

                if np.sqrt(dx * dx + dy * dy) < (r_head + tail_radii[k]):
                    overlap = True
                    break

            if overlap:
                break

        if overlap:
            continue

        # tail-head overlap
        for k in range(n_c_per_chain):
            for i in range(head_count):
                dx = heads[i, 0] - tail_positions[k, 0]
                dy = heads[i, 1] - tail_positions[k, 1]

                dx -= L * np.round(dx / L)
                dy -= L * np.round(dy / L)

                if np.sqrt(dx * dx + dy * dy) < (r_head + tail_radii[k]):
                    overlap = True
                    break

            if overlap:
                break

        if overlap:
            continue

        # tail-tail overlap
        for k in range(n_c_per_chain):
            for i in range(head_count):
                for j in range(n_c_per_chain):
                    dx = tails[i, j, 0] - tail_positions[k, 0]
                    dy = tails[i, j, 1] - tail_positions[k, 1]

                    dx -= L * np.round(dx / L)
                    dy -= L * np.round(dy / L)

                    if np.sqrt(dx * dx + dy * dy) < (tail_radii[j] + tail_radii[k]):
                        overlap = True
                        break

                if overlap:
                    break
            if overlap:
                break

        if overlap:
            continue

        heads[head_count] = head_pos
        tails[head_count] = tail_positions
        head_count += 1

    tries = 0

    # ---- Insert water ----
    while water_count < n_water and tries < max_tries:
        tries += 1

        water_pos = np.empty(2)
        water_pos[0] = np.random.uniform(0.0, L)
        water_pos[1] = np.random.uniform(0.0, L)

        overlap = False

        for i in range(head_count):
            dx = heads[i, 0] - water_pos[0]
            dy = heads[i, 1] - water_pos[1]

            dx -= L * np.round(dx / L)
            dy -= L * np.round(dy / L)

            if np.sqrt(dx * dx + dy * dy) < (r_head + r_water):
                overlap = True
                break

        if overlap:
            continue

        for i in range(head_count):
            for k in range(n_c_per_chain):
                dx = tails[i, k, 0] - water_pos[0]
                dy = tails[i, k, 1] - water_pos[1]

                dx -= L * np.round(dx / L)
                dy -= L * np.round(dy / L)

                if np.sqrt(dx * dx + dy * dy) < (r_water + tail_radii[k]):
                    overlap = True
                    break

            if overlap:
                break

        if overlap:
            continue

        for i in range(water_count):
            dx = water[i, 0] - water_pos[0]
            dy = water[i, 1] - water_pos[1]

            dx -= L * np.round(dx / L)
            dy -= L * np.round(dy / L)

            if np.sqrt(dx * dx + dy * dy) < 2.0 * r_water:
                overlap = True
                break

        if overlap:
            continue

        water[water_count] = water_pos
        water_count += 1

    return heads, tails, water, r_water, r_head, tail_radii

# %%
@njit
def monte_carlo_wp_2D_taper(positions_heads, positions_tails, positions_water,
                      d_max, rotation_max, L, r_water, r_head, r_carbon,
                      n_c_per_chain, tail_radii):

    N_heads = positions_heads.shape[0]
    N_water = positions_water.shape[0]
    
    particle = int(np.random.rand() * (N_heads + N_water))

    displacement = d_max * np.random.normal()
    angle = 2.0 * math.pi * np.random.rand()
    x_displacement = displacement * math.cos(angle)
    y_displacement = displacement * math.sin(angle)

    # ==========================================================
    # PHOSPHOLIPID MOVE
    # ==========================================================
    if particle < N_heads:

        moved_index = particle
        moved_type = 0

        rotation_angle = math.pi / 4.0 * (np.random.rand() - 0.5)

        vec = positions_tails[particle, 0] - positions_heads[particle]
        initial_angle = math.atan2(vec[1], vec[0])

        pos_head = positions_heads[particle]

        new_pos_head = np.empty(2)
        new_pos_head[0] = (pos_head[0] + x_displacement) % L
        new_pos_head[1] = (pos_head[1] + y_displacement) % L

        new_tail_positions = np.empty((n_c_per_chain, 2))

        new_tail_positions[0, 0] = (new_pos_head[0] + math.cos(rotation_angle + initial_angle) * (r_head + tail_radii[0])) % L
        new_tail_positions[0, 1] = (new_pos_head[1] + math.sin(rotation_angle + initial_angle) * (r_head + tail_radii[0])) % L

        for i in range(1, n_c_per_chain):

            prev_x = new_tail_positions[i - 1, 0]
            prev_y = new_tail_positions[i - 1, 1]

            if i == 1:
                ref_x = new_pos_head[0]
                ref_y = new_pos_head[1]
            else:
                ref_x = new_tail_positions[i - 2, 0]
                ref_y = new_tail_positions[i - 2, 1]

            local_angle = math.atan2(prev_y - ref_y, prev_x - ref_x)
            new_angle = local_angle + (rotation_max / 4.0) * np.random.normal()

            bond_length = tail_radii[i - 1] + tail_radii[i]

            new_tail_positions[i, 0] = (prev_x + bond_length * math.cos(new_angle)) % L
            new_tail_positions[i, 1] = (prev_y + bond_length * math.sin(new_angle)) % L

        # ---------- overlap checks ----------

        # head–water
        for i in range(N_water):
            dx = positions_water[i, 0] - new_pos_head[0]
            dy = positions_water[i, 1] - new_pos_head[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx * dx + dy * dy < (r_head + r_water) ** 2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # head–head
        for j in range(N_heads):
            if j == particle:
                continue
            dx = positions_heads[j, 0] - new_pos_head[0]
            dy = positions_heads[j, 1] - new_pos_head[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx * dx + dy * dy < (2.0 * r_head) ** 2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # head–tail
        for j in range(N_heads):
            if j == particle:
                continue
            for k in range(n_c_per_chain):
                dx = positions_tails[j, k, 0] - new_pos_head[0]
                dy = positions_tails[j, k, 1] - new_pos_head[1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx * dx + dy * dy < (r_head + tail_radii[k]) ** 2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # tail–water
        for k in range(n_c_per_chain):
            for i in range(N_water):
                dx = positions_water[i, 0] - new_tail_positions[k, 0]
                dy = positions_water[i, 1] - new_tail_positions[k, 1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx * dx + dy * dy < (r_water + tail_radii[k]) ** 2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # tail–tail
        for j in range(N_heads):
            if j == particle:
                continue
            for k in range(n_c_per_chain):
                for m in range(n_c_per_chain):
                    dx = positions_tails[j, m, 0] - new_tail_positions[k, 0]
                    dy = positions_tails[j, m, 1] - new_tail_positions[k, 1]
                    dx -= L * round(dx / L)
                    dy -= L * round(dy / L)
                    if dx * dx + dy * dy < (tail_radii[k] + tail_radii[m]) ** 2:
                        return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # tail–head
        for j in range(N_heads):
            if j == particle:
                continue
            for k in range(n_c_per_chain):
                dx = positions_heads[j, 0] - new_tail_positions[k, 0]
                dy = positions_heads[j, 1] - new_tail_positions[k, 1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx * dx + dy * dy < (r_head + tail_radii[k]) ** 2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        positions_heads[particle] = new_pos_head
        positions_tails[particle] = new_tail_positions

        return positions_heads, positions_tails, positions_water, True, moved_index, moved_type

    # ==========================================================
    # WATER MOVE
    # ==========================================================
    else:
        particle -= N_heads
        moved_index = particle
        moved_type = 1

        pos_water = positions_water[particle]

        new_pos_water = np.empty(2)
        new_pos_water[0] = (pos_water[0] + x_displacement) % L
        new_pos_water[1] = (pos_water[1] + y_displacement) % L

        for i in range(N_water):
            if i == particle:
                continue
            dx = positions_water[i, 0] - new_pos_water[0]
            dy = positions_water[i, 1] - new_pos_water[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx * dx + dy * dy < (2.0 * r_water) ** 2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        for j in range(N_heads):
            dx = positions_heads[j, 0] - new_pos_water[0]
            dy = positions_heads[j, 1] - new_pos_water[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx * dx + dy * dy < (r_water + r_head) ** 2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

            for k in range(n_c_per_chain):
                dx = positions_tails[j, k, 0] - new_pos_water[0]
                dy = positions_tails[j, k, 1] - new_pos_water[1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx * dx + dy * dy < (r_water + tail_radii[k]) ** 2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        positions_water[particle] = new_pos_water
        return positions_heads, positions_tails, positions_water, True, moved_index, moved_type

# %%
@njit
def monte_carlo_wp_2D(positions_heads, positions_tails, positions_water,
                      d_max, rotation_max, L, r_water, r_head, tail_radii,
                      n_c_per_chain):

    N_heads = positions_heads.shape[0]
    N_water = positions_water.shape[0]
    
    particle = int(np.random.rand() * (N_heads + N_water))

    displacement = d_max * np.random.normal()
    angle = 2.0 * math.pi * np.random.rand()
    x_displacement = displacement * np.cos(angle)
    y_displacement = displacement * np.sin(angle)

    rotation_angle =  math.pi/4 * (np.random.rand()-0.5)
    vec = positions_tails[particle, 0] - positions_heads[particle]
    initial_angle = np.arctan2(vec[1], vec[0])
    # ==========================================================
    # PHOSPHOLIPID MOVE
    # ==========================================================
    if particle < N_heads:

        moved_index = particle
        moved_type = 0

        pos_head = positions_heads[particle]

        # ---------- CHANGED: use NumPy array ----------
        new_pos_head = np.array([
            (pos_head[0] + x_displacement) % L,
            (pos_head[1] + y_displacement) % L
        ])

        # ---------- CHANGED: preallocate tail ----------
        new_tail_positions = np.empty((n_c_per_chain, 2))
        #need to find an initial angle so no preferential direction 

        new_tail_positions[0, 0] = (new_pos_head[0] + np.cos(rotation_angle+initial_angle) * (r_head + tail_radii)) % L
        new_tail_positions[0, 1] = (new_pos_head[1] + np.sin(rotation_angle+initial_angle) * (r_head + r_carbon)) % L

        for i in range(1, n_c_per_chain):

            prev_x = new_tail_positions[i-1, 0]
            prev_y = new_tail_positions[i-1, 1]

            if i == 1:
                ref_x, ref_y = new_pos_head
            else:
                ref_x = new_tail_positions[i-2, 0]
                ref_y = new_tail_positions[i-2, 1]

            initial_angle = math.atan2(prev_y - ref_y, prev_x - ref_x)
            new_angle = initial_angle + (rotation_max / 4.0) * np.random.normal()

            new_tail_positions[i, 0] = (prev_x + (tail_radii[i] + tail_radii[i-1]) * math.cos(new_angle)) % L
            new_tail_positions[i, 1] = (prev_y + (tail_radii[i] + tail_radii[i-1]) * math.sin(new_angle)) % L

        # ---------- overlap checks ----------

        # head–water
        for i in range(N_water):
            dx = positions_water[i, 0] - new_pos_head[0]
            dy = positions_water[i, 1] - new_pos_head[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx*dx + dy*dy < (r_head + r_water)**2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # head–head
        for j in range(N_heads):
            if j == particle:
                continue
            dx = positions_heads[j, 0] - new_pos_head[0]
            dy = positions_heads[j, 1] - new_pos_head[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx*dx + dy*dy < (2 * r_head)**2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # head–tail
        for j in range(N_heads):
            if j == particle:
                continue
            for k in range(n_c_per_chain):
                dx = positions_tails[j, k, 0] - new_pos_head[0]
                dy = positions_tails[j, k, 1] - new_pos_head[1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx*dx + dy*dy < (r_head + tail_radii[k])**2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # tail–water
        for k in range(n_c_per_chain):
            for i in range(N_water):
                dx = positions_water[i, 0] - new_tail_positions[k, 0]
                dy = positions_water[i, 1] - new_tail_positions[k, 1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx*dx + dy*dy < (r_water + tail_radii[k])**2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # tail–tail
        for j in range(N_heads):
            if j == particle:
                continue
            for k in range(n_c_per_chain):
                for m in range(n_c_per_chain):
                    dx = positions_tails[j, m, 0] - new_tail_positions[k, 0]
                    dy = positions_tails[j, m, 1] - new_tail_positions[k, 1]
                    dx -= L * round(dx / L)
                    dy -= L * round(dy / L)
                    if dx*dx + dy*dy < (tail_radii[k] + tail_radii[m])**2:
                        return positions_heads, positions_tails, positions_water, False, moved_index, moved_type
        #tail - heads
        for j in range(N_heads):
            for k in range(n_c_per_chain):
                dx = positions_heads[j, 0] - new_tail_positions[k, 0]
                dy = positions_heads[j, 1] - new_tail_positions[k, 1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx*dx + dy*dy < (r_head + tail_radii[k])**2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type
        # ---------- accept ----------
        positions_heads[particle] = new_pos_head
        positions_tails[particle] = new_tail_positions

        return positions_heads, positions_tails, positions_water, True, moved_index, moved_type

    # ==========================================================
    # WATER MOVE (unchanged logic, array-safe)
    # ==========================================================
    else:
        particle -= N_heads
        moved_index = particle
        moved_type = 1

        pos_water = positions_water[particle]

        new_pos_water = np.array([
            (pos_water[0] + x_displacement) % L,
            (pos_water[1] + y_displacement) % L
        ])

        for i in range(N_water):
            if i == particle:
                continue
            dx = positions_water[i, 0] - new_pos_water[0]
            dy = positions_water[i, 1] - new_pos_water[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx*dx + dy*dy < (2 * r_water)**2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        for j in range(N_heads):
            dx = positions_heads[j, 0] - new_pos_water[0]
            dy = positions_heads[j, 1] - new_pos_water[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx*dx + dy*dy < (r_water + r_head)**2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

            for k in range(n_c_per_chain):
                dx = positions_tails[j, k, 0] - new_pos_water[0]
                dy = positions_tails[j, k, 1] - new_pos_water[1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx*dx + dy*dy < (r_water + tail_radii[k])**2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        positions_water[particle] = new_pos_water
        return positions_heads, positions_tails, positions_water, True, moved_index, moved_type

# %%
@njit # my original slow code version plus the tapered version
def metropolis_pw_2D(positions_heads, positions_tails, positions_water, L, r_water, r_head, r_carbon, epsilon, Temperature, d_max, n_c_per_chain):
    """
    Metropolis algorithm for phospholipid system in 2D.
    Only nearest-neighbour interactions are considered.
    Assumes positions are numpy arrays:
    positions_heads: (N_heads, 2)
    positions_tails: (N_heads, n_c_per_chain, 2)
    positions_water: (N_water, 2)
    """
    N_heads = positions_heads.shape[0]
    N_water = positions_water.shape[0]
    
    # Make copies for trial moves
    pos_heads = np.copy(positions_heads)
    pos_tails = np.copy(positions_tails)
    pos_water = np.copy(positions_water)

    # Perform MC move (already njit)
    new_heads, new_tails, new_water, accepted, moved_index, moved_type = monte_carlo_wp_2D(
        positions_heads, positions_tails, positions_water, d_max, np.pi/8, 
        L, r_water, r_head, r_carbon, n_c_per_chain
    )

    if not accepted:
        return positions_heads, positions_tails, positions_water, False, moved_type

    # Initialize energies
    initial_energy = 0.0
    final_energy = 0.0

    # --- Head particle moved ---
    if moved_type == 0:
        # Tail-water interactions
        for c in range(n_c_per_chain):
            tail_old = pos_tails[moved_index, c]
            tail_new = new_tails[moved_index, c]

            # New
            diffs_new = new_water - tail_new
            diffs_new -= L * np.round(diffs_new / L)
            dists_new = np.sqrt(diffs_new[:,0]**2 + diffs_new[:,1]**2)
            for i in range(dists_new.shape[0]):
                if dists_new[i] < 1.75 * (r_carbon + r_water):
                    final_energy += epsilon

            # Old
            diffs_old = pos_water - tail_old
            diffs_old -= L * np.round(diffs_old / L)
            dists_old = np.sqrt(diffs_old[:,0]**2 + diffs_old[:,1]**2)
            for i in range(dists_old.shape[0]):
                if dists_old[i] < 1.75 * (r_carbon + r_water):
                    initial_energy += epsilon

        # Tail-tail interactions
        for c in range(n_c_per_chain):
            tail_new = new_tails[moved_index, c]
            tail_old = pos_tails[moved_index, c]

            for j in range(N_heads):
                if j == moved_index:
                    continue
                for cc in range(n_c_per_chain):
                    # New
                    diff = new_tails[j, cc] - tail_new
                    diff -= L * np.round(diff / L)
                    dist = np.sqrt(diff[0]**2 + diff[1]**2)
                    if dist < 1.75 * (r_carbon + r_carbon):
                        final_energy -= 1.2 * epsilon
                    # Old
                    diff_old = pos_tails[j, cc] - tail_old
                    diff_old -= L * np.round(diff_old / L)
                    dist_old = np.sqrt(diff_old[0]**2 + diff_old[1]**2)
                    if dist_old < 1.75 * (r_carbon + r_carbon):
                        initial_energy -= 1.2 * epsilon
        #head - water interactions
        diffs_new = new_water - new_heads[moved_index]
        diffs_new -= L * np.round(diffs_new / L)
        dists_new = np.sqrt(diffs_new[:,0]**2 + diffs_new[:,1]**2)
        for i in range(dists_new.shape[0]):
            if dists_new[i] < 1.75 * (r_head + r_water):
                final_energy -= epsilon
        diffs_old = pos_water - pos_heads[moved_index]
        diffs_old -= L * np.round(diffs_old / L)
        dists_old = np.sqrt(diffs_old[:,0]**2 + diffs_old[:,1]**2)
        for i in range(dists_old.shape[0]):
            if dists_old[i] < 1.75 * (r_head + r_water):
                initial_energy -= epsilon
    # --- Water particle moved ---
    else:
        water_old = pos_water[moved_index]
        water_new = new_water[moved_index]

        # Water-water interactions
        #for i in range(N_water):
            #if i == moved_index:
                #continue
            # New
            #diff = new_water[i] - water_new
            #diff -= L * np.round(diff / L)
            #dist = np.sqrt(diff[0]**2 + diff[1]**2)
            #if dist < 2 * (r_water + r_water):
                #final_energy -= epsilon
            # Old
            #diff_old = pos_water[i] - water_old
            #diff_old -= L * np.round(diff_old / L)
            #dist_old = np.sqrt(diff_old[0]**2 + diff_old[1]**2)
            #if dist_old < 2.5 * (r_water + r_water):
                #initial_energy -= epsilon

        # Water-tail interactions
        for i in range(N_heads):
            for c in range(n_c_per_chain):
                # New
                diff = new_tails[i, c] - water_new
                diff -= L * np.round(diff / L)
                dist = np.sqrt(diff[0]**2 + diff[1]**2)
                if dist < 1.75 * (r_carbon + r_water):
                    final_energy += epsilon
                # Old
                diff_old = pos_tails[i, c] - water_old
                diff_old -= L * np.round(diff_old / L)
                dist_old = np.sqrt(diff_old[0]**2 + diff_old[1]**2)
                if dist_old < 1.75 * (r_carbon + r_water):
                    initial_energy += epsilon

        #head - water interactions
        diffs_new = new_heads - water_new
        diffs_new -= L * np.round(diffs_new / L)
        dists_new = np.sqrt(diffs_new[:,0]**2 + diffs_new[:,1]**2)
        for i in range(dists_new.shape[0]):
            if dists_new[i] < 1.75 * (r_head + r_water):
                final_energy -= epsilon
        diffs_old = pos_heads - water_old
        diffs_old -= L * np.round(diffs_old / L)
        dists_old = np.sqrt(diffs_old[:,0]**2 + diffs_old[:,1]**2)
        for i in range(dists_old.shape[0]):
            if dists_old[i] < 1.75 * (r_head + r_water):
                initial_energy -= epsilon

    # Metropolis criterion
    delta_E = final_energy - initial_energy
    if delta_E < 0.0 or np.exp(-delta_E / (k_b * Temperature)) >= np.random.rand():
        return new_heads, new_tails, new_water, True, moved_type
    else:
        return pos_heads, pos_tails, pos_water, False, moved_type
    
@njit
def metropolis_pw_2D_tapered(positions_heads, positions_tails, positions_water,
                     L, r_water, r_head, epsilon, Temperature, k_b,
                     d_max, n_c_per_chain, tail_radii):
    """
    Metropolis algorithm for phospholipid system in 2D
    with tapered tail beads.
    """

    N_heads = positions_heads.shape[0]
    N_water = positions_water.shape[0]
    
    # Make copies for trial moves
    pos_heads = np.copy(positions_heads)
    pos_tails = np.copy(positions_tails)
    pos_water = np.copy(positions_water)

    # Perform MC move
    new_heads, new_tails, new_water, accepted, moved_index, moved_type = monte_carlo_wp_2D_taper(
        positions_heads, positions_tails, positions_water,
        d_max, np.pi / 8.0,
        L, r_water, r_head, 0.0,   # r_carbon no longer used
        n_c_per_chain, tail_radii
    )

    if not accepted:
        return positions_heads, positions_tails, positions_water, False, moved_type

    initial_energy = 0.0
    final_energy = 0.0

    # ==========================================================
    # LIPID MOVE
    # ==========================================================
    if moved_type == 0:

        # Tail-water interactions
        for c in range(n_c_per_chain):
            tail_old = pos_tails[moved_index, c]
            tail_new = new_tails[moved_index, c]

            cutoff_tw = 1.75 * (tail_radii[c] + r_water)

            # New
            diffs_new = new_water - tail_new
            diffs_new -= L * np.round(diffs_new / L)
            dists_new = np.sqrt(diffs_new[:, 0]**2 + diffs_new[:, 1]**2)
            for i in range(dists_new.shape[0]):
                if dists_new[i] < cutoff_tw:
                    final_energy += epsilon

            # Old
            diffs_old = pos_water - tail_old
            diffs_old -= L * np.round(diffs_old / L)
            dists_old = np.sqrt(diffs_old[:, 0]**2 + diffs_old[:, 1]**2)
            for i in range(dists_old.shape[0]):
                if dists_old[i] < cutoff_tw:
                    initial_energy += epsilon

        # Tail-tail interactions
        for c in range(n_c_per_chain):
            tail_new = new_tails[moved_index, c]
            tail_old = pos_tails[moved_index, c]

            for j in range(N_heads):
                if j == moved_index:
                    continue
                for cc in range(n_c_per_chain):

                    cutoff_tt = 1.75 * (tail_radii[c] + tail_radii[cc])

                    # New
                    diff = new_tails[j, cc] - tail_new
                    diff -= L * np.round(diff / L)
                    dist = np.sqrt(diff[0]**2 + diff[1]**2)
                    if dist < cutoff_tt:
                        final_energy -= 1.2 * epsilon

                    # Old
                    diff_old = pos_tails[j, cc] - tail_old
                    diff_old -= L * np.round(diff_old / L)
                    dist_old = np.sqrt(diff_old[0]**2 + diff_old[1]**2)
                    if dist_old < cutoff_tt:
                        initial_energy -= 1.2 * epsilon

        # Head-water interactions
        cutoff_hw = 1.75 * (r_head + r_water)

        diffs_new = new_water - new_heads[moved_index]
        diffs_new -= L * np.round(diffs_new / L)
        dists_new = np.sqrt(diffs_new[:, 0]**2 + diffs_new[:, 1]**2)
        for i in range(dists_new.shape[0]):
            if dists_new[i] < cutoff_hw:
                final_energy -= epsilon

        diffs_old = pos_water - pos_heads[moved_index]
        diffs_old -= L * np.round(diffs_old / L)
        dists_old = np.sqrt(diffs_old[:, 0]**2 + diffs_old[:, 1]**2)
        for i in range(dists_old.shape[0]):
            if dists_old[i] < cutoff_hw:
                initial_energy -= epsilon

    # ==========================================================
    # WATER MOVE
    # ==========================================================
    else:
        water_old = pos_water[moved_index]
        water_new = new_water[moved_index]

        # Water-tail interactions
        for i in range(N_heads):
            for c in range(n_c_per_chain):
                cutoff_tw = 1.75 * (tail_radii[c] + r_water)

                # New
                diff = new_tails[i, c] - water_new
                diff -= L * np.round(diff / L)
                dist = np.sqrt(diff[0]**2 + diff[1]**2)
                if dist < cutoff_tw:
                    final_energy += epsilon

                # Old
                diff_old = pos_tails[i, c] - water_old
                diff_old -= L * np.round(diff_old / L)
                dist_old = np.sqrt(diff_old[0]**2 + diff_old[1]**2)
                if dist_old < cutoff_tw:
                    initial_energy += epsilon

        # Head-water interactions
        cutoff_hw = 1.75 * (r_head + r_water)

        diffs_new = new_heads - water_new
        diffs_new -= L * np.round(diffs_new / L)
        dists_new = np.sqrt(diffs_new[:, 0]**2 + diffs_new[:, 1]**2)
        for i in range(dists_new.shape[0]):
            if dists_new[i] < cutoff_hw:
                final_energy -= epsilon

        diffs_old = pos_heads - water_old
        diffs_old -= L * np.round(diffs_old / L)
        dists_old = np.sqrt(diffs_old[:, 0]**2 + diffs_old[:, 1]**2)
        for i in range(dists_old.shape[0]):
            if dists_old[i] < cutoff_hw:
                initial_energy -= epsilon

    # ==========================================================
    # Metropolis criterion
    # ==========================================================
    delta_E = final_energy - initial_energy

    if delta_E < 0.0 or np.exp(-delta_E / (k_b * Temperature)) >= np.random.rand():
        return new_heads, new_tails, new_water, True, moved_type
    else:
        return pos_heads, pos_tails, pos_water, False, moved_type

# %%
import numpy as np
import math
from numba import njit

@njit
def pbc_dx(dx, L):
    return dx - L * np.round(dx / L)

@njit
def sqdist_pbc(x1, y1, x2, y2, L):
    dx = pbc_dx(x2 - x1, L)
    dy = pbc_dx(y2 - y1, L)
    return dx * dx + dy * dy


# ==========================================================
# PROPOSE MOVE ONLY
# Does NOT modify the system
# TAPERED TAIL VERSION
# ==========================================================

@njit
def propose_mc_move_wp_2D_tapered(
    positions_heads, positions_tails, positions_water,
    d_max, rotation_max, L, r_water, r_head,
    n_c_per_chain, tail_radii
):
    N_heads = positions_heads.shape[0]
    N_water = positions_water.shape[0]

    particle = int(np.random.rand() * (N_heads + N_water))

    displacement = d_max * np.random.normal()
    angle = 2.0 * math.pi * np.random.rand()
    x_displacement = displacement * math.cos(angle)
    y_displacement = displacement * math.sin(angle)

    # ------------------------------------------------------
    # LIPID MOVE
    # ------------------------------------------------------
    if particle < N_heads:
        moved_index = particle
        moved_type = 0

        old_head = np.empty(2, dtype=np.float64)
        old_head[0] = positions_heads[moved_index, 0]
        old_head[1] = positions_heads[moved_index, 1]

        new_head = np.empty(2, dtype=np.float64)
        new_head[0] = (old_head[0] + x_displacement) % L
        new_head[1] = (old_head[1] + y_displacement) % L

        new_tail_positions = np.empty((n_c_per_chain, 2), dtype=np.float64)

        vecx = positions_tails[moved_index, 0, 0] - positions_heads[moved_index, 0]
        vecy = positions_tails[moved_index, 0, 1] - positions_heads[moved_index, 1]
        initial_angle = math.atan2(vecy, vecx)
        rotation_angle = rotation_max * (np.random.rand() - 0.5)

        new_tail_positions[0, 0] = (new_head[0] + math.cos(initial_angle + rotation_angle) * (r_head + tail_radii[0])) % L
        new_tail_positions[0, 1] = (new_head[1] + math.sin(initial_angle + rotation_angle) * (r_head + tail_radii[0])) % L

        for i in range(1, n_c_per_chain):
            prev_x = new_tail_positions[i - 1, 0]
            prev_y = new_tail_positions[i - 1, 1]

            if i == 1:
                ref_x = new_head[0]
                ref_y = new_head[1]
            else:
                ref_x = new_tail_positions[i - 2, 0]
                ref_y = new_tail_positions[i - 2, 1]

            ang0 = math.atan2(prev_y - ref_y, prev_x - ref_x)
            ang_new = ang0 + (rotation_max / 4.0) * np.random.normal()

            bond_length = tail_radii[i - 1] + tail_radii[i]

            new_tail_positions[i, 0] = (prev_x + bond_length * math.cos(ang_new)) % L
            new_tail_positions[i, 1] = (prev_y + bond_length * math.sin(ang_new)) % L

        # ---------- overlap checks ----------

        # head-water
        cutoff2 = (r_head + r_water) ** 2
        for i in range(N_water):
            if sqdist_pbc(new_head[0], new_head[1],
                          positions_water[i, 0], positions_water[i, 1], L) < cutoff2:
                return False, moved_index, moved_type, old_head, new_head, new_tail_positions

        # head-head
        cutoff2 = (2.0 * r_head) ** 2
        for j in range(N_heads):
            if j == moved_index:
                continue
            if sqdist_pbc(new_head[0], new_head[1],
                          positions_heads[j, 0], positions_heads[j, 1], L) < cutoff2:
                return False, moved_index, moved_type, old_head, new_head, new_tail_positions

        # head-tail
        for j in range(N_heads):
            if j == moved_index:
                continue
            for k in range(n_c_per_chain):
                cutoff2 = (r_head + tail_radii[k]) ** 2
                if sqdist_pbc(new_head[0], new_head[1],
                              positions_tails[j, k, 0], positions_tails[j, k, 1], L) < cutoff2:
                    return False, moved_index, moved_type, old_head, new_head, new_tail_positions

        # tail-water
        for k in range(n_c_per_chain):
            cutoff2 = (tail_radii[k] + r_water) ** 2
            for i in range(N_water):
                if sqdist_pbc(new_tail_positions[k, 0], new_tail_positions[k, 1],
                              positions_water[i, 0], positions_water[i, 1], L) < cutoff2:
                    return False, moved_index, moved_type, old_head, new_head, new_tail_positions

        # tail-head
        for k in range(n_c_per_chain):
            cutoff2 = (tail_radii[k] + r_head) ** 2
            for j in range(N_heads):
                if j == moved_index:
                    continue
                if sqdist_pbc(new_tail_positions[k, 0], new_tail_positions[k, 1],
                              positions_heads[j, 0], positions_heads[j, 1], L) < cutoff2:
                    return False, moved_index, moved_type, old_head, new_head, new_tail_positions

        # tail-tail
        for k in range(n_c_per_chain):
            for j in range(N_heads):
                if j == moved_index:
                    continue
                for m in range(n_c_per_chain):
                    cutoff2 = (tail_radii[k] + tail_radii[m]) ** 2
                    if sqdist_pbc(new_tail_positions[k, 0], new_tail_positions[k, 1],
                                  positions_tails[j, m, 0], positions_tails[j, m, 1], L) < cutoff2:
                        return False, moved_index, moved_type, old_head, new_head, new_tail_positions

        return True, moved_index, moved_type, old_head, new_head, new_tail_positions

    # ------------------------------------------------------
    # WATER MOVE
    # ------------------------------------------------------
    else:
        moved_index = particle - N_heads
        moved_type = 1

        old_dummy = np.empty(2, dtype=np.float64)
        new_tail_positions = np.empty((n_c_per_chain, 2), dtype=np.float64)  # dummy

        old_water = np.empty(2, dtype=np.float64)
        old_water[0] = positions_water[moved_index, 0]
        old_water[1] = positions_water[moved_index, 1]

        new_water = np.empty(2, dtype=np.float64)
        new_water[0] = (old_water[0] + x_displacement) % L
        new_water[1] = (old_water[1] + y_displacement) % L

        # water-water
        cutoff2 = (2.0 * r_water) ** 2
        for i in range(N_water):
            if i == moved_index:
                continue
            if sqdist_pbc(new_water[0], new_water[1],
                          positions_water[i, 0], positions_water[i, 1], L) < cutoff2:
                return False, moved_index, moved_type, old_dummy, new_water, new_tail_positions

        # water-head
        cutoff2 = (r_water + r_head) ** 2
        for j in range(N_heads):
            if sqdist_pbc(new_water[0], new_water[1],
                          positions_heads[j, 0], positions_heads[j, 1], L) < cutoff2:
                return False, moved_index, moved_type, old_dummy, new_water, new_tail_positions

        # water-tail
        for j in range(N_heads):
            for k in range(n_c_per_chain):
                cutoff2 = (r_water + tail_radii[k]) ** 2
                if sqdist_pbc(new_water[0], new_water[1],
                              positions_tails[j, k, 0], positions_tails[j, k, 1], L) < cutoff2:
                    return False, moved_index, moved_type, old_dummy, new_water, new_tail_positions

        return True, moved_index, moved_type, old_dummy, new_water, new_tail_positions


# ==========================================================
# LOCAL ENERGIES FOR LIPID
# TAPERED TAIL VERSION
# ==========================================================

@njit
def lipid_local_energy_tapered(
    head_pos, tail_pos, moved_index,
    positions_heads, positions_tails, positions_water,
    L, r_water, r_head, epsilon, n_c_per_chain, tail_radii
):
    N_heads = positions_heads.shape[0]
    N_water = positions_water.shape[0]

    energy = 0.0

    # head-water
    cutoff2 = (1.75 * (r_head + r_water)) ** 2
    for i in range(N_water):
        if sqdist_pbc(head_pos[0], head_pos[1],
                      positions_water[i, 0], positions_water[i, 1], L) < cutoff2:
            energy -= epsilon

    # tail-water
    for c in range(n_c_per_chain):
        x = tail_pos[c, 0]
        y = tail_pos[c, 1]
        cutoff2 = (1.75 * (tail_radii[c] + r_water)) ** 2
        for i in range(N_water):
            if sqdist_pbc(x, y,
                          positions_water[i, 0], positions_water[i, 1], L) < cutoff2:
                energy += epsilon

    # tail-tail
    for c in range(n_c_per_chain):
        x = tail_pos[c, 0]
        y = tail_pos[c, 1]
        for j in range(N_heads):
            if j == moved_index:
                continue
            for cc in range(n_c_per_chain):
                cutoff2 = (1.75 * (tail_radii[c] + tail_radii[cc])) ** 2
                if sqdist_pbc(x, y,
                              positions_tails[j, cc, 0], positions_tails[j, cc, 1], L) < cutoff2:
                    energy -= 1.2 * epsilon

    return energy


# ==========================================================
# LOCAL ENERGIES FOR WATER
# TAPERED TAIL VERSION
# ==========================================================

@njit
def water_local_energy_tapered(
    water_pos,
    positions_heads, positions_tails,
    L, r_water, r_head, epsilon, n_c_per_chain, tail_radii
):
    N_heads = positions_heads.shape[0]
    energy = 0.0

    # water-tail
    for j in range(N_heads):
        for c in range(n_c_per_chain):
            cutoff2 = (1.75 * (r_water + tail_radii[c])) ** 2
            if sqdist_pbc(water_pos[0], water_pos[1],
                          positions_tails[j, c, 0], positions_tails[j, c, 1], L) < cutoff2:
                energy += epsilon

    # water-head
    cutoff2 = (1.75 * (r_water + r_head)) ** 2
    for j in range(N_heads):
        if sqdist_pbc(water_pos[0], water_pos[1],
                      positions_heads[j, 0], positions_heads[j, 1], L) < cutoff2:
            energy -= epsilon

    return energy


# ==========================================================
# PERSISTENT-UPDATE METROPOLIS STEP, NO CELLS
# TAPERED TAIL VERSION
# ==========================================================

@njit
def metropolis_pw_2D_persistent_no_cells_tapered(
    positions_heads, positions_tails, positions_water,
    L, r_water, r_head,
    epsilon, Temperature, k_b,
    d_max, rotation_max, n_c_per_chain, tail_radii
):
    accepted_geom, moved_index, moved_type, old_pos, new_pos, new_tail_positions = propose_mc_move_wp_2D_tapered(
        positions_heads, positions_tails, positions_water,
        d_max, rotation_max, L, r_water, r_head,
        n_c_per_chain, tail_radii
    )

    if not accepted_geom:
        return positions_heads, positions_tails, positions_water, False, moved_type

    # ------------------------------------------------------
    # LIPID MOVE
    # ------------------------------------------------------
    if moved_type == 0:
        initial_energy = lipid_local_energy_tapered(
            positions_heads[moved_index], positions_tails[moved_index], moved_index,
            positions_heads, positions_tails, positions_water,
            L, r_water, r_head, epsilon, n_c_per_chain, tail_radii
        )

        final_energy = lipid_local_energy_tapered(
            new_pos, new_tail_positions, moved_index,
            positions_heads, positions_tails, positions_water,
            L, r_water, r_head, epsilon, n_c_per_chain, tail_radii
        )

        delta_E = final_energy - initial_energy

        if delta_E < 0.0 or np.exp(-delta_E / (k_b * Temperature)) >= np.random.rand():
            positions_heads[moved_index, 0] = new_pos[0]
            positions_heads[moved_index, 1] = new_pos[1]

            for c in range(n_c_per_chain):
                positions_tails[moved_index, c, 0] = new_tail_positions[c, 0]
                positions_tails[moved_index, c, 1] = new_tail_positions[c, 1]

            return positions_heads, positions_tails, positions_water, True, moved_type

        return positions_heads, positions_tails, positions_water, False, moved_type

    # ------------------------------------------------------
    # WATER MOVE
    # ------------------------------------------------------
    else:
        initial_energy = water_local_energy_tapered(
            positions_water[moved_index],
            positions_heads, positions_tails,
            L, r_water, r_head, epsilon, n_c_per_chain, tail_radii
        )

        final_energy = water_local_energy_tapered(
            new_pos,
            positions_heads, positions_tails,
            L, r_water, r_head, epsilon, n_c_per_chain, tail_radii
        )

        delta_E = final_energy - initial_energy

        if delta_E < 0.0 or np.exp(-delta_E / (k_b * Temperature)) >= np.random.rand():
            positions_water[moved_index, 0] = new_pos[0]
            positions_water[moved_index, 1] = new_pos[1]
            return positions_heads, positions_tails, positions_water, True, moved_type

        return positions_heads, positions_tails, positions_water, False, moved_type

@njit
def c_ratio_base_from_P_tapered(P, head_radius_ratio, n_c_per_chain, taper_alpha):

    if n_c_per_chain == 1:
        S1 = 1.0
        S2 = 1.0
    else:
        S1 = 0.0
        S2 = 0.0

        for k in range(n_c_per_chain):
            s = 1.0 - taper_alpha * k / (n_c_per_chain - 1)

            # prevent negative radii
            if s < 0.0:
                s = 0.0

            S1 += s
            S2 += s * s

    c_ratio_base = (4.0 * head_radius_ratio * P * S1) / (math.pi * S2)

    return c_ratio_base

# %%
N = 600
eta = 0.7
epsilon
h, t, w, r_w, r_h, tail_radii = phospholipid_water_2D_tapered(1, N, eta, 1.2,
                                                   c_ratios[0], 4,0.3,taper_values[0])

for step in range(0, 15000000):
    h, t, w, accepted, moved_type = metropolis_pw_2D_persistent_no_cells_tapered(h, t, w, 1, r_w, r_h,
            epsilon, Temperature,k_b, r_h/5,np.pi/6,4,tail_radii)  

import matplotlib.pyplot as plt
from matplotlib.patches import Circle
#plt.figure()
#plt.plot(np.arange(0,len(asphericity_03)),asphericity_03)
#plt.savefig('asphericity trial')

fig, ax = plt.subplots()
ax.set_aspect('equal')

for head in h:
    ax.add_patch(Circle(head, r_h, fill=True, fc = 'red', alpha =1))

for tail in t:
    count = 0
    for point in tail:
        ax.add_patch(Circle(point,tail_radii[count], fill=True, fc = 'orange'))
        count += 1
for water in w:
    ax.add_patch(Circle(water, r_w, fill=True, fc = 'blue'))

ax.set_xlim(0, L)
ax.set_ylim(0, L) #this does work for no overlaps on graph
plt.savefig('final conditions trial.png')
plt.figure()

# %%
print(taper_values[20])
# Out:
# 0.0

# %%
def phospholipid_pair_correlation_2D(positions, r_water, r_head, r_carbon, L, bins):
    #positions is list positions = [heads, tails, water]
    #calculate pair correlation function for phospholipid heads and tails separately
    #only consider head - head interactions and tail - tail interactions for pair correlation function calculations
    #bins is number of bins for pair correlation function calculation
    #calculate g(r) for heads
    head_positions = np.array(positions[0])
    tail_positions = np.array(positions[1]).reshape(-1, 2) # reshape tail positions to be a list of all tail particle positions
    r_head_head, g_r_head_head = pair_correlation_2D(head_positions, r_head*2, L, bins)
    r_tail_tail, g_r_tail_tail = pair_correlation_2D(tail_positions, r_carbon*2, L, bins)
    return r_head_head, g_r_head_head, r_tail_tail, g_r_tail_tail

#plot the positions found above

# %%
#define function to identify monomer clusters in phospholipid system based on tail-tail contacts
@njit
def identify_monomer_clusters(positions_heads, positions_tails,
                              L, r_carbon, n_c_per_chain):

    N = positions_heads.shape[0]

    # adjacency matrix
    connected = np.zeros((N, N), dtype=np.int32)

    cutoff_sq = (4 * r_carbon)**2

    # -----------------------------
    # Build connectivity matrix
    # -----------------------------
    for i in range(N):
        for j in range(i+1, N):

            is_connected = False

            # tail–tail contact check
            for c1 in range(n_c_per_chain):
                for c2 in range(n_c_per_chain):

                    dx = positions_tails[i, c1, 0] - positions_tails[j, c2, 0]
                    dy = positions_tails[i, c1, 1] - positions_tails[j, c2, 1]

                    dx -= L * round(dx / L)
                    dy -= L * round(dy / L)

                    if dx*dx + dy*dy < cutoff_sq:
                        is_connected = True
                        break

                if is_connected:
                    break

            if is_connected:
                connected[i, j] = 1
                connected[j, i] = 1

    # -----------------------------
    # Find connected components
    # -----------------------------
    visited = np.zeros(N, dtype=np.int32)
    monomer_count = 0

    for i in range(N):

        if visited[i] == 1:
            continue

        # DFS stack
        stack = [i]
        visited[i] = 1
        size = 1

        while len(stack) > 0:
            node = stack.pop()

            for j in range(N):
                if connected[node, j] == 1 and visited[j] == 0:
                    visited[j] = 1
                    stack.append(j)
                    size += 1

        # If component size == 1 → monomer
        if size == 1:
            monomer_count += 1

    return monomer_count / N

# %%
#define function that identifies micelle cluster sizes in phospholipid system based on tail-tail contacts
@njit
def average_micelle_size(positions_heads, positions_tails,
                         L, r_carbon, n_c_per_chain):

    N = positions_heads.shape[0]

    # small buffer for numerical stability
    buffer = 2 * r_carbon
    cutoff_sq = (2 * r_carbon + buffer)**2

    # adjacency matrix
    connected = np.zeros((N, N), dtype=np.int32)

    # -----------------------------
    # Build connectivity matrix
    # -----------------------------
    for i in range(N):
        for j in range(i+1, N):

            is_connected = False

            for c1 in range(n_c_per_chain):
                for c2 in range(n_c_per_chain):

                    dx = positions_tails[i, c1, 0] - positions_tails[j, c2, 0]
                    dy = positions_tails[i, c1, 1] - positions_tails[j, c2, 1]

                    dx -= L * round(dx / L)
                    dy -= L * round(dy / L)

                    if dx*dx + dy*dy < cutoff_sq:
                        is_connected = True
                        break

                if is_connected:
                    break

            if is_connected:
                connected[i, j] = 1
                connected[j, i] = 1

    # -----------------------------
    # Find connected components
    # -----------------------------
    visited = np.zeros(N, dtype=np.int32)

    total_micelle_size = 0
    micelle_count = 0

    for i in range(N):

        if visited[i] == 1:
            continue

        # DFS
        stack = [i]
        visited[i] = 1
        size = 1

        while len(stack) > 0:
            node = stack.pop()

            for j in range(N):
                if connected[node, j] == 1 and visited[j] == 0:
                    visited[j] = 1
                    stack.append(j)
                    size += 1

        # if cluster larger than monomer
        if size > 1:
            total_micelle_size += size
            micelle_count += 1

    if micelle_count == 0:
        return 0.0

    return total_micelle_size / micelle_count

@njit
def pbc_dist2(x1, y1, x2, y2, L):
    dx = x1 - x2
    dy = y1 - y2

    dx -= L * np.round(dx / L)
    dy -= L * np.round(dy / L)

    return dx*dx + dy*dy
# --------------------------------------------------
# Identify clusters using simple BFS
# --------------------------------------------------
@njit
def find_clusters(heads, L, r_cut):

    N = heads.shape[0]
    visited = np.zeros(N, dtype=np.int32)
    cluster_sizes = np.zeros(N, dtype=np.int32)

    r_cut2 = r_cut * r_cut
    n_clusters = 0

    for i in range(N):

        if visited[i] == 1:
            continue

        # Start new cluster
        stack = np.zeros(N, dtype=np.int32)
        stack_size = 0

        stack[stack_size] = i
        stack_size += 1
        visited[i] = 1

        size = 0

        while stack_size > 0:

            stack_size -= 1
            j = stack[stack_size]
            size += 1

            for k in range(N):
                if visited[k] == 0:
                    d2 = pbc_dist2(
                        heads[j,0], heads[j,1],
                        heads[k,0], heads[k,1], L
                    )

                    if d2 < r_cut2:
                        visited[k] = 1
                        stack[stack_size] = k
                        stack_size += 1

        cluster_sizes[n_clusters] = size
        n_clusters += 1

    return cluster_sizes[:n_clusters]

# %%
@njit
def micelle_statistics(cluster_sizes, N_total):

    # Maximum possible size is N_total
    H = np.zeros(N_total+1, dtype=np.int32)

    # Build histogram H_i
    for i in range(cluster_sizes.shape[0]):
        size = cluster_sizes[i]
        if size > 2:      # exclude monomers
            H[size] += 1

    numerator_Nn = 0.0
    denominator_Nn = 0.0

    numerator_Nw = 0.0
    denominator_Nw = 0.0

    for i in range(2, N_total+1):
        if H[i] > 0:
            numerator_Nn += i * H[i]
            denominator_Nn += H[i]

            numerator_Nw += i * i * H[i]
            denominator_Nw += i * H[i]

    if denominator_Nn == 0.0:
        return 0.0, 0.0

    Nn = numerator_Nn / denominator_Nn
    Nw = numerator_Nw / denominator_Nw

    return Nn, Nw
@njit
def compute_micelle_sizes(heads, L, r_cut):

    cluster_sizes = find_clusters(heads, L, r_cut)

    Nn, Nw = micelle_statistics(cluster_sizes, heads.shape[0])

    return Nn, Nw

# %%
#all code below from ai to compute the asphericities of micelles in my system
@njit
def minimum_image(dx, L):
    return dx - L * np.round(dx / L)
@njit
def identify_micelles(positions_heads, L, r_cut):
    N = positions_heads.shape[0]
    visited = np.zeros(N, dtype=np.uint8)
    cluster_id = -np.ones(N, dtype=np.int32)
    
    r_cut2 = r_cut * r_cut
    stack = np.empty(N, dtype=np.int32)
    
    current_cluster = 0
    
    for i in range(N):
        if visited[i] == 1:
            continue
        
        stack_size = 1
        stack[0] = i
        
        while stack_size > 0:
            j = stack[stack_size - 1]
            stack_size -= 1
            
            if visited[j] == 1:
                continue
            
            visited[j] = 1
            cluster_id[j] = current_cluster
            
            for k in range(N):
                if visited[k] == 0:
                    dx = minimum_image(
                        positions_heads[j,0] - positions_heads[k,0], L
                    )
                    dy = minimum_image(
                        positions_heads[j,1] - positions_heads[k,1], L
                    )
                    
                    if dx*dx + dy*dy < r_cut2:
                        stack[stack_size] = k
                        stack_size += 1
        
        current_cluster += 1
    
    return cluster_id, current_cluster

@njit
def compute_asphericities_full(
    positions_heads,
    positions_tails,
    cluster_id,
    n_clusters,
    L,
    min_size
):
    N = positions_heads.shape[0]
    n_tail = positions_tails.shape[1]
    
    A_values = np.zeros(n_clusters)
    cluster_sizes = np.zeros(n_clusters, dtype=np.int32)
    
    # Count lipid numbers per cluster
    for i in range(N):
        cid = cluster_id[i]
        if cid >= 0:
            cluster_sizes[cid] += 1
    
    for cid in range(n_clusters):
        
        if cluster_sizes[cid] < min_size:
            continue
        
        # ---- find reference lipid ----
        ref = -1
        for i in range(N):
            if cluster_id[i] == cid:
                ref = i
                break
        
        x_ref = positions_heads[ref,0]
        y_ref = positions_heads[ref,1]
        
        # ---- compute centre of mass over ALL beads ----
        total_beads = cluster_sizes[cid] * (1+n_tail)
        
        x_sum = 0.0
        y_sum = 0.0
        
        for i in range(N):
            if cluster_id[i] == cid:
                
                # --- head ---
                dx = minimum_image(
                    positions_heads[i,0] - x_ref, L
                )
                dy = minimum_image(
                    positions_heads[i,1] - y_ref, L
                )
                
                x_head = x_ref + dx
                y_head = y_ref + dy
                
                x_sum += x_head
                y_sum += y_head
                
                # --- tail beads ---
                for t in range(n_tail):
                    #TRY HASHING OUT TAIL BEADS
                    dx = minimum_image(
                        positions_tails[i,t,0] - x_ref, L
                    )
                    dy = minimum_image(
                        positions_tails[i,t,1] - y_ref, L
                    )
                    
                    x_tail = x_ref + dx
                    y_tail = y_ref + dy
                    
                    x_sum += x_tail
                    y_sum += y_tail
        
        x_cm = x_sum / total_beads
        y_cm = y_sum / total_beads
        
        # ---- build gyration tensor ----
        a = 0.0
        b = 0.0
        c = 0.0
        
        for i in range(N):
            if cluster_id[i] == cid:
                
                # head
                dx = minimum_image(
                    positions_heads[i,0] - x_ref, L
                )
                dy = minimum_image(
                    positions_heads[i,1] - y_ref, L
                )
                
                x = x_ref + dx - x_cm
                y = y_ref + dy - y_cm
                
                a += x*x
                b += x*y
                c += y*y
                
                # tails
                for t in range(n_tail):
                 #   
                    dx = minimum_image(
                        positions_tails[i,t,0] - x_ref, L
                    )
                    dy = minimum_image(
                        positions_tails[i,t,1] - y_ref, L
                    )
                    
                    x = x_ref + dx - x_cm
                    y = y_ref + dy - y_cm
                    
                    a += x*x
                    b += x*y
                    c += y*y
        
        a /= total_beads
        b /= total_beads
        c /= total_beads
        
        trace = a + c
        diff  = a - c
        
        root = np.sqrt(0.25*diff*diff + b*b)
        
        lambda1 = 0.5*trace + root
        lambda2 = 0.5*trace - root
        
        if trace > 0.0:
            A_values[cid] = ((lambda1 - lambda2)**2) / (trace*trace)
    count = 0
    total = 0.0

    for cid in range(n_clusters):
        if cluster_sizes[cid] >= min_size:
            total += A_values[cid]
            count += 1

    if count > 0:
        asphericity_av = total / count
    else:
        asphericity_av = 0.0

    return asphericity_av

@njit
def micelle_asphericity_system_full(
    positions_heads,
    positions_tails,
    L,
    r_cut,
    min_size
):
    cluster_id, n_clusters = identify_micelles(
        positions_heads, L, r_cut
    )
    
    return compute_asphericities_full(
        positions_heads,
        positions_tails, 
        cluster_id,
        n_clusters,
        L,
        min_size
    )
@njit
def rc_from_P(P, rh):
    return (4 * P / np.pi) * rh

# %%
#generate series of data that lie in unit circle to test the asphericity 
Points = []
for n in range(0,10):
    x_value = np.cos(np.pi/5 * n)+1
    y_value = np.sin(np.pi/5*n)+1
    Points.append([x_value,y_value])
#test the asphericity
A = micelle_asphericity_system_full(np.array(Points),10, 0.5, 3)
print(A)

Points_1 = [[1,2],[2,2],[3,2]]
A = micelle_asphericity_system_full(np.array(Points_1), 10,2,3)
print(A)
#the asphericity appears to work perfectly for these points and able to identify the micelles
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       6     Points.append([x_value,y_value])
#       7 #test the asphericity
# ----> 8 A = micelle_asphericity_system_full(np.array(Points),10, 0.5, 3)
#       9 print(A)
#      11 Points_1 = [[1,2],[2,2],[3,2]]
#
# TypeError: not enough arguments: expected 5, got 4

# %%
#my original code
def asphericity_run(L,N, eta, head_radius_ratio,P_value,n_c_per_tail, area_fraction):
    c_ratio = rc_from_P(P_value, head_radius_ratio)
    h , t, w, r_w, r_h, r_c = phospholipid_water_2D(L,N, eta, head_radius_ratio, c_ratio,n_c_per_tail, area_fraction)
    A = np.zeros(100)
    for i in range(1000,150000):
        h, t, w, accepted, moved_type = monte_carlo_pw_2D_cells(h, t, w, L, r_w, r_h, r_c, epsilon, Temperature, d_max, n_c_per_tail, 20)
    for s in range(100):
        for i in range(1000):
            h, t, w, accepted, moved_type = monte_carlo_pw_2D_cells(h, t, w, L, r_w, r_h, r_c, epsilon, Temperature, d_max, n_c_per_tail, 20)
        A[s]= micelle_asphericity_system_full(h, t, L, 3*r_h, 5) 
    return np.mean(A)

# %%
import numpy as np
from numba import njit

@njit
def minimum_image(dx, L):
    return dx - L * np.round(dx / L)

#original tapered cluster asphericity - seems like it works up to about 0.6 packing parameter 
@njit
def lipids_connected_tapered(positions_tails, i, j, L, tail_radii, contact_factor):
    """
    Returns True if lipid i and lipid j are connected through any tail-tail contact.
    Uses tapered tail radii in the cutoff.
    """
    n_tail = positions_tails.shape[1]

    for a in range(n_tail):
        xi = positions_tails[i, a, 0]
        yi = positions_tails[i, a, 1]

        for b in range(n_tail):
            xj = positions_tails[j, b, 0]
            yj = positions_tails[j, b, 1]

            dx = minimum_image(xi - xj, L)
            dy = minimum_image(yi - yj, L)

            rcut = contact_factor * (tail_radii[a] + tail_radii[b])

            if dx * dx + dy * dy < rcut * rcut:
                return True

    return False


@njit
def identify_clusters_tapered(positions_tails, L, tail_radii, contact_factor):
    """
    Cluster lipids using tail-tail connectivity.
    Returns:
        cluster_id : array of cluster labels for each lipid
        n_clusters : total number of clusters
    """
    N = positions_tails.shape[0]

    visited = np.zeros(N, dtype=np.uint8)
    cluster_id = -np.ones(N, dtype=np.int32)
    stack = np.empty(N, dtype=np.int32)

    current_cluster = 0

    for i in range(N):
        if visited[i] == 1:
            continue

        stack_size = 1
        stack[0] = i

        while stack_size > 0:
            j = stack[stack_size - 1]
            stack_size -= 1

            if visited[j] == 1:
                continue

            visited[j] = 1
            cluster_id[j] = current_cluster

            for k in range(N):
                if visited[k] == 0:
                    if lipids_connected_tapered(positions_tails, j, k, L, tail_radii, contact_factor):
                        stack[stack_size] = k
                        stack_size += 1

        current_cluster += 1

    return cluster_id, current_cluster


@njit
def largest_cluster_asphericity_tapered(
    positions_heads,
    positions_tails,
    L,
    tail_radii,
    contact_factor,
    min_size
):
    """
    Computes asphericity of the largest lipid cluster.
    
    Cluster detection:
        tail-tail connectivity with tapered radii
    
    Shape measure:
        all beads included (heads + all tail beads)
    
    Parameters
    ----------
    positions_heads : (N, 2)
    positions_tails : (N, n_tail, 2)
    L : float
    tail_radii : (n_tail,)
    contact_factor : float
        e.g. 1.75 if you want consistency with your interaction cutoff
    min_size : int
        minimum number of lipids in largest cluster required
    """

    N = positions_heads.shape[0]
    n_tail = positions_tails.shape[1]

    cluster_id, n_clusters = identify_clusters_tapered(
        positions_tails, L, tail_radii, contact_factor
    )

    # ------------------------------------------------------
    # Find largest cluster
    # ------------------------------------------------------
    cluster_sizes = np.zeros(n_clusters, dtype=np.int32)

    for i in range(N):
        cid = cluster_id[i]
        if cid >= 0:
            cluster_sizes[cid] += 1

    largest_cid = -1
    largest_size = 0

    for cid in range(n_clusters):
        if cluster_sizes[cid] > largest_size:
            largest_size = cluster_sizes[cid]
            largest_cid = cid

    if largest_size < min_size or largest_cid == -1:
        return 0.0

    # ------------------------------------------------------
    # Choose reference lipid for unwrapping
    # ------------------------------------------------------
    ref = -1
    for i in range(N):
        if cluster_id[i] == largest_cid:
            ref = i
            break

    x_ref = positions_heads[ref, 0]
    y_ref = positions_heads[ref, 1]

    # ------------------------------------------------------
    # Centre of mass over all beads
    # ------------------------------------------------------
    total_beads = largest_size * (1 + n_tail)

    x_sum = 0.0
    y_sum = 0.0

    for i in range(N):
        if cluster_id[i] == largest_cid:

            # head
            dx = minimum_image(positions_heads[i, 0] - x_ref, L)
            dy = minimum_image(positions_heads[i, 1] - y_ref, L)
            x_sum += x_ref + dx
            y_sum += y_ref + dy

            # tails
            for t in range(n_tail):
                dx = minimum_image(positions_tails[i, t, 0] - x_ref, L)
                dy = minimum_image(positions_tails[i, t, 1] - y_ref, L)
                x_sum += x_ref + dx
                y_sum += y_ref + dy

    x_cm = x_sum / total_beads
    y_cm = y_sum / total_beads

    # ------------------------------------------------------
    # Gyration tensor of largest cluster
    # ------------------------------------------------------
    a = 0.0
    b = 0.0
    c = 0.0

    for i in range(N):
        if cluster_id[i] == largest_cid:

            # head
            dx = minimum_image(positions_heads[i, 0] - x_ref, L)
            dy = minimum_image(positions_heads[i, 1] - y_ref, L)

            x = x_ref + dx - x_cm
            y = y_ref + dy - y_cm

            a += x * x
            b += x * y
            c += y * y

            # tails
            for t in range(n_tail):
                dx = minimum_image(positions_tails[i, t, 0] - x_ref, L)
                dy = minimum_image(positions_tails[i, t, 1] - y_ref, L)

                x = x_ref + dx - x_cm
                y = y_ref + dy - y_cm

                a += x * x
                b += x * y
                c += y * y

    a /= total_beads
    b /= total_beads
    c /= total_beads

    trace = a + c
    diff = a - c
    root = np.sqrt(0.25 * diff * diff + b * b)

    lambda1 = 0.5 * trace + root
    lambda2 = 0.5 * trace - root

    if trace > 0.0:
        A = ((lambda1 - lambda2) ** 2) / (trace * trace)
    else:
        A = 0.0

    return A

# %%
import numpy as np
from numba import njit
#new asphericity parameter untested and requires multiple tail - tail contacts to remove random nearby monomers
@njit
def minimum_image(dx, L):
    return dx - L * np.round(dx / L)


@njit
def lipid_contact_count_tapered(positions_tails, i, j, L, tail_radii, contact_factor):
    """
    Count how many tail-tail bead contacts exist between lipid i and lipid j.
    """
    n_tail = positions_tails.shape[1]
    n_contacts = 0

    for a in range(n_tail):
        xi = positions_tails[i, a, 0]
        yi = positions_tails[i, a, 1]

        for b in range(n_tail):
            xj = positions_tails[j, b, 0]
            yj = positions_tails[j, b, 1]

            dx = minimum_image(xi - xj, L)
            dy = minimum_image(yi - yj, L)

            rcut = contact_factor * (tail_radii[a] + tail_radii[b])

            if dx * dx + dy * dy < rcut * rcut:
                n_contacts += 1

    return n_contacts


@njit
def lipids_connected_tapered_min_contacts(
    positions_tails, i, j, L, tail_radii, contact_factor, min_contacts
):
    """
    True if lipids i and j have at least min_contacts tail-tail bead contacts.
    """
    n_tail = positions_tails.shape[1]
    n_contacts = 0

    for a in range(n_tail):
        xi = positions_tails[i, a, 0]
        yi = positions_tails[i, a, 1]

        for b in range(n_tail):
            xj = positions_tails[j, b, 0]
            yj = positions_tails[j, b, 1]

            dx = minimum_image(xi - xj, L)
            dy = minimum_image(yi - yj, L)

            rcut = contact_factor * (tail_radii[a] + tail_radii[b])

            if dx * dx + dy * dy < rcut * rcut:
                n_contacts += 1
                if n_contacts >= min_contacts:
                    return True

    return False


@njit
def identify_clusters_tapered_min_contacts(
    positions_tails, L, tail_radii, contact_factor, min_contacts
):
    """
    Cluster lipids using tail-tail connectivity with at least min_contacts.
    """
    N = positions_tails.shape[0]

    visited = np.zeros(N, dtype=np.uint8)
    cluster_id = -np.ones(N, dtype=np.int32)
    stack = np.empty(N, dtype=np.int32)

    current_cluster = 0

    for i in range(N):
        if visited[i] == 1:
            continue

        stack_size = 1
        stack[0] = i

        while stack_size > 0:
            j = stack[stack_size - 1]
            stack_size -= 1

            if visited[j] == 1:
                continue

            visited[j] = 1
            cluster_id[j] = current_cluster

            for k in range(N):
                if visited[k] == 0:
                    if lipids_connected_tapered_min_contacts(
                        positions_tails, j, k, L, tail_radii, contact_factor, min_contacts
                    ):
                        stack[stack_size] = k
                        stack_size += 1

        current_cluster += 1

    return cluster_id, current_cluster


@njit
def cluster_sizes_from_ids(cluster_id, n_clusters):
    sizes = np.zeros(n_clusters, dtype=np.int32)
    for i in range(cluster_id.shape[0]):
        cid = cluster_id[i]
        if cid >= 0:
            sizes[cid] += 1
    return sizes


@njit
def largest_cluster_id(cluster_id, n_clusters):
    sizes = cluster_sizes_from_ids(cluster_id, n_clusters)

    largest_cid = -1
    largest_size = 0

    for cid in range(n_clusters):
        if sizes[cid] > largest_size:
            largest_size = sizes[cid]
            largest_cid = cid

    return largest_cid, largest_size, sizes


@njit
def prune_largest_cluster_core(
    positions_tails,
    cluster_id,
    largest_cid,
    L,
    tail_radii,
    contact_factor,
    min_contacts_pair,
    min_neighbours_core,
    n_prune_passes
):
    """
    Prune dangling lipids from the largest cluster.
    A lipid is kept only if it has at least min_neighbours_core neighbours
    within the current core under the same lipid-lipid connectivity rule.
    """
    N = positions_tails.shape[0]

    in_core = np.zeros(N, dtype=np.uint8)
    for i in range(N):
        if cluster_id[i] == largest_cid:
            in_core[i] = 1

    for _ in range(n_prune_passes):
        keep = np.zeros(N, dtype=np.uint8)

        for i in range(N):
            if in_core[i] == 0:
                continue

            neighbour_count = 0

            for j in range(N):
                if i == j:
                    continue
                if in_core[j] == 0:
                    continue

                if lipids_connected_tapered_min_contacts(
                    positions_tails, i, j, L, tail_radii, contact_factor, min_contacts_pair
                ):
                    neighbour_count += 1

            if neighbour_count >= min_neighbours_core:
                keep[i] = 1

        for i in range(N):
            in_core[i] = keep[i]

    return in_core


@njit
def count_mask(mask):
    total = 0
    for i in range(mask.shape[0]):
        if mask[i] == 1:
            total += 1
    return total


@njit
def unwrap_core_heads_propagation(
    positions_heads,
    positions_tails,
    in_core,
    L,
    tail_radii,
    contact_factor,
    min_contacts_pair
):
    """
    Unwrap head positions of the pruned core using connectivity propagation.
    Connectivity is based on tail-tail contacts.
    Returns:
        points   : (n_core, 2) unwrapped head positions
        n_core   : number of lipids in core
    """
    N = positions_heads.shape[0]
    n_core = count_mask(in_core)

    points = np.zeros((n_core, 2), dtype=np.float64)
    indices = np.empty(n_core, dtype=np.int32)

    idx = 0
    for i in range(N):
        if in_core[i] == 1:
            indices[idx] = i
            idx += 1

    # map from local index to whether already unwrapped
    done = np.zeros(n_core, dtype=np.uint8)

    # choose first core lipid as seed
    seed_local = 0
    seed_global = indices[seed_local]
    points[seed_local, 0] = positions_heads[seed_global, 0]
    points[seed_local, 1] = positions_heads[seed_global, 1]
    done[seed_local] = 1

    n_done = 1

    # propagate using cluster connectivity
    while n_done < n_core:
        progress = 0

        for a in range(n_core):
            if done[a] == 0:
                continue

            i = indices[a]
            xi = points[a, 0]
            yi = points[a, 1]

            for b in range(n_core):
                if done[b] == 1:
                    continue

                j = indices[b]

                if lipids_connected_tapered_min_contacts(
                    positions_tails, i, j, L, tail_radii, contact_factor, min_contacts_pair
                ):
                    dx = minimum_image(positions_heads[j, 0] - positions_heads[i, 0], L)
                    dy = minimum_image(positions_heads[j, 1] - positions_heads[i, 1], L)

                    points[b, 0] = xi + dx
                    points[b, 1] = yi + dy
                    done[b] = 1
                    n_done += 1
                    progress = 1

        # fallback in case the pruned set becomes disconnected
        if progress == 0:
            for b in range(n_core):
                if done[b] == 0:
                    j = indices[b]
                    dx = minimum_image(positions_heads[j, 0] - positions_heads[seed_global, 0], L)
                    dy = minimum_image(positions_heads[j, 1] - positions_heads[seed_global, 1], L)
                    points[b, 0] = points[seed_local, 0] + dx
                    points[b, 1] = points[seed_local, 1] + dy
                    done[b] = 1
                    n_done += 1
            break

    return points, n_core


@njit
def asphericity_from_points(points, n_points):
    """
    2D asphericity from a set of unwrapped points.
    """
    if n_points < 2:
        return 0.0

    x_cm = 0.0
    y_cm = 0.0
    for i in range(n_points):
        x_cm += points[i, 0]
        y_cm += points[i, 1]

    x_cm /= n_points
    y_cm /= n_points

    a = 0.0
    b = 0.0
    c = 0.0

    for i in range(n_points):
        x = points[i, 0] - x_cm
        y = points[i, 1] - y_cm

        a += x * x
        b += x * y
        c += y * y

    a /= n_points
    b /= n_points
    c /= n_points

    trace = a + c
    if trace <= 0.0:
        return 0.0

    diff = a - c
    root = np.sqrt(0.25 * diff * diff + b * b)

    lambda1 = 0.5 * trace + root
    lambda2 = 0.5 * trace - root

    return ((lambda1 - lambda2) ** 2) / (trace * trace)


@njit
def largest_micelle_asphericity_tapered_core(
    positions_heads,
    positions_tails,
    L,
    tail_radii,
    contact_factor,
    min_contacts_pair,
    min_size,
    min_neighbours_core,
    n_prune_passes
):
    """
    Improved largest-micelle asphericity.

    Cluster detection:
        tail-tail connectivity with at least min_contacts_pair contacts

    Largest micelle:
        largest cluster by lipid count

    Core cleanup:
        prune dangling lipids with too few neighbours

    Shape measure:
        heads only

    Unwrapping:
        propagation through lipid connectivity
    """
    cluster_id, n_clusters = identify_clusters_tapered_min_contacts(
        positions_tails, L, tail_radii, contact_factor, min_contacts_pair
    )

    largest_cid, largest_size, sizes = largest_cluster_id(cluster_id, n_clusters)

    if largest_cid < 0 or largest_size < min_size:
        return 0.0, 0, 0

    in_core = prune_largest_cluster_core(
        positions_tails,
        cluster_id,
        largest_cid,
        L,
        tail_radii,
        contact_factor,
        min_contacts_pair,
        min_neighbours_core,
        n_prune_passes
    )

    core_size = count_mask(in_core)

    if core_size < min_size:
        return 0.0, largest_size, core_size

    points, n_points = unwrap_core_heads_propagation(
        positions_heads,
        positions_tails,
        in_core,
        L,
        tail_radii,
        contact_factor,
        min_contacts_pair
    )

    A = asphericity_from_points(points, n_points)

    return A, largest_size, core_size

# %%
from numba import njit
#sped up chatgpt version
@njit
def asphericity_run(L, N, eta, head_radius_ratio, P_value, n_c_per_tail, area_fraction,
                    epsilon, Temperature, d_max, k_b,taper_value ):

    c_ratio = c_ratio_base_from_P_tapered(P_value, head_radius_ratio, n_c_per_tail, taper_value)
    h, t, w, r_w, r_h, tail_radii = phospholipid_water_2D_tapered(L, N, eta, head_radius_ratio,
                                                   c_ratio, 5, area_fraction,0.8)


    A = np.zeros(100, dtype=np.float64)

    for step in range(0, 30000000):
        h, t, w, accepted, moved_type = metropolis_pw_2D_persistent_no_cells_tapered(
            h, t, w, L, r_w, r_h,
            epsilon, Temperature, k_b,d_max,np.pi/6, 5, tail_radii
            )

    for s in range(100):
        for i in range(1000):
            h, t, w, accepted, moved_type = metropolis_pw_2D_persistent_no_cells_tapered(
            h, t, w, L, r_w, r_h,
            epsilon, Temperature, k_b,d_max,np.pi/6, 5, tail_radii
            )
        A[s] = micelle_asphericity_system_full(h,t, L, 3.5 * r_h, 6)
    return np.mean(A), largest_cluster_asphericity_tapered(h,t,L,tail_radii, 1.75, 5), largest_micelle_asphericity_tapered_core(h,t,L,tail_radii, 1.75, 2, 5, 2, 1)

# %%
#now that we have defined all variables and functions needed for calculations, can begin generating the simulations needed for report
#want to investigate the monomer count, micelle averages for fixed Packing parameter - do for one high and one low 
#investigate the asphericity for different packing parameters therefore probably need about 10 different P with minimum 5 runs of each
#and only generating the asphericity parameter every 5000 runs after has run for about 1.5x10^7 - and collect then 100 data points which can be averaged for asphericity
#calculate standard error and evarge for each value of asphericity
#could also include plot of asphericity w.r.t monte carlo steps to show that after certain no. of steps there is only random change - chi-squared analysis to asses
#would show that the system has equillibrated and reached a minimum energy state
#now set the general parameters kept constant across all systems
L = 1
N = 500
eta = 0.7
head_radius_ratio = 1.2 #keep this constant and vary the ratio of the carbon atoms to this
area_fraction = 0.3
epsilon = 1
t = 1.8
k_b = 1.4 * 10 ** -23
Temperature = t * epsilon / k_b
n_c_per_tail = 6 #weirdly does not affect the packing parameter of the system - should show in the report why 
#d_max = r_water / 10 - can only set this once the radius of water has been defined

# %%
# for first packing parameter calculations keep the number of carbon atoms in the tail constant 
P_values = [0.25,0.275,0.3,0.325,0.35,0.375,0.4,0.425,0.45,0.475,0.5,0.525,0.55,0.575,0.6,0.625,0.65,0.675,0.7,0.725,0.75, 0.825,0.85,0.875,0.9,0.925,0.95,0.975,1, 0.225,0.2,0.175,0.15,0.125,0.1, 0.075,0.05]
new_P_values = [0.2625, 0.2875, 0.3125, 0.3375, 0.3625,0.3875, 0.4125,0.4375, 0.4625,0.4875,0.5125,0.5375,0.5625, 0.5875]
for item in new_P_values:
    P_values.append(item)
taper_values = []
new_taper_values = []
for P_value in new_P_values:
    taper_value = taper_value_from_P(P_value, 1.2, 0.8,5)
    new_taper_values.append(taper_value)
print(len(P_values))
print(len(taper_values))
print(taper_values)
# Out:
# 51
# 0
# []

# %%
print(P_values)
# Out:
# [0.25, 0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.425, 0.45, 0.475, 0.5, 0.525, 0.55, 0.575, 0.6, 0.625, 0.65, 0.675, 0.7, 0.725, 0.75, 0.825, 0.85, 0.875, 0.9, 0.925, 0.95, 0.975, 1, 0.225, 0.2, 0.175, 0.15, 0.125, 0.1, 0.075, 0.05, [0.2625, 0.2875, 0.3125, 0.3375, 0.3625, 0.3875, 0.4125, 0.4375, 0.4625, 0.4875, 0.5125, 0.5375, 0.5625, 0.5875], [0.2625, 0.2875, 0.3125, 0.3375, 0.3625, 0.3875, 0.4125, 0.4375, 0.4625, 0.4875, 0.5125, 0.5375, 0.5625, 0.5875], 0.2625, 0.2875, 0.3125, 0.3375, 0.3625, 0.3875, 0.4125, 0.4375, 0.4625, 0.4875, 0.5125, 0.5375, 0.5625, 0.5875]

# %%
#set up code to run for averages with errors of asphericity 
A_2_total = list(A_2_total)
for i in range(len(new_P_values)):
    A_1_list = []
    A_2_list = []
    A_3_list = []
    c_ratio = c_ratio_base_from_P_tapered(new_P_values[i],head_radius_ratio, 5, new_taper_values[i])
    for n in range(5):
        A_1,A_2,A_3 = asphericity_run(L,N,eta, head_radius_ratio, c_ratio, 5, area_fraction, epsilon, Temperature, r_h/5, k_b, new_taper_values[i] )
        A_1_list.append(A_1)
        A_2_list.append(A_2)
        A_3_list.append(A_3[0])
    A_1_total.append(np.mean(A_1_list))
    A_2_total.append(np.mean(A_2_list))
    A_3_total.append(np.mean(A_3_list))
    A_1_errors.append(np.std(A_1_list) / np.sqrt(4))
    A_2_errors.append(np.std(A_2_list) / np.sqrt(4))
    A_3_errors.append(np.std(A_3_list) / np.sqrt(4))
    print(A_1_total[i], A_1_errors[i])
    print(A_2_total[i], A_2_errors[i])
    print(A_3_total[i], A_3_errors[i])
# Out:
# 0.4340884529579657 0.05294915986713989
# 0.10914586729825437 0.02698300099006315
# 0.0730414863675276 0.02356127356019085
# 0.35905962312751794 0.04636120894283583
# 0.30199048286478003 0.09649463459346738
# 0.21064265715364744 0.04753295730053729
# 0.472723536254945 0.06065255128563238
# 0.25389654526131744 0.0679998598344286
# 0.12368936234102443 0.018465968751721906
# 0.3625293345921833 0.07141310833695928
# 0.23397118725847213 0.07857257307696759
# 0.10645906703788163 0.049332366313108666
# 0.4503882214959054 0.09337257529524902
# 0.23551021908573438 0.06262887373719286
# 0.1440310695477655 0.05864795775829917
# 0.3865846645644185 0.07045801717591989
# 0.2172589055241311 0.062042466369841814
# 0.14735849825410458 0.05335628155794688
# 0.3188774586169264 0.04152182621186197
# 0.31201659672076804 0.0678464913401788
# 0.1853298155089384 0.06321577710970805
# 0.22794943837470688 0.07897903581682475
# 0.4555450428488813 0.059617453767447544
# 0.41555538335657455 0.050386923236385064
# ...

# %%
#provided the above works then we need to fit a curve to the data to perform chi^2 analysis 
import scipy.optimize
import scipy.stats
from scipy.optimize import curve_fit 
def linear_model(x, params):
    return x*params[0] + params[1]
def quadratic_model(x,params):
    return x**2 * params[0] + x * params[1] + params[2]
#define sigmoid function
#params = [Amin, Amax, k, P0]
def sigmoid(P, params):
    return  (params[0])/(1 + np.exp(-params[1]*(P-params[2])))

#define the chi^2 analysis part
def chi_squared(model_params, model, x_data, y_data, y_err):
    chi_sq = np.sum(((y_data - model(x_data, model_params))/y_err)**2)
    print(chi_sq)
    return chi_sq
def optimize_chi_squared(model, x_data, y_data, yerr, initial_values #can get these from the curve fit function
                         ):
    fit = scipy.optimize.minimize(chi_squared, initial_values, args = (model,x_data,y_data, yerr))
    print(fit.message)
    return fit.x.copy()

#reduced chi-squared should be calculated too
#THIS IS HOW TO USE OPTIMIZE FOR CHI_SQUARED
#fit = scipy.optimize.minimize(chi_squared, # the function to minimize
                            #initial_values, # where in 'parameter space' to start from
                            #args=(linear_model, x_values, y_values, y_errors) # model function and data to use
                             
# Termination output message is fit.message - did the minimisation complete successfully?
#print(fit.message)
#slope, intercept = fit.x.copy()

#print('best fit slope = {} units?'.format(slope))
#print('best fit intercept = {} units?'.format(intercept))

#normalised residuals function
def normalised_residual(x,y,yerr, model, model_params):
        residuals = np.asarray(y) - np.asarray(model(x, model_params))
        normalised_residual = np.asarray(residuals)/np.asarray(yerr)
        return normalised_residual

# %%
zero_indices = [i for i, value in enumerate(A_2_errors) if value == 0]

print(zero_indices)
A_2_errors = A_2_errors[:32] + A_2_errors[37:]
print(A_2_errors)
# Out:
# []
# [0.02698300099006315, 0.09649463459346738, 0.0679998598344286, 0.07857257307696759, 0.06262887373719286, 0.062042466369841814, 0.0678464913401788, 0.059617453767447544, 0.05250305283590541, 0.09236348029907518, 0.05484315397384926, 0.09372319474888163, 0.09803876961601733, 0.06274892531500217, 0.06226812712096176, 0.08512720450787038, 0.08473470089571841, 0.11164369508312304, 0.1579615188963482, 0.053040902760544364, 0.06485588944424812, 0.09815079529144834, 0.09212538404662252, 0.08438801932386635, 0.10701963939285689, 0.10106248249574527, 0.10895069312631285, 0.1174929893228173, 0.08904762810176144, 0.019515111083762048, 0.03790683240300898, 0.0777050835596494, 0.07625314952342896, 0.06255908597588326, 0.06709157940135504, 0.09862379462036276, 0.10274825585250923, 0.044333311305482945, 0.06634811554714165, 0.07100007670255559, 0.13036439694270494]
# ---------------------------------------------------------------------------
# ...

# %%
#time to plot some different trend lines and find best chi-squared fit
#remove zeros from the P_values section 

print(len(P_values), len(A_2_total), len(A_2_errors))
params = np.array([0.65,0.5,0])
initial_chi = chi_squared(params, sigmoid,P_values, A_2_total, A_2_errors)
new_chi_squared = optimize_chi_squared(sigmoid, P_values,A_2_total, A_2_errors,params)
dof = len(P_values) - len(params)
print(dof)
print(new_chi_squared)
#normalised residual calculations
norm_resid = normalised_residual(P_values, A_2_total, A_2_errors, sigmoid, new_chi_squared)
P_values_ordered = sorted(P_values)
# Out:
# 41 41 41
# 424.0888324588947
# 424.0888324588947
# 424.0888450224222
# 424.08883234596175
# 424.088830370411
# 3006.886472635809
# 3006.886385076418
# 3006.8864771902736
# 3006.8864655889506
# 373.26821263083366
# 373.26821258540986
# 373.2682112688595
# 373.2682124176707
# 302.56880048680483
# 302.56879195642347
# 302.5687993653149
# 302.5688013302727
# 1364.1826197609896
# 1364.1826197534008
# 1364.1826197886242
# 1364.1826197799492
# 301.15914591568514
# 301.1591359427581
# 301.1591447503537
# 301.1591475299651
# 298.3277619426106
# 298.32775194932043
# 298.3277607897301
# 298.32776357310263
# 287.31816438727105
# 287.3181542835676
# 287.31816328211266
# 287.31816609537964
# 248.19987853117277
# 248.19986753045703
# 248.1998775948926
# 248.1998809118975
# 159.3299693498512
# 159.32996207711278
# 159.3299687249138
# 159.32996928092967
# 403.8528670309729
# 403.852855012292
# 403.8528679606114
# 403.8528980917484
# 129.3696919234242
# 129.36968243145097
# 129.36969145025128
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
fig = plt.figure()
gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1], hspace=0)
#definitely do not get good results with the first asphericity definition, best definition is from the A_2
# -------------------------
# TOP MAIN AXIS
# -------------------------
ax_top = fig.add_subplot(gs[0])
#ax_top.plot(P_values, A_1_total, linestyle = ' ' , markersize = 5, marker = '^', color = 'blue')
ax_top.plot(P_values, A_2_total, linestyle = ' ', markersize = 5, marker = 's', color = 'green')
#ax_top.plot([0.05,0.075,0.1,0.125,0.15], [0,0,0,0,0], marker = '^', color = 'blue', linestyle = ' ')
#ax_top.plot(P_values, A_3_total, linestyle = ' ', markersize = 5, marker = 'o', color = 'red')
#ax_top.errorbar(P_values, A_1_total, yerr = A_1_errors, label = '1', linestyle = ' ', markersize = 4, elinewidth = 0.5, color = 'blue')
ax_top.errorbar(P_values, A_2_total, yerr = A_2_errors,linestyle = ' ', markersize = 3, elinewidth = 0.5, color = 'green')
#ax_top.errorbar(P_values, A_3_total, yerr = A_3_errors, label = '3', linestyle = ' ', markersize = 4, elinewidth = 0.5, color = 'red')
ax_top.plot(P_values_ordered, sigmoid(P_values_ordered, new_chi_squared), linestyle = '-', color = 'black')
ax_top.set_xlabel('Packing Parameter')
ax_top.set_ylabel('Asphericity')
ax_top.set_xlim(0.17,1.005)
ax_top.set_ylim(0,0.8)
ax_top.set_yticks([0,0.2,0.4,0.6,0.8])
ax_top.set_xticks([])
ax_top.tick_params(axis='x', which='both', bottom=False, labelbottom=False)
ax_inset1 = ax_top.inset_axes([0.72, 0.05, 0.25, 0.35])
ax_inset1.hist(norm_resid, bins = 20, edgecolor = 'black', color = 'blue')
ax_inset1.set_xticks([])
ax_inset1.set_title('Normalised \n Residuals', fontsize = 8)

ax_inset1.set_yticks([])

ax_bottom = fig.add_subplot(gs[1], sharex = ax_top)
ax_bottom.plot(P_values, norm_resid, marker = 'o', markersize = 2, linestyle = ' ', color = 'blue')
ax_bottom.plot([0,1.2],[0,0], linestyle = '--', color = 'black')
ax_bottom.set_xticks([0.2,0.4,0.6,0.8,1])
ax_bottom.set_xlabel('Packing Parameter')
ax_bottom.set_ylabel('Residuals')


plt.savefig('graph 4')

# %%
#do analysis on the avergaes graph 
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# final cell for the averages plot - using high packing parameter to see asphericity vary  - realistically need to replot once i have found lines of best fit later
Nn_final_03 = []
Nn_03_errors = []
Nw_final_03 = []
Nw_errors_03 = []
monomer_final_03 = []
monomer_errors_03 = []
asphericity_03_final = []
asphericity_03_errors = []
index_values = np.arange(0,1480,20)
N = 400 #reset for 400 particles to make slightly faster
while len(Nn_final_03) < 15:
    #reset the system
    Nn_total = []
    Nw_total = []
    monomer = []
    A =  []
    h, t, w, r_w, r_h, tail_radii = phospholipid_water_2D_tapered(1, N, eta, 1.2,
                                                   0.8, 4,0.3, 0)

    for i in range(10000,35000000):
        h, t, w, accepted, moved_type = metropolis_pw_2D_persistent_no_cells_tapered(h, t, w, 1, r_w, r_h,
            epsilon, Temperature,k_b, r_h/5,np.pi/6,4,tail_radii)
        if i % 100000 == 0:
            monomer_count = identify_monomer_clusters(h, t, L, tail_radii[0], n_c_per_tail)
            monomer.append(monomer_count)
            Nn, Nw = compute_micelle_sizes(h,L,4.5*r_h)
            Nn_total.append(Nn)
            Nw_total.append(Nw)
            asphericity = largest_cluster_asphericity_tapered(h,t,L,tail_radii, 1.75, 5)
            A.append(asphericity)
    Nn_final_03.append(Nn_total)
    Nw_final_03.append(Nw_total)
    asphericity_03_final.append(A)
    monomer_final_03.append(monomer)

Nn_final = np.mean(np.array(Nn_final_03), axis = 0)
Nn_errors = np.std(np.array(Nn_final_03), axis = 0)/np.sqrt(5)
Nw_final = np.mean(np.array(Nw_final_03), axis = 0)
Nw_errors = np.std(np.array(Nw_final_03), axis = 0)/np.sqrt(5)
A_final = np.mean(np.array(asphericity_03_final), axis = 0)
A_errors = np.std(np.array(asphericity_03_final), axis = 0)/np.sqrt(6)
Monomer_final = np.mean(np.array(monomer_final_03), axis = 0)
Monomer_errors = np.std(np.array(monomer_final_03), axis = 0)/np.sqrt(5)

# %%
#define functions for the chi-squared analysis of the data 
#assume straight line for majority of the points for increase in size of the micelle than can plot second straight line for the plateau section
def plateau_model(x, params):
    y_inf, y0, k = params
    return y_inf - (y_inf - y0) * np.exp(-k * x)
x_values = np.arange(0,34.89, 0.1)
params_Nn = [7.5,3.8,0.5]
params_Nw = [5,3.8,0.5]
chi_init_Nn = chi_squared(params_Nn, plateau_model, x_values, Nn_final, Nn_errors) 
chi_Nn = optimize_chi_squared(plateau_model, x_values, Nn_final, Nn_errors, params_Nn) # chisquared = 86.8, [7.50126014 4.0863327  0.0365117 ]
chi_init_Nw = chi_squared(params_Nw, plateau_model, x_values,Nw_final, Nw_errors )
chi_Nw = optimize_chi_squared(plateau_model, x_values, Nw_final, Nw_errors, params_Nw) #chisquared = 68.3, [5.42893388 3.76408535 0.04644258]
# Out:
# 63598.25330692724
# 63598.25330692724
# 63598.25394254961
# 63598.25335907776
# 63598.25381085033
# 35580477.75370783
# 35580478.10642077
# 35580477.39174116
# 35580444.73143337
# 44547.98229735666
# 44547.982799218225
# 44547.98236415159
# 44547.98320083481
# 612.6552891494215
# 612.6553098279561
# 612.6553147496022
# 612.6570215879642
# 686997.308371478
# 686997.3145070551
# 686997.3006078003
# 686996.6668363609
# 2680.8885869752253
# 2680.88857516617
# 2680.88847354669
# 2680.882121134481
# 135.89140718840497
# 135.89140928141666
# 135.89140367057732
# 135.89162103290442
# 1.864342739313374e+273
# 1.864342747661485e+273
# 1.8643427309652625e+273
# 1.864340807512177e+273
# 2.822730240139162e+92
# 2.8227302596456483e+92
# 2.8227302206326736e+92
# 2.822727323247671e+92
# 2.477482128223255e+32
# 2.4774821491301393e+32
# 2.477482107316371e+32
# 2.4774795893299653e+32
# 4691201626952.258
# 4691201669690.603
# 4691201584211.835
# 4691196976963.581
# 2828273.6462260396
# ...

# %%
#normalised residual calculations
norm_resid_Nw = normalised_residual(x_values, Nw_final, Nw_errors, plateau_model,[7.50126014, 4.0863327,  0.0365117 ] )
norm_resid_Nn = normalised_residual(x_values, Nn_final, Nn_errors, plateau_model, [5.42893388, 3.76408535, 0.04644258] )

# %%
x_values = np.arange(0,34.89, 0.1)
print(chi_Nn, chi_Nw)
fig = plt.figure()
gs = gridspec.GridSpec(2, 1, height_ratios=[2, 1], hspace=0)

# -------------------------
# TOP MAIN AXIS
# -------------------------
ax_top = fig.add_subplot(gs[0])
ax_top.tick_params(labelbottom=False)

ax_top.errorbar(x_values, Nn_final, yerr = Nn_errors, fmt = '^', label = 'Number Averaged', markersize = 1,elinewidth = 1,alpha = 0.3, color = 'blue')
ax_top.errorbar(x_values, Nw_final, yerr = Nw_errors, fmt = 'o', label = 'Weight Averaged', markersize = 1,elinewidth = 1,alpha = 0.4, color = 'red')
ax_top.plot(x_values, plateau_model(x_values,  [7.50126014, 4.0863327,  0.0365117 ]), color = 'black')
ax_top.plot(x_values, plateau_model(x_values, [5.42893388 ,3.76408535 ,0.04644258]), color = 'black')

#ax_bottom.plot(x_values[], linear_model(x_values[],chi_Nn), color = 'black', linestyle = '- -')
#ax_bottom.plot(x_values[], linear_model(x_values, chi_Nw), colour = 'black', linestyle = '- -')

ax_top.set_xlim(0,1500)
ax_top.set_yticks([3,5,7])
ax_top.set_xticks([])
ax_top.set_ylim(3,8)
ax_top.legend(loc = 'upper left', fontsize = 11)
ax_top.set_ylabel('Micelle Size', fontsize = 11)
ax_inset3 = ax_top.inset_axes([0.66, 0,0.34, 0.22])
ax_inset3.set_xticks([])
ax_inset3.set_yticks([])
ax_inset3.set_title('Normalised Residuals   ', fontsize = 9)
ax_inset1 = ax_top.inset_axes([0.66, 0.0, 0.17, 0.22])
ax_inset1.hist(norm_resid_Nw, bins = 20, color = 'red', edgecolor = 'black')
ax_inset1.set_xticks([])
ax_inset1.set_yticks([])

ax_inset2 = ax_top.inset_axes([0.83, 0.0, 0.17, 0.22])
ax_inset2.hist(norm_resid_Nw, bins = 20, color = 'blue', edgecolor = 'black')
ax_inset2.set_xticks([])
ax_inset2.set_yticks([])

ax_bottom = fig.add_subplot(gs[1], sharex=ax_top)
ax_bottom.errorbar(x_values,A_final, yerr = A_errors, fmt = 'o', markersize = 1, elinewidth = 1,alpha = 0.4, color = 'green')

ax_bottom.set_ylabel('Asphericity', fontsize = 11)
ax_bottom.set_xlabel('Monte Carlo Move / $10^4$', fontsize = 11)
ax_bottom.set_ylim(0,0.8)
ax_bottom.set_xticks([0,5,10,15,20, 25, 30,35])
ax_bottom.set_xticklabels([0,5,10,15,20, 25, 30,35])
ax_bottom.set_yticks([0,0.3,0.6])
ax_bottom.set_xlim(0,35)

plt.savefig('graph 1')
# Out:
# [5.42893388 3.76408535 0.04644258] [7.50126014 4.0863327  0.0365117 ]

# %%
#start thinking about how to produce graph that shows evolution of different size structures with more monte carlo moves for low packing parameter 
#code to get two adjacent graphs with one showing bilayer formations and the other circular micelles
N = 500
eta = 0.7
epsilon
h_1, t_1, w_1, r_w_1, r_h_1, tail_radii_1 = phospholipid_water_2D_tapered(1, N, eta, 1.2,
                                                   0.6, 5,0.3,0.8)

for step in range(0, 50000000):
    h_1, t_1, w_1, accepted, moved_type = metropolis_pw_2D_persistent_no_cells_tapered(h_1, t_1, w_1, 1, r_w_1, r_h_1,
            epsilon, Temperature,k_b, r_h_1/5,np.pi/6,4,tail_radii_1)  

import matplotlib.pyplot as plt
from matplotlib.patches import Circle
#plt.figure()
#plt.plot(np.arange(0,len(asphericity_03)),asphericity_03)
#plt.savefig('asphericity trial')

fig, ax = plt.subplots()
ax.set_aspect('equal')

for head in h_1:
    ax.add_patch(Circle(head, r_h_1, fill=True, fc = 'red', alpha =1))

for tail in t_1:
    count = 0
    for point in tail:
        ax.add_patch(Circle(point,tail_radii_1[count], fill=True, fc = 'orange'))
        count += 1
for water in w_1:
    ax.add_patch(Circle(water, r_w, fill=True, fc = 'blue'))

ax.set_xlim(0, L)
ax.set_ylim(0, L)
ax.set_xticks([])
ax.set_yticks([])
#this does work for no overlaps on graph
plt.savefig('graph_2.png')
#new figure for hopefully bilayer style structures

# %%
#code to get two adjacent graphs with one showing bilayer formations and the other circular micelles
N = 600
eta = 0.7
epsilon
h_1, t_1, w_1, r_w_1, r_h_1, tail_radii_1 = phospholipid_water_2D_tapered(1, N, eta, 1.2,
                                                   0.8, 6,0.3,1)

for step in range(0, 20000000):
    h_1, t_1, w_1, accepted, moved_type = metropolis_pw_2D_persistent_no_cells_tapered(h_1, t_1, w_1, 1, r_w_1, r_h_1,
            epsilon, Temperature,k_b, r_h_1/5,np.pi/6,6,tail_radii_1)  

import matplotlib.pyplot as plt
from matplotlib.patches import Circle
#plt.figure()
#plt.plot(np.arange(0,len(asphericity_03)),asphericity_03)
#plt.savefig('asphericity trial')

fig, ax = plt.subplots()
ax.set_aspect('equal')

for head in h_1:
    ax.add_patch(Circle(head, r_h_1, fill=True, fc = 'red', alpha =1))

for tail in t_1:
    count = 0
    for point in tail:
        ax.add_patch(Circle(point,tail_radii_1[count], fill=True, fc = 'orange'))
        count += 1
for water in w_1:
    ax.add_patch(Circle(water, r_w, fill=True, fc = 'blue'))

ax.set_xlim(0, L)
ax.set_ylim(0, L)
ax.set_xticks([])
ax.set_yticks([])
#this does work for no overlaps on graph
plt.savefig('graph_2.png')
#new figure for hopefully bilayer style structures
plt.figure()


h_2, t_2, w_2, r_w_2, r_h_2, tail_radii_2 = phospholipid_water_2D_tapered(1, N, eta, 1.2,
                                                   0.8, 4,0.3,0)

for step in range(0, 40000000):
    h_2, t_2, w_2, accepted, moved_type = metropolis_pw_2D_persistent_no_cells_tapered(h_2, t_2, w_2, 1, r_w_2, r_h_2,
            epsilon, Temperature,k_b, r_h_2/5,np.pi/6,4,tail_radii_2)  

import matplotlib.pyplot as plt
from matplotlib.patches import Circle
#plt.figure()
#plt.plot(np.arange(0,len(asphericity_03)),asphericity_03)
#plt.savefig('asphericity trial')

fig, ax = plt.subplots()
ax.set_aspect('equal')

for head in h_2:
    ax.add_patch(Circle(head, r_h_2, fill=True, fc = 'red', alpha =1))

for tail in t_2:
    count = 0
    for point in tail:
        ax.add_patch(Circle(point,tail_radii_2[count], fill=True, fc = 'orange'))
        count += 1
for water in w_2:
    ax.add_patch(Circle(water, r_w_2, fill=True, fc = 'blue'))

ax.set_xlim(0, L)
ax.set_ylim(0, L) #this does work for no overlaps on graph
ax.set_xticks([])
ax.set_yticks([])
plt.savefig('graph_3.png')
plt.figure()

# %%
#generate radius ratio values from the packing parameter 
c_ratios = []
for P_value in P_values:
    c_ratio = rc_from_P(P_value, head_radius_ratio)
    c_ratios.append(c_ratio)
print(c_ratios)
#from list of Carbon tail ratios generate the initial configurations for all systems

#h_03 , t_03, w_03, r_w_03, r_h_03, r_c_03 = phospholipid_water_2D(L,N, eta, head_radius_ratio, c_ratios[0],n_c_per_tail, area_fraction)
#h_035, t_035, w_035, r_w_035, r_h_035, r_c_035 = phospholipid_water_2D(L,N, eta, head_radius_ratio, c_ratios[1],n_c_per_tail, area_fraction)
h_04, t_04, w_04, r_w_04, r_h, r_c_04 = phospholipid_water_2D(L, N, eta, head_radius_ratio, c_ratios[2], n_c_per_tail, area_fraction)
#h_045, t_045, w_045, r_w_045, r_h_045, r_c_045 = phospholipid_water_2D(L, N, eta, head_radius_ratio,c_ratios[3],n_c_per_tail, area_fraction )
#h_05, t_05, w_05, r_w_05, r_h_05, r_c_05 = phospholipid_water_2D(L, N, eta, head_radius_ratio,c_ratios[4],n_c_per_tail, area_fraction )
#h_055, t_055, w_055, r_w_055, r_h_055, r_c_055 = phospholipid_water_2D(L, N, eta, head_radius_ratio,c_ratios[5],n_c_per_tail, area_fraction )
#h_06, t_06, w_06, r_w_06, r_h_06, r_c_06 = phospholipid_water_2D(L, N, eta, head_radius_ratio,c_ratios[6],n_c_per_tail, area_fraction )
#h_065, t_065, w_065, r_w_065, r_h_065, r_c_065 = phospholipid_water_2D(L, N, eta, head_radius_ratio,c_ratios[7],n_c_per_tail, area_fraction )
#h_07, t_07, w_07, r_w_07, r_h_07, r_c_07 = phospholipid_water_2D(L, N, eta, head_radius_ratio,c_ratios[8],n_c_per_tail, area_fraction )
#h_075, t_075, w_075, r_w_075, r_h_075, r_c_075 = phospholipid_water_2D(L, N, eta, head_radius_ratio,c_ratios[9],n_c_per_tail, area_fraction )

#10 initiail configurations with different packing parameters for the phospholipids only varying the size of the carbon atoms in each tail
d_max = r_w_04 / 10
# Out:
# [0.38197186342054884, 0.4201690497626037, 0.45836623610465854, 0.4965634224467135, 0.5347606087887683, 0.5729577951308232, 0.6111549814728781, 0.649352167814933, 0.6875493541569878, 0.7257465404990427, 0.7639437268410977, 0.8021409131831525, 0.8403380995252074, 0.8785352858672622, 0.9167324722093171, 0.954929658551372, 0.993126844893427, 1.0313240312354819, 1.0695212175775366, 1.1077184039195915, 1.1459155902616465, 1.2605071492878108, 1.298704335629866, 1.336901521971921, 1.3750987083139756, 1.4132958946560308, 1.4514930809980855, 1.4896902673401402, 1.5278874536821954, 0.3437746770784939, 0.30557749073643903, 0.26738030439438415, 0.22918311805232927, 0.19098593171027442, 0.15278874536821951, 0.11459155902616464, 0.07639437268410976]

# %%
#now write the code to check the asphericity parameter measurement after some monte carlo moves in the lowest packing parameter system
#using P = 0.3
Nn_total_03 = []
Nw_total_03 = []
monomer_list_03 = []
asphericity_03 = []
h, t, w, r_w, r_h, tail_radii = phospholipid_water_2D_tapered(1, N, eta, 1.2,
                                                   0.7, 4,0.3, 0.0)

for i in range(1000,30000000):
    h, t, w, accepted, moved_type = metropolis_pw_2D_persistent_no_cells_tapered(h, t, w, 1, r_w, r_h,
            epsilon, Temperature,k_b, r_h/5,np.pi/6,4,tail_radii)
    if i % 10000 == 0:
        monomer_count = identify_monomer_clusters(h, t, L,tail_radii[0] , n_c_per_tail)
        monomer_list_03.append(monomer_count)
        Nn, Nw = compute_micelle_sizes(h,L,3.5*r_h)
        Nn_total_03.append(Nn)
        Nw_total_03.append(Nw)
        A_value = micelle_asphericity_system_full(h, t, L, 2.8 * r_h, 5)
        asphericity_03.append(A_value)
        print(f'Move {i/10000}')
# Out:
# Move 1.0
# Move 2.0
# Move 3.0
# Move 4.0
# Move 5.0
# Move 6.0
# Move 7.0
# Move 8.0
# Move 9.0
# Move 10.0
# Move 11.0
# Move 12.0
# Move 13.0
# Move 14.0
# Move 15.0
# Move 16.0
# Move 17.0
# Move 18.0
# Move 19.0
# Move 20.0
# Move 21.0
# Move 22.0
# Move 23.0
# Move 24.0
# Move 25.0
# Move 26.0
# Move 27.0
# Move 28.0
# Move 29.0
# Move 30.0
# Move 31.0
# Move 32.0
# Move 33.0
# Move 34.0
# Move 35.0
# Move 36.0
# Move 37.0
# Move 38.0
# Move 39.0
# Move 40.0
# Move 41.0
# Move 42.0
# Move 43.0
# Move 44.0
# Move 45.0
# Move 46.0
# Move 47.0
# Move 48.0
# Move 49.0
# Move 50.0
# Move 51.0
# Move 52.0
# Move 53.0
# Move 54.0
# Move 55.0
# Move 56.0
# Move 57.0
# Move 58.0
# Move 59.0
# Move 60.0
# Move 61.0
# Move 62.0
# Move 63.0
# Move 64.0
# Move 65.0
# Move 66.0
# Move 67.0
# Move 68.0
# Move 69.0
# Move 70.0
# Move 71.0
# Move 72.0
# Move 73.0
# Move 74.0
# Move 75.0
# Move 76.0
# Move 77.0
# Move 78.0
# Move 79.0
# Move 80.0
# Move 81.0
# Move 82.0
# Move 83.0
# Move 84.0
# ...

# %%
#try again for A_05 be cause seem to have an outlier
import builtins 
list = builtins.list
A_05_2 = []
h_05_2, t_05_2, w_05_2, r_w_05_2, r_h_05_2, r_c_05_2 = phospholipid_water_2D(L, N, eta, head_radius_ratio,c_ratios[1],n_c_per_tail, area_fraction )
#for i in range(1000,15000000):
    #h_05_2, t_05_2, w_05_2, accepted, moved_type = metropolis_pw_2D(h_05_2, t_05_2, w_05_2, L, r_w_05_2, r_h_05_2, r_c_05_2, epsilon, Temperature, d_max, n_c_per_tail)
#while len(A_05_2) < 100:
   # for i in range(1000):
      #  h_05_2, t_05_2, w_05_2, accepted, moved_type = metropolis_pw_2D(h_05_2, t_05_2, w_05_2, L, r_w_05_2, r_h_05_2, r_c_05_2, epsilon, Temperature, d_max, n_c_per_tail)
#    A_05_2.append(micelle_asphericity_system_full(h_05_2, t_05_2, L, 3.5 * r_h_05_2, 5))
#print(A_05_2)
print(r_w_05_2, r_h_05_2, r_c_05_2)
# Out:
# 0.012040447982177821 0.014448537578613384 0.006438757293038908

# %%
c_ratio = rc_from_P(0.3, head_radius_ratio)
N = 500
eta = 0.6
h, t, w, r_w, r_h, r_c = phospholipid_water_2D(L, N, eta, head_radius_ratio,
                                                   c_ratio, n_c_per_tail, area_fraction)
N_heads = h.shape[0]
N_water = w.shape[0]
n_c = t.shape[1]
n_cells = 10
    # capacities (safe)
cap_h = N_heads
cap_w = N_water
cap_t = N_heads * n_c

cells_h = -np.ones((n_cells, n_cells, cap_h), dtype=np.int32)
counts_h = np.zeros((n_cells, n_cells), dtype=np.int32)

cells_w = -np.ones((n_cells, n_cells, cap_w), dtype=np.int32)
counts_w = np.zeros((n_cells, n_cells), dtype=np.int32)

cells_t = -np.ones((n_cells, n_cells, cap_t), dtype=np.int32)
counts_t = np.zeros((n_cells, n_cells), dtype=np.int32)

init_cell_lists(h, t, w, L, n_cells, cells_h, counts_h, cells_t, counts_t, cells_w, counts_w)

neigh_buf = np.empty((9, 2), dtype=np.int32)
new_tail_buf = np.empty((n_c, 2), dtype=np.float64)
    # ---------------------------
    # >>> END SNIPPET INSERT <<<
    # ---------------------------

A = np.zeros(100, dtype=np.float64)

for step in range(1000, 100000000):
    h, t, w, accepted, moved_type = monte_carlo_pw_2D_cells_persistent_noalloc(h, t, w, L, r_w, r_h, r_c,
            epsilon, Temperature, d_max, n_c,
            10, k_b,
            cells_h, counts_h, cells_t, counts_t, cells_w, counts_w,
            neigh_buf, new_tail_buf
        )    

import matplotlib.pyplot as plt
from matplotlib.patches import Circle
#plt.figure()
#plt.plot(np.arange(0,len(asphericity_03)),asphericity_03)
#plt.savefig('asphericity trial')

fig, ax = plt.subplots()
ax.set_aspect('equal')

for head in h:
    ax.add_patch(Circle(head, r_h, fill=True, fc = 'red', alpha =1))

for tail in t:
    for point in tail:
        ax.add_patch(Circle(point, r_c, fill=True, fc = 'orange'))
for water in w:
    ax.add_patch(Circle(water, r_w, fill=True, fc = 'blue'))

ax.set_xlim(0, L)
ax.set_ylim(0, L) #this does work for no overlaps on graph
plt.savefig('final conditions trial.png')
plt.figure()
print(compute_asphericities_full(h, ))

# %%
#run super long cell after defining new function for all the packing parameter values that we want 
L=1
N=400
A_totals = []
A_errors = []
P_values = [0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.425, 0.45, 0.475, 0.5, 0.525, 0.55, 0.575, 0.6, 0.625, 0.65, 0.7, 0.75]
for packing_parameter in P_values:
    A_averages = []
    print('new packing parameter')
    h, t, w, r_w, r_h, r_c = phospholipid_water_2D(L, N, eta, head_radius_ratio,
                                                   c_ratio, n_c_per_tail, area_fraction)
    d_max = r_w / 8
    for n in range(3):
        A_value = asphericity_run(L, N, eta, head_radius_ratio, packing_parameter, n_c_per_tail, area_fraction,epsilon, Temperature, d_max, 10, k_b)
        A_averages.append(A_value)
        print(n)
        print(A_value)
    A_totals.append(np.mean(A_averages))
    print(packing_parameter)
    A_errors.append(np.std(A_averages) / np.sqrt(1))
print(A_totals)
# Out:
# new packing parameter
# 0
# 0.39644069477294713
# 1
# 0.4574100198100577
# 2
# 0.5205960945010386
# 0.275
# new packing parameter
# 0
# 0.3610642823507273
# 1
# 0.5232957690185077
# 2
# 0.4599406820526825
# 0.3
# new packing parameter
# 0
# 0.3575909142591965
# 1
# 0.4957195751427305
# 2
# 0.3544052665693178
# 0.325
# new packing parameter
# 0
# 0.541909934880928
# 1
# 0.5644941522260919
# 2
# 0.44431190584720015
# 0.35
# new packing parameter
# 0
# 0.27112748452493673
# 1
# 0.33521969024387865
# 2
# 0.5427380369285927
# 0.375
# new packing parameter
# 0
# 0.27075265237570273
# 1
# 0.5284543012527123
# 2
# 0.4351756047667958
# 0.4
# new packing parameter
# 0
# 0.560719498485101
# 1
# 0.41121880102801966
# 2
# 0.43124228207304277
# 0.425
# new packing parameter
# 0
# 0.2863572566021654
# 1
# 0.35550014433159455
# 2
# 0.4445458648885282
# 0.45
# new packing parameter
# 0
# 0.4043388074239225
# 1
# 0.5386739239415946
# 2
# 0.5293644715280176
# 0.475
# new packing parameter
# 0
# ...

# %%
A_new = []
A_error_new = []
P_values_new = [0.725,0.75,0.775,0.8,0.825,0.85,0.875,0.9,0.925,0.95,0.975,0.1]
for packing_parameter in P_values_new:
    A_averages = []
    print('new packing parameter')
    h, t, w, r_w, r_h, r_c = phospholipid_water_2D(L, N, eta, head_radius_ratio,
                                                   c_ratio, n_c_per_tail, area_fraction)
    d_max = r_w / 8
    for n in range(4):
        A_value = asphericity_run(L, N, eta, head_radius_ratio, packing_parameter, n_c_per_tail, area_fraction,epsilon, Temperature, d_max, 10, k_b)
        A_averages.append(A_value)
        print(n)
        print(A_value)
    A_new.append(np.mean(A_averages))
    print(packing_parameter)
    A_error_new.append(np.std(A_averages) / np.sqrt(4))
print(A_new)
# Out:
# new packing parameter
# 0
# 0.20154951720733802
# 1
# 0.3958166137637052
# 2
# 0.47662522207537455
# 3
# 0.44296610402299197
# 0.725
# new packing parameter
# 0
# 0.5267236530378614
# 1
# 0.5863339466203178
# 2
# 0.33275438617793734
# 3
# 0.43343144705298725
# 0.75
# new packing parameter
# 0
# 0.4210599654519375
# 1
# 0.6474264139951009
# 2
# 0.42183447625991716
# 3
# 0.3190497125071445
# 0.775
# new packing parameter
# 0
# 0.5189258870007503
# 1
# 0.3018326083100755
# 2
# 0.4896453530458942
# 3
# 0.5978274091058209
# 0.8
# new packing parameter
# 0
# 0.028017477401297404
# 1
# 0.27210387966623206
# 2
# 0.2927128890563024
# 3
# 0.1633253763911109
# 0.825
# new packing parameter
# 0
# 0.3780862919617479
# 1
# 0.3963490980125538
# 2
# 0.37781692017521484
# 3
# 0.0
# 0.85
# new packing parameter
# 0
# 0.5049585338071191
# 1
# 0.378276083168571
# 2
# 0.050151829677946805
# 3
# 0.2453190163481339
# 0.875
# new packing parameter
# 0
# 0.2768520469749007
# 1
# 0.049951362861024896
# 2
# ...

# %%
#now to calculate the standard errors on the asphericity values
A_total = [A_0275,A_03,A_0325, A_035,A_0375, A_04,A_0425, A_045,A_0475, A_05,A_0525, A_055,A_0575, A_06,A_0625, A_065, A_07, A_075]
A_averages = []
A_errors = []
for A_list in A_total:
    A_average = np.mean(A_list)
    A_averages.append(A_average)
    A_error = np.std(A_average)
    A_errors.append(A_error)

#can now plot asphericity against P with errors associated to see the general trend and hope that as P increases A decreases
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 #now to calculate the standard errors on the asphericity values
# ----> 2 A_total = [A_0275,A_03,A_0325, A_035,A_0375, A_04,A_0425, A_045,A_0475, A_05,A_0525, A_055,A_0575, A_06,A_0625, A_065, A_07, A_075]
#       3 A_averages = []
#       4 A_errors = []
#
# NameError: name 'A_0275' is not defined

# %%
Nn_final = np.mean(np.array(Nn_final_03), axis = 0)
Nn_errors = np.std(np.array(Nn_final_03), axis = 0)/np.sqrt(5)
Nw_final = np.mean(np.array(Nw_final_03), axis = 0)
Nw_errors = np.std(np.array(Nw_final_03), axis = 0)/np.sqrt(5)
A_final = np.mean(np.array(asphericity_03_final), axis = 0)
A_errors = np.std(np.array(asphericity_03_final), axis = 0)/np.sqrt(6)
Monomer_final = np.mean(np.array(monomer_final_03), axis = 0)
Monomer_errors = np.std(np.array(monomer_final_03), axis = 0)/np.sqrt(5)

#now produce plot - will also need to incllude line of best fit for micelle size averages
fig = plt.figure()
gs = gridspec.GridSpec(2, 1, height_ratios=[2, 1], hspace=0)
x_values = np.arange(0,1499)
# -------------------------
# TOP MAIN AXIS
# -------------------------
ax_top = fig.add_subplot(gs[0])
ax2 = ax_top.twinx()
ax_top.errorbar(x_values[::10], Nn_final[::10], yerr = Nn_errors[::10], fmt = '^', label = 'Number Averaged', markersize = 2,elinewidth = 0.5, color = 'purple')
ax_top.errorbar(x_values[::10], Nw_final[::10], yerr = Nw_errors[::10], fmt = 'o', label = 'Weight Averaged', markersize = 2,elinewidth = 0.5, color = 'red')
ax_bottom.errorbar(x_values[::10], Monomer_final[::10], yerr = Monomer_errors[::10], fmt = '^', markersize = 2, elinewidth = 0.5, color = 'green')
ax2.errorbar(x_values[::10], Monomer_final[::10], yerr = Monomer_errors[::10], fmt = '^', markersize = 2, elinewidth = 0.5, color = 'green')
ax2.set_ylim(0.05,0.6)
ax_top.set_xlim(0,1500)
ax_top.set_yticks([3,5,7])
ax_top.set_xticks([])
ax_top.set_ylim(2,8)
ax_top.legend(loc = 'upper left', fontsize = 9)
ax_top.set_ylabel('Average Micelle Size', fontsize = 9)

ax_bottom = fig.add_subplot(gs[1], sharex=ax_top)
ax_bottom.errorbar(x_values[::10],A_final[::10], yerr = A_errors[::10], fmt = 'o', markersize = 2, elinewidth = 0.5, color = 'blue')
ax_bottom.set_ylabel('Asphericity of Micelles', fontsize = 9)
ax_bottom.set_xlabel('Monte Carlo Move / $10^4$', fontsize = 9)
ax_bottom.set_ylim(0,0.6)
ax_bottom.set_yticks([0,0.25,0.5])
ax_bottom.set_xlim(0,1500)

plt.savefig('graph 1')

# %%
#plot the graphs for average asphericity vs packing parameter and also graph for asphericity over monte carlo steps
#might actually want to increase the number of different packing parameters used and also re run some to get better average for asphericity
#P_values = P_values + P_values_new
#A_totals = A_totals + A_new
#A_errors = A_errors + A_error_new
print(P_values[0:30])
print(P_values)
print(A_totals)
print(A_errors)
plt.figure()
plt.errorbar(P_values[:30], A_totals[:30], yerr = A_errors[:30], fmt = 'o', markersize = 2)
plt.ylabel('')
plt.xlabel('2D Packing Parameter')
plt.savefig('Asphericity vs Packing Parameter')
#looks good but tiny errors because same system is used and after equillibration there is minimal change to the asphericity

#make this plot look better with error bars and two axis plus line of best fit 

x_values = np.arange(0,1499)
plt.figure()
plt.plot(x_values, asphericity_03, label = 'Asphericity')
plt.plot(x_values, Nn_total_03, label = 'Number Averaged Micelle Size')
plt.plot(x_values, Nw_total_03, label = 'Weight Averaged Micelle Size')
plt.plot(x_values, monomer_list_03, label = 'Monomer Count')
plt.xlabel('Monte Carlo Step / 10000 moves')
plt.ylabel('System Properties')
plt.legend()
plt.savefig('Averages for P 0_3')
#using P = 0.3

#have several plots for the report now as can include two final state images asphericity vs packing parameter
#can include plots of micelle properties for at least one packing parameter
print(A_averages)
print(A_errors)
# Out:
# [0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.425, 0.45, 0.475, 0.5, 0.525, 0.55, 0.575, 0.6, 0.625, 0.65, 0.7, 0.75, 0.725, 0.75, 0.775, 0.8, 0.825, 0.85, 0.875, 0.9, 0.925, 0.95, 0.975, 0.1]
# [0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.425, 0.45, 0.475, 0.5, 0.525, 0.55, 0.575, 0.6, 0.625, 0.65, 0.7, 0.75, 0.725, 0.75, 0.775, 0.8, 0.825, 0.85, 0.875, 0.9, 0.925, 0.95, 0.975, 0.1, 0.725, 0.75, 0.775, 0.8, 0.825, 0.85, 0.875, 0.9, 0.925, 0.95, 0.975, 0.1, 0.725, 0.75, 0.775, 0.8, 0.825, 0.85, 0.875, 0.9, 0.925, 0.95, 0.975, 0.1, 0.725, 0.75, 0.775, 0.8, 0.825, 0.85, 0.875, 0.9, 0.925, 0.95, 0.975, 0.1, 0.725, 0.75, 0.775, 0.8, 0.825, 0.85, 0.875, 0.9, 0.925, 0.95, 0.975, 0.1]
# ...
