# %%
import numpy as np
import matplotlib.pyplot as plt
import random
# !pip install numba 
from numba import njit
# defining simple lattice functions to place n particles in a box of length L 

def simple_lattice_2D(L,n):
     positions = []
     N = int(np.sqrt(n))
     separation = L / N
     for i in range(0,N):
            for j in range(0,N):
                x = (i + 0.5) * separation
                y = (j + 0.5) * separation
                positions.append(list([x,y]))
     return positions


def simple_lattice_3D(L,n):
    positions = []
    N = int(np.cbrt(n))
    separation = L / N
    for i in range(0,N):
        for j in range(0,N):
            for k in range(0,N):
                x = (i + 0.5) * separation
                y = (j + 0.5) * separation
                z = (k + 0.5) * separation
                positions.append((x,y,z))
    return positions

def particle_diameter_3D(L, n, vol_fraction):
    volume_per_particle = (L**3 * vol_fraction) / n
    diameter = 2*(3 * volume_per_particle / (4 * np.pi))**(1/3)
    return diameter
def particle_diameter_2D(L,n, area_fraction):
    area_per_particle = (L**2 * area_fraction) / n
    diameter = 2*(area_per_particle / np.pi)**(1/2)
    return diameter

x_coords, y_coords = zip(*simple_lattice_2D(1,100))
plt.figure( facecolor=(1, 1, 1, 0.3))
plt.plot(x_coords, y_coords, 'o', markersize = 23.5)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xticks([])
plt.yticks([])
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Simple Lattice in 2D', fontsize = 16)
plt.savefig('simple_lattice_2D')

def monte_carlo_2D_np(positions, displacement, L, diameter):
    positions = np.array(positions, dtype=float)  # ensure numeric array
    N = len(positions)
    
    # Pick a random particle
    particle = random.randint(0, N - 1)
    
    # Copy positions for trial move
    new_positions = positions.copy()
    
    # Random displacement along x or y
    axis = random.randint(0, 1)       # 0=x, 1=y
    direction = 1 if random.randint(0, 1) == 0 else -1
    new_positions[particle, axis] += direction * displacement
    
    # Apply periodic boundary conditions
    new_positions[particle] %= L
    
    # Compute distances from the moved particle to all others
    diffs = new_positions - new_positions[particle]         # shape (N, 2)
    
    # Minimum image convention for periodic boundaries
    diffs = diffs - L * np.round(diffs / L)
    
    distances = np.linalg.norm(diffs, axis=1)
    distances[particle] = np.inf  # ignore self-distance
    
    # Check overlap
    if np.any(distances < diameter):
        return positions  # reject move
    else:
        return new_positions  # accept move
    
L = 4
n = 4 
vol_fraction = 0.1
no_density = n / (L**2)
diameter = particle_diameter_2D(L, n, vol_fraction)
# Out:
# Requirement already satisfied: numba in /home/sophiameadows/anaconda3/envs/ppp/lib/python3.12/site-packages (0.62.1)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /home/sophiameadows/anaconda3/envs/ppp/lib/python3.12/site-packages (from numba) (0.45.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in /home/sophiameadows/anaconda3/envs/ppp/lib/python3.12/site-packages (from numba) (1.26.4)

# %%
# create stepwise function to move random particle in random direction by displacement amount specified
#also account for the periodic boundary conditions inside the movement 
import random
def monte_carlo_2D(positions, displacement, L, diameter):
    positions = np.array(positions, dtype=float)  # ensure numeric array
    N = len(positions)
    
    # Pick a random particle
    particle = random.randint(0, N - 1)
    
    # Copy positions for trial move
    new_positions = positions.copy()
    
    #random angle for movement and then calculate x and y changes
    angle = random.uniform(0, 2 * np.pi)
    x_change = displacement * np.cos(angle)
    y_change = displacement * np.sin(angle)
    new_positions[particle, 0] += x_change
    new_positions[particle, 1] += y_change
    # Apply periodic boundary conditions
    new_positions[particle] %= L
    
    # Compute distances from the moved particle to all others
    diffs = new_positions - new_positions[particle]         # shape (N, 2)
    
    # Minimum image convention for periodic boundaries
    diffs = diffs - L * np.round(diffs / L)
    
    distances = np.linalg.norm(diffs, axis=1)
    distances[particle] = np.inf  # ignore self-distance
    
    # Check overlap
    if np.any(distances < diameter):
        return positions  # reject move
    else:
        return new_positions  # accept move

# %%
#list of provided parameters - good starting point


L = 1
n = 100
vol_fraction = 0.72
no_density = n / (L**2)
diameter = particle_diameter_2D(L, n, vol_fraction)
pos_0 = simple_lattice_2D(L,n)

pos_new = monte_carlo_2D(pos_0, 0.0001, L, diameter)

if np.array_equal(pos_new, pos_0):
    print("Move rejected")
else:
    print("Move accepted")
  
#particles free to move with monte carlo function for 2D
#code to find the optimum displacement value to achieve 25% - 50% acceptance rate
acceptance_count = 0
pos_ref = pos_0
for i in range(0,1000):
    pos_new = monte_carlo_2D(pos_ref, 0.0043,L, diameter)
    if np.array_equal(pos_new, pos_ref):
        pass #move rejected
    else:
        acceptance_count += 1 #move accepted
        pos_ref = pos_new
print(acceptance_count)

#gives rougly 39% acceptance rate for the suggested parameters
# Out:
# Move accepted
# 426

# %%
#define total energy calculation function

def total_energy(positions, L, diameter):
    positions = np.array(positions, dtype=float)
    N = len(positions)
    total_energy = 0.0
    
    for i in range(N):
        for j in range(i + 1, N):
            # Compute distance with minimum image convention
            diff = positions[i] - positions[j]
            diff = diff - L * np.round(diff / L)
            distance = np.linalg.norm(diff)
            
            # Simple hard-sphere potential
            if distance < diameter:
                total_energy += np.inf  # Infinite energy for overlap
            else:
                total_energy += 0.0  # No interaction otherwise
                
    return np.array(total_energy)

# define function to calculate the change in energy after a single move
def energy_change(positions, initial_energy, new_positions):
    new_coords = np.any(new_positions != positions, axis=1)
    moved_particle = np.where(new_coords)[0][0]
    new_energy = initial_energy
    for i in range(0,len(positions)):
        if i == moved_particle:
            continue  # Skip self-interaction
        # Compute distance with minimum image convention
        diff_old = positions[moved_particle] - positions[i]
        diff_old = diff_old - L * np.round(diff_old / L)
        distance_old = np.linalg.norm(diff_old)
        
        diff_new = new_positions[moved_particle] - new_positions[i]
        diff_new = diff_new - L * np.round(diff_new / L)
        distance_new = np.linalg.norm(diff_new)
        
        # Simple hard-sphere potential
            
        if distance_new < diameter and distance_old >= diameter:
            new_energy = np.inf + initial_energy # add infinite energy if moving into overlap
        if distance_new >= diameter and distance_old < diameter:
            new_energy = -np.inf + initial_energy # Remove infinite energy if moving out of overlap
        else:
            new_energy = 0.0 + initial_energy # no overlap either before or after
    return new_energy

# %%
#test initial energy and energy change functions
initial_energy = total_energy(pos_0, L, diameter)
pos_new = monte_carlo_2D(pos_0, 0.0043,L,diameter)
delta_E = energy_change(np.array(pos_0), initial_energy, pos_new)
print(initial_energy)
print(delta_E)
#i think this works, as E should always be
# Out:
# 0.0
# 0.0

# %%
#defining the metropolis algorithm - will have to change the monte carlo to accept even if center of spheres are within a radius
def metropolis(positions,initial_energy, delta_E_func, stepwise_function, displacement, L, diameter, k_B, T):
    positions = np.array(positions)
    new_positions = stepwise_function(positions, displacement, L , diameter)
    delta_E = delta_E_func(positions, initial_energy, new_positions)
    if delta_E > 0:
        n == random.rand(0,1)
        if n < np.exp(-delta_E / (k_B * T)):#how do we find T
            return  new_positions
        else:
            return positions
    else:
        return positions
# this should allow you to input the initial energy, positions, displacement, L Boltzman constant and temperature 
#then will perform a montecarlo step to the system to move particle
#calculate the energy after the move and accept if energy is lowered
#if energy is the same or more then it is accepted if the metropolis function is less than the random number generated

# %%
#define the pair correlation function
#try delta_r as approx 0.1 times the diameter as initial trial
@njit
def pair_correlation_2D(positions, diameter, L, bins=100):
    N = len(positions) # no.of particles
    hist = np.zeros(bins, dtype=float) # create histogram array for each bin
    delta_r = (L / 2) / bins  # bin width
    
    for i in range(N):
        for j in range(i + 1, N):
            # Compute distance with minimum image convention
            diff = positions[i] - positions[j]
            diff = diff - L * np.round(diff / L)
            distance = (diff[0]**2 + diff[1]**2)**0.5
            
            # Determine which bin this distance falls into
            bin_index = int(distance / delta_r)
            if bin_index < bins:
                hist[bin_index] += 1  # count each pair once
            
    r = ((np.arange(bins) + 0.5) * delta_r) / diameter # midpoint of each bin for average value of r 
    area_density = N / (L**2)
    n_ideal = 2 * np.pi * r * delta_r * area_density * N # ideal gas distribution

    g_r = hist / n_ideal
    return r, g_r

# %%
#trial of pair correlation function
N = 100
L = 1
eta_68 = 0.68
#equilibration run for area fration = 0.68
diameter_68 = particle_diameter_2D(L, N, eta_68)
pos_0_68 = np.array(simple_lattice_2D(L,N))
pos_68 = pos_0_68.copy()
r_68, g_r_68 = pair_correlation_2D(pos_68,diameter_68, L)
r_initial_68, g_r_initial = pair_correlation_2D(pos_0_68, diameter_68, L) # initial position before equilibrating
#run monte carlo 10**4 times
g_r_total_eq = []

for i in range(0, 4*10 **4 + 1):
    pos_68 = monte_carlo_2D(pos_68, 0.0043, L, diameter_68)
    if i % 10000 == 0:
        r, g_r = pair_correlation_2D(pos_68,diameter_68, L, bins = 100)
        g_r_total_eq.append(g_r)

x2_coords = r
y1_coords = g_r_total_eq[0]
y2_coords = g_r_total_eq[1]
y3_coords = g_r_total_eq[2]
y4_coords = g_r_total_eq[3]
y5_coords = g_r_total_eq[4]
plt.figure()
plt.plot(x2_coords, y1_coords, label='After 0 moves')
plt.plot(x2_coords, y2_coords, label='After 10000 moves')
plt.plot(x2_coords, y3_coords, label='After 20000 moves')
plt.plot(x2_coords, y4_coords, label='After 30000 moves')
plt.plot(x2_coords, y5_coords, label='After 40000 moves')
plt.savefig('equillibration_2D.png')


x_coords, y_coords = zip(*pos_68)
x_coords = list(x_coords)
y_coords = list(y_coords)
x_original = x_coords.copy()
y_original = y_coords.copy()
#adding a shiftedcopy to left hand side of box
x_coords += [x - 1 for x in x_original]
y_coords += y_original
#adding shifted to right side of box
x_coords += [x + 1 for x in x_original]
y_coords += y_original
#adding shifte to top of box
x_coords += x_original
y_coords += [y + 1 for y in y_original]
#adding shifted to bottom of box
x_coords += x_original
y_coords += [y - 1 for y in y_original]

plt.figure(facecolor = (1,1,1,0.3))
plt.plot(x_coords, y_coords, 'o', markersize = 23.5)
plt.xlim(0,1)
plt.ylim(0,1)
plt.xticks([])
plt.yticks([])
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Equillibrated Hard Disk System', fontsize = 16)
plt.savefig('simple_lattice_2D_equillibrated.png')

# %%
#averagine the g_r values after equillibration
#use position from previous code block
g_r_total_68 = []
#run through the monte carlo steps again    
for i in range(0, 5*10 **5 + 1):
    pos_68 = monte_carlo_2D(pos_68, 0.0043, L, diameter_68)
    if i % 1000 == 0:
        r_68, g_r_68 = pair_correlation_2D(pos_68,diameter_68, L, bins = 100)
        g_r_total_68.append(g_r_68)

x_68 = r_68
y_68 = np.mean(g_r_total_68, axis=0)    

#don't run any more code in this box as takes approx 20 seconds to run
#runs way faster with numba acceleration so is fine now
#now calculate for different values of area fraction (0.69, 0.70, 0.71, 0.72)
eta_69 = 0.69
diameter_69 = particle_diameter_2D(L, N, eta_69)
pos_0_69 = np.array(simple_lattice_2D(L,N))
pos_69 = pos_0_69.copy()
r_69, g_r_69 = pair_correlation_2D(pos_69,diameter_69, L)
g_r_total_69 = []
#run through the monte carlo steps again
for i in range(0, 4*10 **4 + 1):
    pos_69 = monte_carlo_2D(pos_69, 0.0043, L, diameter_68)
for i in range(0, 5*10 **5 + 1):
    pos_69 = monte_carlo_2D(pos_69, 0.0043, L, diameter_69)
    if i % 1000 == 0:
        r_69, g_r_69 = pair_correlation_2D(pos_69,diameter_69, L, bins = 100)
        g_r_total_69.append(g_r_69)
x_69 = r_69
y_69 = np.mean(g_r_total_69, axis=0)    

eta_70 = 0.70
diameter_70 = particle_diameter_2D(L, N, eta_70)
pos_0_70 = np.array(simple_lattice_2D(L,N))
pos_70 = pos_0_70.copy()
r_70, g_r_70 = pair_correlation_2D(pos_70,diameter_70, L)
g_r_total_70 = []
#run through the monte carlo steps again
for i in range(0, 1*10 **5 + 1):
    pos_70 = monte_carlo_2D(pos_70, 0.0043, L, diameter_70)
for i in range(0, 5*10 **5 + 1):
    pos_70 = monte_carlo_2D(pos_70, 0.0043, L, diameter_70)
    if i % 1000 == 0:
        r_70, g_r_70 = pair_correlation_2D(pos_70,diameter_70, L, bins = 100)
        g_r_total_70.append(g_r_70)
x_70 = r_70
y_70 = np.mean(g_r_total_70, axis=0)            

eta_71 = 0.71
diameter_71 = particle_diameter_2D(L, N, eta_71)
pos_0_71 = np.array(simple_lattice_2D(L,N))
pos_71 = pos_0_71.copy()
r_71, g_r_71 = pair_correlation_2D(pos_71,diameter_71, L)
g_r_total_71 = []
#run through the monte carlo steps again
for i in range(0, 1*10 **5 + 1):
    pos_71 = monte_carlo_2D(pos_71, 0.0043, L, diameter_71)
for i in range(0, 5*10 **5 + 1):                    
    pos_71 = monte_carlo_2D(pos_71, 0.0043, L, diameter_71)
    if i % 1000 == 0:
        r_71, g_r_71 = pair_correlation_2D(pos_71,diameter_71, L, bins = 100)
        g_r_total_71.append(g_r_71)
x_71 = r_71
y_71 = np.mean(g_r_total_71, axis=0)    

eta = 0.72
diameter_72 = particle_diameter_2D(L, N, eta)
pos_0_72 = np.array(simple_lattice_2D(L,N))
pos_72 = pos_0_72.copy()
r_72, g_r_72 = pair_correlation_2D(pos_72,diameter_72, L)
g_r_total_72 = []
#run through the monte carlo steps again
for i in range(0, 1*10 **5 + 1):
    pos_72 = monte_carlo_2D(pos_72, 0.0043, L, diameter_72)
for i in range(0, 5*10 **5 + 1):                    
    pos_72 = monte_carlo_2D(pos_72, 0.0043, L, diameter_72)
    if i % 1000 == 0:
        r_72, g_r_72 = pair_correlation_2D(pos_72,diameter_72, L, bins = 100)
        g_r_total_72.append(g_r_72)
x_72 = r_72
y_72 = np.mean(g_r_total_72, axis=0)

# %%
#make a pretty graph for 2D average g(r)
#calculate some errors too

g_err_68 = np.std(g_r_total_68, axis = 0) / np.sqrt(len(g_r_total_68))
x_err  = (L/2) / 200 # bin width / 2
g_err_69 = np.std(g_r_total_69, axis = 0) / np.sqrt(len(g_r_total_69))
g_err_70 = np.std(g_r_total_70, axis = 0) / np.sqrt(len(g_r_total_70))
g_err_71 = np.std(g_r_total_71, axis = 0) / np.sqrt(len(g_r_total_71))
g_err_72 = np.std(g_r_total_72, axis = 0) / np.sqrt(len(g_r_total_72))
#could try to find a model to fit - might be a decaying exponential? / don't know how to do this though

plt.figure()
plt.plot(x_68, y_68, color = 'black', linewidth = 0.5, label = 'Area Fraction = 0.68')
#plt.errorbar(x_68, y_68, yerr= g_err_68, xerr = x_err, fmt = 'o',color = 'blue', ecolor = 'navy', capsize = 2, markersize = 1, label = 'area fraction = 0.68')
#plt.errorbar(x_69, y_69, yerr= g_err_69, xerr = x_err, fmt = 'o',color = 'orange', ecolor = 'red', capsize = 2, markersize = 1, label = 'area fraction = 0.69')
#plt.errorbar(x_70, y_70, xerr = x_err, yerr = g_err_70, fmt = 'o',color = 'green', ecolor = 'darkgreen', capsize = 2, markersize = 1, label = 'area fraction = 0.70')
#plt.errorbar(x_71, y_71, xerr = x_err, yerr = g_err_71, fmt = 'o',color = 'red', ecolor = 'darkred', capsize = 2, markersize = 1, label = 'area fraction = 0.71')
#plt.errorbar(x_72, y_72, xerr = x_err, yerr = g_err_72, fmt = 'o',color = 'purple', ecolor = 'indigo', capsize = 2, markersize = 1, label = 'area fraction = 0.72')
#plt.plot(x_69, y_69, color = '', linewidth = 0.5, label = 'area fraction = 0.69')
plt.plot(x_70, y_70, color = 'green', linewidth = 0.5, label = 'Area Fraction = 0.70')
#plt.plot(x_71, y_71, color = 'red', linewidth = 0.5, label = 'area fraction = 0.71')
plt.plot(x_72, y_72, color = 'purple', linewidth = 0.5, label = 'Area Fraction = 0.72')
plt.xlabel('r / $\sigma$')
plt.ylabel('g(r)')
plt.legend()
plt.savefig('average_g(r).png')
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\s'
# <>:23: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_28206/2989302950.py:23: SyntaxWarning: invalid escape sequence '\s'
#   plt.xlabel('r / $\sigma$')

# %%
#extend the functions to 3D
#define the monte carlo function for stepwise in 3D - still using the hard sphere model so no overlaps
def monte_carlo_3D(positions, displacement, L, diameter):
    N = len(positions)
    
    # Pick a random particle
    particle = random.randint(0, N - 1)
    
    # Copy positions for trial move
    new_positions = positions.copy()
    
    # find 2 random angles for movement in 3D
    cos_theta = np.random.uniform(-1, 1)
    theta = np.arccos(cos_theta)
    phi = random.uniform(0, 2 * np.pi)
    x_change = displacement * np.sin(theta) * np.cos(phi)
    y_change = displacement * np.sin(theta) * np.sin(phi)
    z_change = displacement * cos_theta
    new_positions[particle, 0] += x_change
    new_positions[particle, 1] += y_change
    new_positions[particle, 2] += z_change
    # Apply periodic boundary conditions
    new_positions[particle] %= L
    # Compute distances from the moved particle to all others
    diffs = new_positions - new_positions[particle]         # shape (N, 3)
    # Minimum image convention for periodic boundaries
    diffs = diffs - L * np.round(diffs / L)
    distances = (diffs**2).sum(axis=1)**0.5
    distances[particle] = np.inf  # ignore self-distance    
    # Check overlap
    if np.any(distances < diameter):
        return positions  # reject move
    else:
        return new_positions  # accept move
    
#define the pair correlation function for 3D
@njit
def pair_correlation_3D(positions, diameter, L, bins=100):
    N = len(positions) # no.of particles
    hist = np.zeros(bins, dtype=float) # create histogram array for each bin
    delta_r = (L / 2) / bins  # bin width
    
    for i in range(N):
        for j in range(i + 1, N):
            # Compute distance with minimum image convention
            diff = positions[i] - positions[j]
            diff = diff - L * np.round(diff / L)
            distance = (diff[0]**2 + diff[1]**2 + diff[2]**2)**0.5
            
            # Determine which bin this distance falls into
            bin_index = int(distance / delta_r)
            if bin_index < bins:
                hist[bin_index] += 1  # count each pair once
            
    r = ((np.arange(bins) + 0.5) * delta_r) / diameter # midpoint of each bin for average value of r 
    volume_density = N / (L**3)
    n_ideal = 4 * np.pi * r**2 * delta_r * volume_density * N # ideal gas distribution

    g_r = 10 * hist / n_ideal
    return r, g_r

def generate_fcc(L, nx, ny=None, nz=None):
    """
    Generate an FCC lattice inside a cubic box L.
    nx,ny,nz = number of conventional FCC cells per axis (integers).
    Returns positions array with shape (4*nx*ny*nz, 3).
    """
    if ny is None: ny = nx
    if nz is None: nz = nx
    a = L / nx  # lattice constant such that nx cells fill the box
    # conventional FCC basis (in units of a)
    basis = np.array([
        [0.0, 0.0, 0.0],
        [0.5, 0.5, 0.0],
        [0.5, 0.0, 0.5],
        [0.0, 0.5, 0.5]
    ])
    positions = []
    for i in range(nx):
        for j in range(ny):
            for k in range(nz):
                origin = np.array([i, j, k], dtype=float) * a
                for b in basis:
                    positions.append(origin + b * a)
    return np.array(positions, dtype=float)

# Example: make 10x10x10 conventional FCC cells in box L
L = 1.0
nx = 10
pos = generate_fcc(L, nx)  # gives 4 * 10^3 = 4000 particles

# %%
#need to test to find when approx 25%-50% acceptance rate for 3D
L = 1
vol_fraction_3D = 0.58
d = particle_diameter_3D(L, 864, vol_fraction_3D)
pos_3D = np.array(generate_fcc(L, 6), dtype=float)
acceptance_count_3D  = 0 
for i in range(0,1000):
    pos_new_3D = monte_carlo_3D(pos_3D, 0.01,L, d)
    if pos_new_3D is pos_3D:
        pass #move rejected
    else:
        acceptance_count_3D += 1 #move accepted
        pos_3D = pos_new_3D
print(acceptance_count_3D)
# Out:
# 392

# %%
#testing out the 3D pair correlation function
#lols chatgpt thought this would take 30-60 minutes with just numpy
#tr with fcc cubic as initial structure sine couldnt go above 0.5 vol fraction with simple cubic

L = 1
N = 864
positions = np.array(generate_fcc(L, 6), dtype=float)

vol_fraction = 0.5
d_50 = particle_diameter_3D(L, N, vol_fraction)
pos_3D_50 = positions.copy()
r_3D, g_r_3D_50 = pair_correlation_3D(positions, d_50, L, bins=100)
g_r_3D_50 = []
#equillibration run
for i in range(0, 7*10 **5 + 1):
    pos_3D_50 = monte_carlo_3D(pos_3D_50, 0.01 , L, d_50)
    if i % 10000 == 0:
        r_3D_new, g_r_new_3D = pair_correlation_3D(pos_3D_50,d_50, L, bins = 100)
        g_r_3D_50.append(g_r_new_3D)
x_coords_3D = r_3D
y_coords_3D_50 = np.mean(g_r_3D_50, axis=0)
plt.figure()
plt.plot(x_coords_3D, y_coords_3D_50)
plt.savefig('equillibration_3D.png')

#continue from equillibration to get average g(r)
g_r_3D_50 = []
#run through the monte carlo steps again
for i in range(0, 5*10 **5 + 1):
    pos_3D_50 = monte_carlo_3D(pos_3D_50, 0.01, L, d_50)
    if i % 1000 == 0:
        r_3D_new, g_r_new_3D = pair_correlation_3D(pos_3D_50, d_50, L, bins = 100)
        g_r_3D_50.append(g_r_new_3D)
y_coords_3D_50 = np.mean(g_r_3D_50, axis=0)

# %%
#complete g(r) function for different volume fractions in 3D
vol_frac_55 = 0.55
d_55 = particle_diameter_3D(L, N, vol_frac_55)
pos_3D_55 = positions.copy()
r_3D, g_r_3D_55 = pair_correlation_3D(positions, d_55, L, bins=100)
g_r_3D_55 = []
#equillibration run
for i in range(0, 7*10 **5 + 1):
    pos_3D_55 = monte_carlo_3D(pos_3D_55, 0.01 , L, d_55)
    if i % 10000 == 0:
        r_3D_new, g_r_new_3D = pair_correlation_3D(pos_3D_55,d_55, L, bins = 100)
        g_r_3D_55.append(g_r_new_3D)

#continue from equillibration to get average g(r)
g_r_3D_55 = []
#run through the monte carlo steps again
for i in range(0, 5*10 **5 + 1):
    pos_3D_55 = monte_carlo_3D(pos_3D_55, 0.01, L, d_55)
    if i % 1000 == 0:
        r_3D_new, g_r_new_3D = pair_correlation_3D(pos_3D_55, d_55, L, bins = 100)
        g_r_3D_55.append(g_r_new_3D)
y_coords_3D_55 = np.mean(g_r_3D_55, axis=0)


vol_fraction = 0.58
d_58 = particle_diameter_3D(L, N, vol_fraction)
pos_3D_58 = positions.copy()
r_3D, g_r_3D_58 = pair_correlation_3D(positions, d_58, L, bins=100)
g_r_3D_58 = []
#equillibration run
for i in range(0, 7*10 **5 + 1):
    pos_3D_58 = monte_carlo_3D(pos_3D_58, 0.01, L, d_58)
    if i % 10000 == 0:
        r_3D_new, g_r_new_3D = pair_correlation_3D(pos_3D_58,d_58, L, bins = 100)
        g_r_3D_58.append(g_r_new_3D)

#continue from equillibration to get average g(r)
g_r_3D_58 = []
#run through the monte carlo steps again
for i in range(0, 5*10 **5 + 1):
    pos_3D_58 = monte_carlo_3D(pos_3D_58, 0.01, L, d_58)
    if i % 1000 == 0:
        r_3D_new, g_r_new_3D = pair_correlation_3D(pos_3D_58, d_58, L, bins = 100)
        g_r_3D_58.append(g_r_new_3D)
y_coords_3D_58 = np.mean(g_r_3D_58, axis=0)

# %%
plt.figure()
plt.plot(x_coords_3D, y_coords_3D_50, label = 'vol frac = 0.50')
plt.plot(x_coords_3D, y_coords_3D_55, label = 'vol frac = 0.55')
plt.plot(x_coords_3D, y_coords_3D_58, label = 'vol frac = 0.58')
plt.xlabel('r / $\sigma$')
plt.ylabel('g(r)')
plt.legend()
plt.savefig('average_g(r)_3D.png')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_28206/4173109073.py:5: SyntaxWarning: invalid escape sequence '\s'
#   plt.xlabel('r / $\sigma$')

# %%
#plot one figure with two axis to have 2D and 3D g(r) on same graph
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec



fig = plt.figure(figsize=(8, 6))

# Create two stacked axes with no vertical spacing
gs = gridspec.GridSpec(2, 1, height_ratios=[1, 1], hspace=0)

# -------------------------
# TOP MAIN AXIS
# -------------------------
ax_top = fig.add_subplot(gs[0])
ax_top.plot(x_68, y_68, color = 'red', linewidth = 0.6, label = 'Area Fraction = 0.68')
ax_top.plot(x_72, y_72, color = 'blueviolet', linewidth = 0.6, label = 'Area Fraction = 0.72')
ax_top.legend(loc='upper right')
ax_top.set_xticks([0,1,2,3,4,5])
ax_top.set_yticks([0,0.1,0.2])
ax_top.set_xlim(0,5)
ax_top.set_ylim(0,0.28)
ax_top.set_ylabel("g(r) - 2D ", fontsize=14)

# -------------------------
# INSET AXIS (ZOOM VIEW)
# -------------------------
ax_inset = inset_axes(ax_top, width="30%", height="40%", loc="upper center")

# zoom region
xmin, xmax = 1.5, 2.1
ymin, ymax = 0, 0.1
ax_inset.set_xlim(xmin, xmax)
ax_inset.set_ylim(ymin, ymax)

ax_inset.plot(x_68,y_68, color = 'red', linewidth = 0.6)
ax_inset.plot(x_72, y_72, color = 'blueviolet', linewidth = 0.6)
ax_inset.set_xticks([])
ax_inset.set_yticks([])
# Draw bounding box and dashed connector lines
mark_inset(ax_top, ax_inset, loc1=2, loc2=4, fc="none", ec="black", linestyle="--", alpha = 0.5)

# -------------------------
# BOTTOM AXIS - 3D
# -------------------------
ax_bottom = fig.add_subplot(gs[1], sharex=ax_top)

ax_bottom.plot(x_coords_3D, y_coords_3D_50, color = 'navy', linewidth = 0.6, label = 'Volume Fraction = 0.50')
ax_bottom.plot(x_coords_3D, y_coords_3D_58, color = 'darkgreen', linewidth = 0.6, label = 'Volume Fraction = 0.58')

ax_bottom.set_xlabel("r / $\sigma$")
ax_bottom.set_ylabel("g(r) - 3D ")
ax_bottom.legend(loc='upper right')
ax_bottom.set_xticks([0,1,2,3,4,5])
ax_bottom.set_yticks([0,0.1,0.2,0.3])
ax_bottom.set_xlim(0,5)
ax_bottom.set_ylim(0,0.32)
#inset for bottom axis

ax_inset = inset_axes(ax_bottom, width="30%", height="40%", loc= 'upper center' )
xmin, xmax = 1.3, 2.0
ymin, ymax = 0, 0.1
ax_inset.set_xlim(xmin, xmax)
ax_inset.set_ylim(ymin, ymax)
ax_inset.set_xticks([])
ax_inset.set_yticks([])


ax_inset.plot(x_coords_3D, y_coords_3D_50, color = 'navy', linewidth = 0.6)
ax_inset.plot(x_coords_3D, y_coords_3D_58, color = 'darkgreen', linewidth = 0.6)

mark_inset(ax_bottom, ax_inset, loc1=2,loc2 = 4, fc="none", ec="black", linestyle="--", alpha = 0.5)
# Remove top axis x tick labels so they don't overlap
plt.setp(ax_top.get_xticklabels(), visible=False)
plt.show()

plt.savefig('2D_and_3D_g(r).png')
# Out:
# <>:53: SyntaxWarning: invalid escape sequence '\s'
# <>:53: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_28206/4263737930.py:53: SyntaxWarning: invalid escape sequence '\s'
#   ax_bottom.set_xlabel("r / $\sigma$")
# /tmp/ipykernel_28206/4263737930.py:77: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D 
x,y,z = zip(*pos_3D_58)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
ax.set_zlim(0,1)
plt.title('Equillibrated Hard Sphere System (Vol Fraction = 0.58)')
plt.savefig('simple_lattice_3D_equillibrated.png')

x1,y1,z1 = zip(*positions)
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(x1,y1,z1)
plt.savefig('FCC Lattice 3D.png')

# %%
#create function that works for 2 different sized particles in lattice 
#still spherical structure
#random allocation rather than initial lattice structure 
def two_particle_system_2D(L, N_total, particle_1_fraction, area_fraction, radius_scale_factor):
    n1 = int(N_total * particle_1_fraction)
    n2 = N_total - n1
    #calculate radius of each particle type 
    area_1 = area_fraction * (L**2) / (n1 + (radius_scale_factor**2) * n2)
    radius_1 = (area_1 / np.pi) ** 0.5
    radius_2 = radius_scale_factor * radius_1
    #generate random positions 
    #first list in positions is particle type 1, second list is particle type 2
    positions = [[], []]  # lists of [x, y]

    # ---- Insert type 1 particles ----
    while len(positions[0]) < n1:
        pos = np.array([random.uniform(0, L), random.uniform(0, L)])

        if len(positions[0]) > 0:
            diffs = np.array(positions[0]) - pos
            diffs -= L * np.round(diffs / L)
            dists = np.linalg.norm(diffs, axis=1)
            if not np.all(dists >= 2 * radius_1):
                continue

        positions[0].append(pos)

    # ---- Insert type 2 particles ----
    while len(positions[1]) < n2:
        pos = np.array([random.uniform(0, L), random.uniform(0, L)])

        d1 = np.array(positions[0]) - pos
        d1 -= L * np.round(d1 / L)
        if not np.all(np.linalg.norm(d1, axis=1) >= radius_1 + radius_2):
            continue

        if len(positions[1]) > 0:
           d2 = np.array(positions[1]) - pos
           d2 -= L * np.round(d2 / L)
           if not np.all(np.linalg.norm(d2, axis=1) >= 2 * radius_2):
               continue

        positions[1].append(pos)

    return np.array(positions[0]), np.array(positions[1]), radius_1, radius_2

# %%
#create plot to visualise two particle system
L = 1
N_total = 100
particle_1_fraction = 0.7
area_fraction = 0.4
radius_scale_factor = 0.7
positions = [[],[]] # output positions into single lits containing both particle types 
positions[0], positions[1], r1, r2 = two_particle_system_2D(L, N_total, particle_1_fraction, area_fraction, radius_scale_factor)


x1, y1 = zip(*positions[0])
x2, y2 = zip(*positions[1]) 
plt.figure()
plt.scatter(x1, y1, label = 'Particle Type 1', alpha = 0.5, s= 120)
plt.scatter(x2, y2, label = 'Particle Type 2', alpha = 0.5, s =  120*(0.7**2))
plt.xlim(0,L)
plt.ylim(0,L)
plt.savefig('two_particle_system_2D.png')

# %%
#alter the original monte carlo method to accept two different sized particles
def monte_carlo_two_particle_2D(pos1, pos2, d_max, L, r1, r2):
    N1 = len(pos1)
    N2 = len(pos2)
    N = N1 + N2
    pos1 = np.asarray(pos1)
    pos2 = np.asarray(pos2)
    positions = np.vstack((pos1, pos2))
    new_positions = positions.copy()
    # pick particle
    particle = random.randrange(N)
    #n will reduce the displacement randomly
    n = random.random()
    # trial displacement
    theta = random.uniform(0, 2*np.pi)
    x_displacement = d_max * np.cos(theta)*n
    y_displacement = d_max * np.sin(theta)*n
    
    # --------------------
    # Move particle of type 1
    # --------------------

    x_old, y_old = positions[particle]
    new_positions[particle,0] += x_displacement
    new_positions[particle,1] += y_displacement
    new_positions[particle] %=L
        # type-1 vs type-1
    diffs = new_positions - new_positions[particle]
    diffs = diffs - L * np.round(diffs / L)
    distances = np.linalg.norm(diffs,axis=1)
    distances[particle] = np.inf  # ignore self-distance

    if particle < N1:
        if np.any(distances[0:particle] < 2*r1) or np.any(distances[particle:N1] < 2*r1) or np.any(distances[N1:] < r1+r2):
            return pos1.copy(), pos2.copy() #reject move:
        else:
            return new_positions[0:N1], new_positions[N1:] #accept move
    else:
        if np.any(distances[0:N1]<r1+r2) or np.any(distances[N1:particle]<2*r2) or np.any(distances[particle:] <2*r2):
            return pos1.copy(), pos2.copy() #reject move
        else:      
            return new_positions[0:N1], new_positions[N1:] #accept move

# %%
#define two particle initial system in 3D 
def two_particle_system_3D(L, N_total, particle_1_fraction, vol_fraction, radius_scale_factor):
    n1 = int(N_total * particle_1_fraction)
    n2 = N_total - n1
    #calculate radius of each particle type
    vol_1 = vol_fraction * (L**3) / (n1 + (radius_scale_factor**3) * n2)
    r_1 = ( (3/4) * (vol_1 / np.pi) ) ** (1/3)
    r_2 = radius_scale_factor * r_1
    #generate random positions
    positions = [[],[]] # empty initial positions lists for x,y,z coordinates
    while len(positions[0]) < n1:
        pos = np.array([random.uniform(0, L), random.uniform(0, L), random.uniform(0,L)])

        if len(positions[0]) > 0:
            diffs = np.array(positions[0]) - pos
            dists = np.linalg.norm(diffs, axis=1)
            if not np.all(dists >= 2 * r_1):
                continue
 
        positions[0].append(pos)
    while len(positions[1]) < n2:
        pos = np.array([random.uniform(0, L), random.uniform(0, L), random.uniform(0,L)])

        if len(positions[0]) > 0:
            d1 = np.linalg.norm(np.array(positions[0]) - pos, axis=1)
            if not np.all(d1 >= r_1 + r_2):
                continue

        if len(positions[1]) > 0:
            d2 = np.linalg.norm(np.array(positions[1]) - pos, axis=1)
            if not np.all(d2 >= 2 * r_2):
                continue

        positions[1].append(pos)

    return np.array(positions[0]), np.array(positions[1]), r_1, r_2

# %%
#try monte carlo run for 2 particle 2D system - think the original pair correlation function should work
#use the results from previous code block for initial positions
L=1 
N_total = 100
particle_1_fraction = 0.7
area_fraction = 0.55
radius_scale_factor = 0.7
positions = [[],[]]
positions[0], positions[1], r1, r2 = two_particle_system_2D(L, N_total, particle_1_fraction, area_fraction, radius_scale_factor)

#find monte carlo step size for reasonable acceptance rate 
acceptance_count = 0
for i in range(0,1000):
    pos1_new, pos2_new = monte_carlo_two_particle_2D(positions[0], positions[1], 0.02, L, r1, r2)
    if np.array_equal(pos1_new, positions[0]) and np.array_equal(pos2_new, positions[1]):
        pass #move rejected
    else:
        acceptance_count += 1 #move accepted
        positions[0] = pos1_new
        positions[1] = pos2_new
print(acceptance_count)
# Out:
# 617

# %%
#after acceptance count is checked, run monte carlo to equillibrate 
positions = [[],[]]
positions[0], positions[1], r1, r2 = two_particle_system_2D(L, N_total, particle_1_fraction, area_fraction, radius_scale_factor)
#equillibration run
for i in range(0, 8*10 **5 + 1):
    positions[0], positions[1] = monte_carlo_two_particle_2D(np.array(positions[0]),np.array(positions[1]), 0.02, L, r1, r2)

# %%
#monte carlo equillibrated so start with pair correlation function calculation for two particle system
#total pair correlation function and also pair correlation for each particle type separately
positions_2D = [positions[0].copy(), positions[1].copy()]

d1 = 2 * r1
d2 = 2 * r2
n1 = int(N_total * particle_1_fraction)
n2 = N_total - n1
average_diameter = (n1*d1 + n2*d2) / N_total

g_r_total_av = []
g_r_total_1 = []
g_r_total_2 = []

for step in range(5*10**4 + 1):

    positions_2D[0], positions_2D[1] = monte_carlo_two_particle_2D(np.array(positions_2D[0]), np.array(positions_2D[1]), 0.02, L, r1, r2)

    if step % 1000 == 0:
        # TOTAL g(r)
        positions_total = np.vstack((positions_2D[0], positions_2D[1]))
        r_total, g_r_total = pair_correlation_2D(positions_total, average_diameter, L, bins=95)
        g_r_total_av.append(g_r_total)

        # TYPE 1
        r_1, g_r_1 = pair_correlation_2D(positions_2D[0], d1, L, bins=95)
        g_r_total_1.append(g_r_1)

        # TYPE 2
        r_2, g_r_2 = pair_correlation_2D(positions_2D[1], d2, L, bins=95)
        g_r_total_2.append(g_r_2)

# %%
#plot graph of the pair correlation functions
x_1_2D = r_1
x_2_2D = r_2
x_total_2D = r_total
y_1_2D = np.mean(g_r_total_1, axis=0)
y_2_2D = np.mean(g_r_total_2, axis=0)
y_total_2D = np.mean(g_r_total_av, axis=0)

plt.figure()
plt.plot(x_total_2D, y_total_2D, color = 'black', linewidth = 0.6, label = 'Total g(r)')
plt.plot(x_1_2D, y_1_2D, color = 'blue', linewidth = 0.6, label = 'Particle Type 1 g(r)')
plt.plot(x_2_2D, y_2_2D, color = 'red', linewidth = 0.6, label = 'Particle Type 2 g(r)')
plt.legend()
plt.xlabel('r / $\sigma$')
plt.ylabel('g(r)')
plt.savefig('two_particle_g(r)_2D.png')
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_28206/254346491.py:14: SyntaxWarning: invalid escape sequence '\s'
#   plt.xlabel('r / $\sigma$')

# %%
x1, y1 = zip(*positions_2D[0])
x2, y2 = zip(*positions_2D[1])
plt.figure()
plt.scatter(x1, y1, label = 'Particle Type 1', alpha = 0.5, s = 550)
plt.scatter(x2, y2, label = 'Particle Type 2', alpha = 0.5, s =  550*(radius_scale_factor**2))
plt.xlim(0,L)
plt.ylim(0,L)
plt.title('Equillibrated Two Particle System (Area Fraction = 0.55)')
plt.savefig('two_particle_system_2D_equillibrated.png')
plt.legend()

# %%
#change shape of particle for phospholipid element
def phospholipid_water_2D(L, N_total,water_fraction, head_radius_ratio,c_ratio, n_c_per_chain, area_fraction):
    #water_fraction is fraction of total particles that are water
    #head_radius_ratio is ratio of water particle radius to phospholipid head radius
    #c_ratio is ratio of water particle radius to carbon atom diameter in tail
    #area_fraction is total area fraction of all particles in system
    n_water = int(N_total * water_fraction)
    n_phospholipid = N_total - n_water
    n_head = n_phospholipid
    n_tail = n_phospholipid
    area_water = area_fraction * (L**2) / (n_water + head_radius_ratio**2 * n_head + (c_ratio**2 * n_c_per_chain * n_tail))
    r_water = (area_water / np.pi) ** 0.5
    r_head = head_radius_ratio * r_water
    r_carbon = c_ratio * r_water
    positions = [[],[],[]] 
    max_tries = 100000
    tries = 0
    # lists for heads, tails, water [list for tails will be a list with position of each carbon atom in tail - 2 lists per phosphate head]
    # ---- Insert phospholipids first ----
    # Insert heads at same time as tail
    while len(positions[0]) < n_head and tries < max_tries:
        tries += 1
        if tries % 1000 ==0:
            print(f'Tries = {tries}, Phospholipids placed = {len(positions[0])}/{n_head}')
        tail_positions = [] # xcoords and ycoords list for carbon atoms in tails
        head_pos = np.array([random.uniform(0, L), random.uniform(0, L)])
        angle = random.uniform(0, 2*np.pi)
        tail_x = (head_pos[0] + np.cos(angle)*(r_head + r_carbon))%L
        tail_y = (head_pos[1] + np.sin(angle)*(r_head + r_carbon))%L

        tail_positions.append(np.array([tail_x, tail_y]))
        while len(tail_positions) < n_c_per_chain:
            angle += np.random.normal(0, np.pi/16) # add some flexibility to tail correlates to real flexibility of phospholipid tails
            tail_x = (tail_positions[-1][0] + 2 * np.cos(angle)*r_carbon)%L
            tail_y = (tail_positions[-1][1] + 2* np.sin(angle)*r_carbon)%L
            tail_positions.append(np.array([tail_x, tail_y])) # tail positions is list of n carbon atoms lists with x and y coords
             #periodic boundary conditions
        #check for overlaps with existing particles
        if len(positions[0]) > 0:
            diffs_heads = np.array(positions[0]) - head_pos # check head - head overlap
            diffs_heads -= L * np.round(diffs_heads / L)
            dists_heads = np.linalg.norm(diffs_heads, axis=1)
            if not np.all(dists_heads >= 2 * r_head):
                continue
            #check head-tail overlaps
            overlap = False
            for existing_tail in positions[1]:
                diffs = np.array(existing_tail) - head_pos
                diffs -= L * np.round(diffs / L)
                if np.any(np.linalg.norm(diffs, axis=1) < (r_head + r_carbon)):
                    overlap = True
                    break
            if overlap:
                continue
            #check tail - head overlaps
            diffs_tail_head_total = []
            for tail_pos in tail_positions:
                diffs_tail_head = np.array(positions[0]) - np.array(tail_pos)
                diffs_tail_head -=L * np.round(diffs_tail_head / L)
                dists_tail_head = list(np.linalg.norm(diffs_tail_head, axis=1))
                diffs_tail_head_total.append(dists_tail_head)
            if not np.all(np.array(diffs_tail_head_total) >= r_head + r_carbon):
                continue
            #check tail - tail overlaps
            
            overlap = False
            for tail_pos in tail_positions:
                for existing_tail in positions[1]:
                    diffs = np.array(existing_tail) - tail_pos
                    diffs -= L * np.round(diffs / L)
                    if np.any(np.linalg.norm(diffs, axis=1) < 2 * r_carbon):
                        overlap = True
                        break
                if overlap:
                    break

            if overlap:
                continue
        positions[0].append(head_pos)
        positions[1].append(tail_positions)
    tries = 0
    #Now time to insert the water molecules
    while len(positions[2]) < n_water and tries < max_tries:
        water_pos = np.array([random.uniform(0, L), random.uniform(0, L)])
        tries += 1
        if tries % 1000 == 0:
            print(f'Tries for water = {tries}, Water placed = {len(positions[2])}/{n_water}')
        
        overlap = False
        #check for overlaps with all phospholipids
        diffs_water_head = np.array(positions[0]) - water_pos
        diffs_water_head -= L * np.round(diffs_water_head / L)
        dists_water_head = np.linalg.norm(diffs_water_head, axis=1)
        if not np.all(dists_water_head >= r_head + r_water):
            continue
        diffs_water_tail_total = []
        for existing_tail in positions[1]:
            diffs = np.array(existing_tail) - water_pos
            diffs -= L * np.round(diffs / L)
            if np.any(np.linalg.norm(diffs, axis=1) < (r_water + r_carbon)):
                overlap = True
                break
        if overlap:
            continue
        #check water - water overlaps
        if len(positions[2]) > 0:
            diffs_water_water = np.array(positions[2]) - water_pos
            diffs_water_water -= L * np.round(diffs_water_water / L)
            dists_water_water = np.linalg.norm(diffs_water_water, axis=1)
            if not np.all(dists_water_water >= 2 * r_water):
                continue
        positions[2].append(water_pos)
    
    
    return np.array(positions[0]), np.array(positions[1]), np.array(positions[2]), r_water, r_head, r_carbon

# %%
#trial placing a phospholipid system
L = 1
N_total = 1000
water_fraction = 0.95
head_radius_ratio = 1.5
c_ratio = 0.7
n_c_per_chain = 4
area_fraction = 0.4
positions_heads, positions_tails, positions_water, r_water, r_head, r_carbon = phospholipid_water_2D(L, N_total, water_fraction, head_radius_ratio, c_ratio, n_c_per_chain, area_fraction)
#plot the phospholipid water system

x_heads, y_heads = zip(*positions_heads)
x_tails = []
y_tails = []
for tail in positions_tails:
    x_tail, y_tail = zip(*tail)
    x_tails.extend(x_tail)
    y_tails.extend(y_tail)
    
plt.figure()
from matplotlib.patches import Circle

fig, ax = plt.subplots()
ax.set_aspect('equal')

for h in positions_heads:
    ax.add_patch(Circle(h, r_head, fill=True, fc = 'red', alpha =1))

for tail in positions_tails:
    for t in tail:
        ax.add_patch(Circle(t, r_carbon, fill=True, fc = 'orange'))
for w in positions_water:
    ax.add_patch(Circle(w, r_water, fill=True, fc = 'blue'))

ax.set_xlim(0, L)
ax.set_ylim(0, L) #this does work for no overlaps on graph
plt.savefig('phospholipid_trial_2D') 
#should have working model for phospholipid and water placing in the original structure
# flatten all particles
# Out:
# Tries for water = 1000, Water placed = 496/950
# Tries for water = 2000, Water placed = 687/950
# Tries for water = 3000, Water placed = 799/950
# Tries for water = 4000, Water placed = 890/950

# %%
#time to define the metropolis algorithm then the monte carlo algorithm for the phospholipid system 
#check for overlaps in monte carlo - metropolis algorithm will be used to accept or reject monte carlo steps based on change to energy as hard
#sphere model will always reject with any overlaps
#need to define n_c_per_chain before running this code

import math
from numba import njit

@njit
def monte_carlo_wp_2D(positions_heads, positions_tails, positions_water,
                      d_max, rotation_max, L, r_water, r_head, r_carbon,
                      n_c_per_chain):

    N_heads = positions_heads.shape[0]
    N_water = positions_water.shape[0]
    
    particle = int(np.random.rand() * (N_heads + N_water))

    displacement = d_max * np.random.normal()
    angle = 2.0 * math.pi * np.random.rand()
    x_displacement = displacement * np.cos(angle)
    y_displacement = displacement * np.sin(angle)

    rotation_angle = 2.0 * math.pi * np.random.rand()
    vec = positions_tails[particle, 0] - positions_heads[particle]
    initial_angle = np.arctan2(vec[1], vec[0])
    # ==========================================================
    # PHOSPHOLIPID MOVE
    # ==========================================================
    if particle < N_heads:

        moved_index = particle
        moved_type = 0

        pos_head = positions_heads[particle]

        # ---------- CHANGED: use NumPy array ----------
        new_pos_head = np.array([
            (pos_head[0] + x_displacement) % L,
            (pos_head[1] + y_displacement) % L
        ])

        # ---------- CHANGED: preallocate tail ----------
        new_tail_positions = np.empty((n_c_per_chain, 2))
        #need to find an initial angle so no preferential direction 

        new_tail_positions[0, 0] = (new_pos_head[0] + np.cos(rotation_angle) * (r_head + r_carbon)) % L
        new_tail_positions[0, 1] = (new_pos_head[1] + np.sin(rotation_angle) * (r_head + r_carbon)) % L

        for i in range(1, n_c_per_chain):

            prev_x = new_tail_positions[i-1, 0]
            prev_y = new_tail_positions[i-1, 1]

            if i == 1:
                ref_x, ref_y = new_pos_head
            else:
                ref_x = new_tail_positions[i-2, 0]
                ref_y = new_tail_positions[i-2, 1]

            initial_angle = math.atan2(prev_y - ref_y, prev_x - ref_x)
            new_angle = initial_angle + (rotation_max / 4.0) * np.random.normal()

            new_tail_positions[i, 0] = (prev_x + 2 * r_carbon * math.cos(new_angle)) % L
            new_tail_positions[i, 1] = (prev_y + 2 * r_carbon * math.sin(new_angle)) % L

        # ---------- overlap checks ----------

        # head–water
        for i in range(N_water):
            dx = positions_water[i, 0] - new_pos_head[0]
            dy = positions_water[i, 1] - new_pos_head[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx*dx + dy*dy < (r_head + r_water)**2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # head–head
        for j in range(N_heads):
            if j == particle:
                continue
            dx = positions_heads[j, 0] - new_pos_head[0]
            dy = positions_heads[j, 1] - new_pos_head[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx*dx + dy*dy < (2 * r_head)**2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # head–tail
        for j in range(N_heads):
            if j == particle:
                continue
            for k in range(n_c_per_chain):
                dx = positions_tails[j, k, 0] - new_pos_head[0]
                dy = positions_tails[j, k, 1] - new_pos_head[1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx*dx + dy*dy < (r_head + r_carbon)**2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # tail–water
        for k in range(n_c_per_chain):
            for i in range(N_water):
                dx = positions_water[i, 0] - new_tail_positions[k, 0]
                dy = positions_water[i, 1] - new_tail_positions[k, 1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx*dx + dy*dy < (r_water + r_carbon)**2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        # tail–tail
        for j in range(N_heads):
            if j == particle:
                continue
            for k in range(n_c_per_chain):
                for m in range(n_c_per_chain):
                    dx = positions_tails[j, m, 0] - new_tail_positions[k, 0]
                    dy = positions_tails[j, m, 1] - new_tail_positions[k, 1]
                    dx -= L * round(dx / L)
                    dy -= L * round(dy / L)
                    if dx*dx + dy*dy < (2 * r_carbon)**2:
                        return positions_heads, positions_tails, positions_water, False, moved_index, moved_type
        #tail - heads
        for j in range(N_heads):
            for k in range(n_c_per_chain):
                dx = positions_heads[j, 0] - new_tail_positions[k, 0]
                dy = positions_heads[j, 1] - new_tail_positions[k, 1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx*dx + dy*dy < (r_head + r_carbon)**2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type
        # ---------- accept ----------
        positions_heads[particle] = new_pos_head
        positions_tails[particle] = new_tail_positions

        return positions_heads, positions_tails, positions_water, True, moved_index, moved_type

    # ==========================================================
    # WATER MOVE (unchanged logic, array-safe)
    # ==========================================================
    else:
        particle -= N_heads
        moved_index = particle
        moved_type = 1

        pos_water = positions_water[particle]

        new_pos_water = np.array([
            (pos_water[0] + x_displacement) % L,
            (pos_water[1] + y_displacement) % L
        ])

        for i in range(N_water):
            if i == particle:
                continue
            dx = positions_water[i, 0] - new_pos_water[0]
            dy = positions_water[i, 1] - new_pos_water[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx*dx + dy*dy < (2 * r_water)**2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        for j in range(N_heads):
            dx = positions_heads[j, 0] - new_pos_water[0]
            dy = positions_heads[j, 1] - new_pos_water[1]
            dx -= L * round(dx / L)
            dy -= L * round(dy / L)
            if dx*dx + dy*dy < (r_water + r_head)**2:
                return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

            for k in range(n_c_per_chain):
                dx = positions_tails[j, k, 0] - new_pos_water[0]
                dy = positions_tails[j, k, 1] - new_pos_water[1]
                dx -= L * round(dx / L)
                dy -= L * round(dy / L)
                if dx*dx + dy*dy < (r_water + r_carbon)**2:
                    return positions_heads, positions_tails, positions_water, False, moved_index, moved_type

        positions_water[particle] = new_pos_water
        return positions_heads, positions_tails, positions_water, True, moved_index, moved_type
count = 0
for i in range(1000):
    positions_heads, positions_tails, positions_water, accepted, moved_index, moved_type = monte_carlo_wp_2D(
        positions_heads, positions_tails, positions_water,
        d_max=0.02, rotation_max=np.pi/8, L=L,
        r_water=r_water, r_head=r_head, r_carbon=r_carbon,
        n_c_per_chain=n_c_per_chain
    )
    if accepted:
        count += 1
print(f"Total accepted moves: {count}")
# Out:
# Total accepted moves: 351

# %%
#time to define the metropolis algorithm for the phospholipid system 
#only want to consider nearest neighbour interactions for energy calculations
#only need to consider the energy change ffor the metropolis algorithm 

@njit
def metropolis_pw_2D(positions_heads, positions_tails, positions_water, L, r_water, r_head, r_carbon, epsilon, Temperature, d_max, n_c_per_chain):
    """
    Metropolis algorithm for phospholipid system in 2D.
    Only nearest-neighbour interactions are considered.
    Assumes positions are numpy arrays:
    positions_heads: (N_heads, 2)
    positions_tails: (N_heads, n_c_per_chain, 2)
    positions_water: (N_water, 2)
    """
    N_heads = positions_heads.shape[0]
    N_water = positions_water.shape[0]
    
    # Make copies for trial moves
    pos_heads = np.copy(positions_heads)
    pos_tails = np.copy(positions_tails)
    pos_water = np.copy(positions_water)

    # Perform MC move (already njit)
    new_heads, new_tails, new_water, accepted, moved_index, moved_type = monte_carlo_wp_2D(
        positions_heads, positions_tails, positions_water, d_max, np.pi/32, 
        L, r_water, r_head, r_carbon, n_c_per_chain
    )

    if not accepted:
        return positions_heads, positions_tails, positions_water, False, moved_type

    # Initialize energies
    initial_energy = 0.0
    final_energy = 0.0

    # --- Head particle moved ---
    if moved_type == 0:
        # Tail-water interactions
        for c in range(n_c_per_chain):
            tail_old = pos_tails[moved_index, c]
            tail_new = new_tails[moved_index, c]

            # New
            diffs_new = new_water - tail_new
            diffs_new -= L * np.round(diffs_new / L)
            dists_new = np.sqrt(diffs_new[:,0]**2 + diffs_new[:,1]**2)
            for i in range(dists_new.shape[0]):
                if dists_new[i] < 1.5 * (r_carbon + r_water):
                    final_energy += epsilon

            # Old
            diffs_old = pos_water - tail_old
            diffs_old -= L * np.round(diffs_old / L)
            dists_old = np.sqrt(diffs_old[:,0]**2 + diffs_old[:,1]**2)
            for i in range(dists_old.shape[0]):
                if dists_old[i] < 1.5 * (r_carbon + r_water):
                    initial_energy += epsilon

        # Tail-tail interactions
        for c in range(n_c_per_chain):
            tail_new = new_tails[moved_index, c]
            tail_old = pos_tails[moved_index, c]

            for j in range(N_heads):
                if j == moved_index:
                    continue
                for cc in range(n_c_per_chain):
                    # New
                    diff = new_tails[j, cc] - tail_new
                    diff -= L * np.round(diff / L)
                    dist = np.sqrt(diff[0]**2 + diff[1]**2)
                    if dist < 1.5 * (r_carbon + r_carbon):
                        final_energy -= epsilon
                    # Old
                    diff_old = pos_tails[j, cc] - tail_old
                    diff_old -= L * np.round(diff_old / L)
                    dist_old = np.sqrt(diff_old[0]**2 + diff_old[1]**2)
                    if dist_old < 1.5 * (r_carbon + r_carbon):
                        initial_energy -= epsilon
        #head - water interactions
        diffs_new = new_water - new_heads[moved_index]
        diffs_new -= L * np.round(diffs_new / L)
        dists_new = np.sqrt(diffs_new[:,0]**2 + diffs_new[:,1]**2)
        for i in range(dists_new.shape[0]):
            if dists_new[i] < 1.5 * (r_head + r_water):
                final_energy += epsilon
        diffs_old = pos_water - pos_heads[moved_index]
        diffs_old -= L * np.round(diffs_old / L)
        dists_old = np.sqrt(diffs_old[:,0]**2 + diffs_old[:,1]**2)
        for i in range(dists_old.shape[0]):
            if dists_old[i] < 1.5 * (r_head + r_water):
                initial_energy += epsilon
    # --- Water particle moved ---
    else:
        water_old = pos_water[moved_index]
        water_new = new_water[moved_index]

        # Water-water interactions
        for i in range(N_water):
            if i == moved_index:
                continue
            # New
            diff = new_water[i] - water_new
            diff -= L * np.round(diff / L)
            dist = np.sqrt(diff[0]**2 + diff[1]**2)
            if dist < 1.5 * (r_water + r_water):
                final_energy -= epsilon
            # Old
            diff_old = pos_water[i] - water_old
            diff_old -= L * np.round(diff_old / L)
            dist_old = np.sqrt(diff_old[0]**2 + diff_old[1]**2)
            if dist_old < 1.5 * (r_water + r_water):
                initial_energy -= epsilon

        # Water-tail interactions
        for i in range(N_heads):
            for c in range(n_c_per_chain):
                # New
                diff = new_tails[i, c] - water_new
                diff -= L * np.round(diff / L)
                dist = np.sqrt(diff[0]**2 + diff[1]**2)
                if dist < 1.5 * (r_carbon + r_water):
                    final_energy += epsilon
                # Old
                diff_old = pos_tails[i, c] - water_old
                diff_old -= L * np.round(diff_old / L)
                dist_old = np.sqrt(diff_old[0]**2 + diff_old[1]**2)
                if dist_old < 1.5 * (r_carbon + r_water):
                    initial_energy += epsilon

        #head - water interactions
        diffs_new = new_heads - water_new
        diffs_new -= L * np.round(diffs_new / L)
        dists_new = np.sqrt(diffs_new[:,0]**2 + diffs_new[:,1]**2)
        for i in range(dists_new.shape[0]):
            if dists_new[i] < 1.5 * (r_head + r_water):
                final_energy += epsilon
        diffs_old = pos_heads - water_old
        diffs_old -= L * np.round(diffs_old / L)
        dists_old = np.sqrt(diffs_old[:,0]**2 + diffs_old[:,1]**2)
        for i in range(dists_old.shape[0]):
            if dists_old[i] < 1.5 * (r_head + r_water):
                initial_energy += epsilon

    # Metropolis criterion
    delta_E = final_energy - initial_energy
    if delta_E < 0.0 or np.exp(-delta_E / (k_b * Temperature)) >= np.random.rand():
        return new_heads, new_tails, new_water, True, moved_type
    else:
        return pos_heads, pos_tails, pos_water, False, moved_type

# %%
#bug testing the metropolis algorithm for phospholipid system 
L = 1
N_total = 500
water_fraction = 0.8
head_radius_ratio = 1.1
c_ratio = 0.4
n_c_per_chain = 6 
area_fraction = 0.35
positions_heads, positions_tails, positions_water, r_water, r_head, r_carbon = phospholipid_water_2D(L, N_total, water_fraction, head_radius_ratio, c_ratio, n_c_per_chain, area_fraction)

t = 2 # ratio from the paper found for energy and temperature 
#t = k_b * T / epsilon
epsilon = 1
k_b = 1.4 * 10 ** -23
Temperature = t * epsilon / k_b
d_max = r_water / 10
count = 0
water_count = 0
head_count = 0
for i in range(1000):
    positions_heads, positions_tails, positions_water, accepted, moved_type = metropolis_pw_2D(positions_heads, positions_tails, positions_water, L, r_water, r_head, r_carbon, epsilon, Temperature, d_max, n_c_per_chain)
    if accepted:
        count += 1
        if moved_type ==1:
            water_count += 1
        else:
            head_count += 1
             
print(f'Acceptance count for metropolis algorithm = {count} out of 1000 moves')
print(f'Water count = {water_count}')
print(f'Head count = {head_count}')

plt.figure()
from matplotlib.patches import Circle

fig, ax = plt.subplots()
ax.set_aspect('equal')

for h in positions_heads:
    ax.add_patch(Circle(h, r_head, fill=True, fc = 'red', alpha =1))

for tail in positions_tails:
    for t in tail:
        ax.add_patch(Circle(t, r_carbon, fill=True, fc = 'orange'))
for w in positions_water:
    ax.add_patch(Circle(w, r_water, fill=True, fc = 'blue'))

ax.set_xlim(0, L)
ax.set_ylim(0, L) #this does work for no overlaps on graph
plt.savefig('trial_1.png')
plt.figure()
from matplotlib.patches import Circle
#seems to be working for the system
# Out:
# Tries for water = 1000, Water placed = 281/400
# Tries for water = 2000, Water placed = 372/400
# Acceptance count for metropolis algorithm = 719 out of 1000 moves
# Water count = 702
# Head count = 17

# %%
N_total = 1000
water_fraction = 0.8
area_fraction = 0.4
head_radius_ratio = 1.1
c_ratio = 0.4
n_c_per_chain = 6
d_max = r_water/3
positions_heads, positions_tails, positions_water, r_water, r_head, r_carbon = phospholipid_water_2D(L, N_total, water_fraction, head_radius_ratio, c_ratio, n_c_per_chain, area_fraction)
#trial run at higher number of moves
count = 0
for i in range(10000000):
    positions_heads, positions_tails, positions_water, accepted, moved_type = metropolis_pw_2D(positions_heads, positions_tails, positions_water, L, r_water, r_head, r_carbon, epsilon, Temperature, d_max, n_c_per_chain)
    if accepted:
        count += 1
    if i%1000 == 0:
        print(f'Move {i}, Accepted moves so far: {count}')
# Out:
# Tries for water = 1000, Water placed = 318/800
# Tries for water = 2000, Water placed = 478/800
# Tries for water = 3000, Water placed = 590/800
# Tries for water = 4000, Water placed = 661/800
# Tries for water = 5000, Water placed = 722/800
# Tries for water = 6000, Water placed = 768/800
# Move 0, Accepted moves so far: 1
# Move 1000, Accepted moves so far: 583
# Move 2000, Accepted moves so far: 1157
# Move 3000, Accepted moves so far: 1727
# Move 4000, Accepted moves so far: 2284
# Move 5000, Accepted moves so far: 2847
# Move 6000, Accepted moves so far: 3396
# Move 7000, Accepted moves so far: 3927
# Move 8000, Accepted moves so far: 4475
# Move 9000, Accepted moves so far: 5037
# Move 10000, Accepted moves so far: 5590
# Move 11000, Accepted moves so far: 6156
# Move 12000, Accepted moves so far: 6708
# Move 13000, Accepted moves so far: 7238
# Move 14000, Accepted moves so far: 7779
# Move 15000, Accepted moves so far: 8329
# Move 16000, Accepted moves so far: 8899
# Move 17000, Accepted moves so far: 9422
# Move 18000, Accepted moves so far: 9956
# Move 19000, Accepted moves so far: 10477
# Move 20000, Accepted moves so far: 11012
# Move 21000, Accepted moves so far: 11548
# Move 22000, Accepted moves so far: 12110
# Move 23000, Accepted moves so far: 12669
# Move 24000, Accepted moves so far: 13206
# Move 25000, Accepted moves so far: 13740
# Move 26000, Accepted moves so far: 14284
# Move 27000, Accepted moves so far: 14819
# Move 28000, Accepted moves so far: 15383
# Move 29000, Accepted moves so far: 15940
# Move 30000, Accepted moves so far: 16493
# Move 31000, Accepted moves so far: 17053
# Move 32000, Accepted moves so far: 17598
# Move 33000, Accepted moves so far: 18160
# Move 34000, Accepted moves so far: 18696
# Move 35000, Accepted moves so far: 19233
# Move 36000, Accepted moves so far: 19764
# Move 37000, Accepted moves so far: 20310
# Move 38000, Accepted moves so far: 20837
# Move 39000, Accepted moves so far: 21390
# Move 40000, Accepted moves so far: 21929
# Move 41000, Accepted moves so far: 22474
# Move 42000, Accepted moves so far: 23008
# Move 43000, Accepted moves so far: 23557
# Move 44000, Accepted moves so far: 24139
# Move 45000, Accepted moves so far: 24702
# Move 46000, Accepted moves so far: 25262
# Move 47000, Accepted moves so far: 25816
# Move 48000, Accepted moves so far: 26331
# Move 49000, Accepted moves so far: 26865
# Move 50000, Accepted moves so far: 27371
# Move 51000, Accepted moves so far: 27899
# Move 52000, Accepted moves so far: 28442
# Move 53000, Accepted moves so far: 28980
# Move 54000, Accepted moves so far: 29538
# Move 55000, Accepted moves so far: 30079
# Move 56000, Accepted moves so far: 30621
# Move 57000, Accepted moves so far: 31161
# Move 58000, Accepted moves so far: 31745
# Move 59000, Accepted moves so far: 32272
# Move 60000, Accepted moves so far: 32809
# Move 61000, Accepted moves so far: 33352
# Move 62000, Accepted moves so far: 33899
# Move 63000, Accepted moves so far: 34425
# Move 64000, Accepted moves so far: 34969
# Move 65000, Accepted moves so far: 35513
# Move 66000, Accepted moves so far: 36035
# Move 67000, Accepted moves so far: 36568
# Move 68000, Accepted moves so far: 37119
# Move 69000, Accepted moves so far: 37657
# Move 70000, Accepted moves so far: 38192
# Move 71000, Accepted moves so far: 38731
# Move 72000, Accepted moves so far: 39260
# Move 73000, Accepted moves so far: 39818
# Move 74000, Accepted moves so far: 40366
# Move 75000, Accepted moves so far: 40904
# Move 76000, Accepted moves so far: 41438
# Move 77000, Accepted moves so far: 41957
# Move 78000, Accepted moves so far: 42466
# Move 79000, Accepted moves so far: 43028
# Move 80000, Accepted moves so far: 43558
# Move 81000, Accepted moves so far: 44110
# Move 82000, Accepted moves so far: 44656
# Move 83000, Accepted moves so far: 45178
# Move 84000, Accepted moves so far: 45720
# Move 85000, Accepted moves so far: 46228
# Move 86000, Accepted moves so far: 46769
# Move 87000, Accepted moves so far: 47289
# Move 88000, Accepted moves so far: 47799
# Move 89000, Accepted moves so far: 48316
# Move 90000, Accepted moves so far: 48886
# Move 91000, Accepted moves so far: 49430
# Move 92000, Accepted moves so far: 49990
# Move 93000, Accepted moves so far: 50517
# Move 94000, Accepted moves so far: 51046
# Move 95000, Accepted moves so far: 51568
# Move 96000, Accepted moves so far: 52100
# Move 97000, Accepted moves so far: 52681
# Move 98000, Accepted moves so far: 53225
# Move 99000, Accepted moves so far: 53751
# Move 100000, Accepted moves so far: 54283
# Move 101000, Accepted moves so far: 54817
# Move 102000, Accepted moves so far: 55358
# Move 103000, Accepted moves so far: 55877
# Move 104000, Accepted moves so far: 56442
# Move 105000, Accepted moves so far: 56984
# Move 106000, Accepted moves so far: 57520
# Move 107000, Accepted moves so far: 58054
# Move 108000, Accepted moves so far: 58589
# Move 109000, Accepted moves so far: 59148
# Move 110000, Accepted moves so far: 59691
# Move 111000, Accepted moves so far: 60231
# Move 112000, Accepted moves so far: 60784
# Move 113000, Accepted moves so far: 61333
# Move 114000, Accepted moves so far: 61874
# Move 115000, Accepted moves so far: 62426
# Move 116000, Accepted moves so far: 62957
# Move 117000, Accepted moves so far: 63534
# Move 118000, Accepted moves so far: 64059
# Move 119000, Accepted moves so far: 64611
# Move 120000, Accepted moves so far: 65167
# Move 121000, Accepted moves so far: 65697
# Move 122000, Accepted moves so far: 66208
# Move 123000, Accepted moves so far: 66760
# Move 124000, Accepted moves so far: 67286
# Move 125000, Accepted moves so far: 67800
# Move 126000, Accepted moves so far: 68321
# Move 127000, Accepted moves so far: 68848
# Move 128000, Accepted moves so far: 69368
# Move 129000, Accepted moves so far: 69897
# Move 130000, Accepted moves so far: 70420
# Move 131000, Accepted moves so far: 70966
# Move 132000, Accepted moves so far: 71510
# Move 133000, Accepted moves so far: 72026
# Move 134000, Accepted moves so far: 72551
# Move 135000, Accepted moves so far: 73103
# Move 136000, Accepted moves so far: 73667
# Move 137000, Accepted moves so far: 74188
# Move 138000, Accepted moves so far: 74726
# Move 139000, Accepted moves so far: 75278
# Move 140000, Accepted moves so far: 75820
# Move 141000, Accepted moves so far: 76368
# Move 142000, Accepted moves so far: 76922
# Move 143000, Accepted moves so far: 77466
# Move 144000, Accepted moves so far: 77994
# Move 145000, Accepted moves so far: 78542
# Move 146000, Accepted moves so far: 79103
# Move 147000, Accepted moves so far: 79677
# Move 148000, Accepted moves so far: 80217
# Move 149000, Accepted moves so far: 80779
# Move 150000, Accepted moves so far: 81318
# Move 151000, Accepted moves so far: 81890
# Move 152000, Accepted moves so far: 82445
# Move 153000, Accepted moves so far: 82997
# Move 154000, Accepted moves so far: 83521
# Move 155000, Accepted moves so far: 84063
# Move 156000, Accepted moves so far: 84580
# Move 157000, Accepted moves so far: 85110
# Move 158000, Accepted moves so far: 85660
# Move 159000, Accepted moves so far: 86197
# Move 160000, Accepted moves so far: 86740
# Move 161000, Accepted moves so far: 87247
# Move 162000, Accepted moves so far: 87796
# Move 163000, Accepted moves so far: 88340
# Move 164000, Accepted moves so far: 88865
# Move 165000, Accepted moves so far: 89380
# Move 166000, Accepted moves so far: 89907
# Move 167000, Accepted moves so far: 90455
# Move 168000, Accepted moves so far: 90975
# Move 169000, Accepted moves so far: 91551
# Move 170000, Accepted moves so far: 92084
# Move 171000, Accepted moves so far: 92649
# Move 172000, Accepted moves so far: 93212
# Move 173000, Accepted moves so far: 93752
# Move 174000, Accepted moves so far: 94284
# Move 175000, Accepted moves so far: 94804
# Move 176000, Accepted moves so far: 95343
# Move 177000, Accepted moves so far: 95879
# Move 178000, Accepted moves so far: 96403
# Move 179000, Accepted moves so far: 96937
# Move 180000, Accepted moves so far: 97473
# Move 181000, Accepted moves so far: 98018
# Move 182000, Accepted moves so far: 98549
# Move 183000, Accepted moves so far: 99081
# Move 184000, Accepted moves so far: 99621
# Move 185000, Accepted moves so far: 100170
# Move 186000, Accepted moves so far: 100714
# Move 187000, Accepted moves so far: 101227
# Move 188000, Accepted moves so far: 101759
# Move 189000, Accepted moves so far: 102303
# Move 190000, Accepted moves so far: 102834
# Move 191000, Accepted moves so far: 103357
# Move 192000, Accepted moves so far: 103872
# Move 193000, Accepted moves so far: 104414
# Move 194000, Accepted moves so far: 104949
# Move 195000, Accepted moves so far: 105479
# Move 196000, Accepted moves so far: 105982
# Move 197000, Accepted moves so far: 106521
# Move 198000, Accepted moves so far: 107045
# Move 199000, Accepted moves so far: 107569
# Move 200000, Accepted moves so far: 108142
# Move 201000, Accepted moves so far: 108661
# Move 202000, Accepted moves so far: 109197
# Move 203000, Accepted moves so far: 109734
# Move 204000, Accepted moves so far: 110287
# Move 205000, Accepted moves so far: 110836
# Move 206000, Accepted moves so far: 111374
# Move 207000, Accepted moves so far: 111912
# Move 208000, Accepted moves so far: 112474
# Move 209000, Accepted moves so far: 112985
# Move 210000, Accepted moves so far: 113515
# Move 211000, Accepted moves so far: 114039
# Move 212000, Accepted moves so far: 114573
# Move 213000, Accepted moves so far: 115096
# Move 214000, Accepted moves so far: 115629
# Move 215000, Accepted moves so far: 116131
# Move 216000, Accepted moves so far: 116681
# Move 217000, Accepted moves so far: 117231
# Move 218000, Accepted moves so far: 117783
# Move 219000, Accepted moves so far: 118331
# Move 220000, Accepted moves so far: 118849
# Move 221000, Accepted moves so far: 119409
# Move 222000, Accepted moves so far: 119927
# Move 223000, Accepted moves so far: 120460
# Move 224000, Accepted moves so far: 120979
# Move 225000, Accepted moves so far: 121545
# Move 226000, Accepted moves so far: 122097
# Move 227000, Accepted moves so far: 122628
# Move 228000, Accepted moves so far: 123150
# Move 229000, Accepted moves so far: 123703
# Move 230000, Accepted moves so far: 124235
# Move 231000, Accepted moves so far: 124779
# Move 232000, Accepted moves so far: 125306
# Move 233000, Accepted moves so far: 125847
# Move 234000, Accepted moves so far: 126363
# Move 235000, Accepted moves so far: 126867
# Move 236000, Accepted moves so far: 127398
# Move 237000, Accepted moves so far: 127921
# Move 238000, Accepted moves so far: 128448
# Move 239000, Accepted moves so far: 128986
# Move 240000, Accepted moves so far: 129502
# Move 241000, Accepted moves so far: 130053
# Move 242000, Accepted moves so far: 130560
# Move 243000, Accepted moves so far: 131081
# Move 244000, Accepted moves so far: 131646
# Move 245000, Accepted moves so far: 132170
# Move 246000, Accepted moves so far: 132707
# Move 247000, Accepted moves so far: 133247
# Move 248000, Accepted moves so far: 133796
# Move 249000, Accepted moves so far: 134347
# Move 250000, Accepted moves so far: 134881
# Move 251000, Accepted moves so far: 135405
# Move 252000, Accepted moves so far: 135933
# Move 253000, Accepted moves so far: 136482
# Move 254000, Accepted moves so far: 137028
# Move 255000, Accepted moves so far: 137573
# Move 256000, Accepted moves so far: 138113
# Move 257000, Accepted moves so far: 138626
# Move 258000, Accepted moves so far: 139172
# Move 259000, Accepted moves so far: 139719
# Move 260000, Accepted moves so far: 140264
# Move 261000, Accepted moves so far: 140804
# Move 262000, Accepted moves so far: 141322
# Move 263000, Accepted moves so far: 141893
# Move 264000, Accepted moves so far: 142400
# Move 265000, Accepted moves so far: 142941
# Move 266000, Accepted moves so far: 143463
# Move 267000, Accepted moves so far: 144003
# Move 268000, Accepted moves so far: 144549
# Move 269000, Accepted moves so far: 145073
# Move 270000, Accepted moves so far: 145613
# Move 271000, Accepted moves so far: 146120
# Move 272000, Accepted moves so far: 146648
# Move 273000, Accepted moves so far: 147161
# Move 274000, Accepted moves so far: 147678
# Move 275000, Accepted moves so far: 148202
# Move 276000, Accepted moves so far: 148725
# Move 277000, Accepted moves so far: 149253
# Move 278000, Accepted moves so far: 149798
# Move 279000, Accepted moves so far: 150313
# Move 280000, Accepted moves so far: 150862
# Move 281000, Accepted moves so far: 151386
# Move 282000, Accepted moves so far: 151921
# Move 283000, Accepted moves so far: 152463
# Move 284000, Accepted moves so far: 152996
# Move 285000, Accepted moves so far: 153520
# Move 286000, Accepted moves so far: 154077
# Move 287000, Accepted moves so far: 154618
# Move 288000, Accepted moves so far: 155123
# Move 289000, Accepted moves so far: 155624
# Move 290000, Accepted moves so far: 156159
# Move 291000, Accepted moves so far: 156695
# Move 292000, Accepted moves so far: 157234
# Move 293000, Accepted moves so far: 157758
# Move 294000, Accepted moves so far: 158325
# Move 295000, Accepted moves so far: 158869
# Move 296000, Accepted moves so far: 159406
# Move 297000, Accepted moves so far: 159907
# Move 298000, Accepted moves so far: 160468
# Move 299000, Accepted moves so far: 160999
# Move 300000, Accepted moves so far: 161527
# Move 301000, Accepted moves so far: 162056
# Move 302000, Accepted moves so far: 162570
# Move 303000, Accepted moves so far: 163082
# Move 304000, Accepted moves so far: 163604
# Move 305000, Accepted moves so far: 164152
# Move 306000, Accepted moves so far: 164683
# Move 307000, Accepted moves so far: 165218
# Move 308000, Accepted moves so far: 165740
# Move 309000, Accepted moves so far: 166246
# Move 310000, Accepted moves so far: 166791
# Move 311000, Accepted moves so far: 167344
# Move 312000, Accepted moves so far: 167896
# Move 313000, Accepted moves so far: 168435
# Move 314000, Accepted moves so far: 168969
# Move 315000, Accepted moves so far: 169512
# Move 316000, Accepted moves so far: 170090
# Move 317000, Accepted moves so far: 170649
# Move 318000, Accepted moves so far: 171199
# Move 319000, Accepted moves so far: 171774
# Move 320000, Accepted moves so far: 172315
# Move 321000, Accepted moves so far: 172849
# Move 322000, Accepted moves so far: 173385
# Move 323000, Accepted moves so far: 173904
# Move 324000, Accepted moves so far: 174439
# Move 325000, Accepted moves so far: 174967
# Move 326000, Accepted moves so far: 175512
# Move 327000, Accepted moves so far: 176047
# Move 328000, Accepted moves so far: 176580
# Move 329000, Accepted moves so far: 177103
# Move 330000, Accepted moves so far: 177647
# Move 331000, Accepted moves so far: 178172
# Move 332000, Accepted moves so far: 178710
# Move 333000, Accepted moves so far: 179253
# Move 334000, Accepted moves so far: 179788
# Move 335000, Accepted moves so far: 180350
# Move 336000, Accepted moves so far: 180903
# Move 337000, Accepted moves so far: 181440
# Move 338000, Accepted moves so far: 181966
# Move 339000, Accepted moves so far: 182495
# Move 340000, Accepted moves so far: 183009
# Move 341000, Accepted moves so far: 183504
# Move 342000, Accepted moves so far: 184026
# Move 343000, Accepted moves so far: 184560
# Move 344000, Accepted moves so far: 185118
# Move 345000, Accepted moves so far: 185668
# Move 346000, Accepted moves so far: 186201
# Move 347000, Accepted moves so far: 186758
# Move 348000, Accepted moves so far: 187331
# Move 349000, Accepted moves so far: 187862
# Move 350000, Accepted moves so far: 188409
# Move 351000, Accepted moves so far: 188940
# Move 352000, Accepted moves so far: 189494
# Move 353000, Accepted moves so far: 190025
# Move 354000, Accepted moves so far: 190567
# Move 355000, Accepted moves so far: 191095
# Move 356000, Accepted moves so far: 191623
# Move 357000, Accepted moves so far: 192156
# Move 358000, Accepted moves so far: 192711
# Move 359000, Accepted moves so far: 193267
# Move 360000, Accepted moves so far: 193822
# Move 361000, Accepted moves so far: 194366
# Move 362000, Accepted moves so far: 194902
# Move 363000, Accepted moves so far: 195448
# Move 364000, Accepted moves so far: 195989
# Move 365000, Accepted moves so far: 196554
# Move 366000, Accepted moves so far: 197129
# Move 367000, Accepted moves so far: 197671
# Move 368000, Accepted moves so far: 198198
# Move 369000, Accepted moves so far: 198755
# Move 370000, Accepted moves so far: 199309
# Move 371000, Accepted moves so far: 199844
# Move 372000, Accepted moves so far: 200395
# Move 373000, Accepted moves so far: 200936
# Move 374000, Accepted moves so far: 201482
# Move 375000, Accepted moves so far: 202031
# Move 376000, Accepted moves so far: 202579
# Move 377000, Accepted moves so far: 203125
# Move 378000, Accepted moves so far: 203648
# Move 379000, Accepted moves so far: 204212
# Move 380000, Accepted moves so far: 204781
# Move 381000, Accepted moves so far: 205304
# Move 382000, Accepted moves so far: 205849
# Move 383000, Accepted moves so far: 206400
# Move 384000, Accepted moves so far: 206953
# Move 385000, Accepted moves so far: 207475
# Move 386000, Accepted moves so far: 208032
# Move 387000, Accepted moves so far: 208580
# Move 388000, Accepted moves so far: 209147
# Move 389000, Accepted moves so far: 209679
# Move 390000, Accepted moves so far: 210193
# Move 391000, Accepted moves so far: 210754
# Move 392000, Accepted moves so far: 211295
# Move 393000, Accepted moves so far: 211828
# Move 394000, Accepted moves so far: 212383
# Move 395000, Accepted moves so far: 212914
# Move 396000, Accepted moves so far: 213442
# Move 397000, Accepted moves so far: 214013
# Move 398000, Accepted moves so far: 214589
# Move 399000, Accepted moves so far: 215132
# Move 400000, Accepted moves so far: 215689
# Move 401000, Accepted moves so far: 216260
# Move 402000, Accepted moves so far: 216797
# Move 403000, Accepted moves so far: 217365
# Move 404000, Accepted moves so far: 217932
# Move 405000, Accepted moves so far: 218465
# Move 406000, Accepted moves so far: 219030
# Move 407000, Accepted moves so far: 219600
# Move 408000, Accepted moves so far: 220169
# Move 409000, Accepted moves so far: 220721
# Move 410000, Accepted moves so far: 221253
# Move 411000, Accepted moves so far: 221777
# Move 412000, Accepted moves so far: 222323
# Move 413000, Accepted moves so far: 222882
# Move 414000, Accepted moves so far: 223437
# Move 415000, Accepted moves so far: 223969
# Move 416000, Accepted moves so far: 224519
# Move 417000, Accepted moves so far: 225054
# Move 418000, Accepted moves so far: 225608
# Move 419000, Accepted moves so far: 226136
# Move 420000, Accepted moves so far: 226672
# Move 421000, Accepted moves so far: 227201
# Move 422000, Accepted moves so far: 227748
# Move 423000, Accepted moves so far: 228305
# Move 424000, Accepted moves so far: 228847
# Move 425000, Accepted moves so far: 229384
# Move 426000, Accepted moves so far: 229948
# Move 427000, Accepted moves so far: 230494
# Move 428000, Accepted moves so far: 231005
# Move 429000, Accepted moves so far: 231542
# Move 430000, Accepted moves so far: 232081
# Move 431000, Accepted moves so far: 232618
# Move 432000, Accepted moves so far: 233163
# Move 433000, Accepted moves so far: 233687
# Move 434000, Accepted moves so far: 234249
# Move 435000, Accepted moves so far: 234816
# Move 436000, Accepted moves so far: 235357
# Move 437000, Accepted moves so far: 235891
# Move 438000, Accepted moves so far: 236451
# Move 439000, Accepted moves so far: 236995
# Move 440000, Accepted moves so far: 237521
# Move 441000, Accepted moves so far: 238076
# Move 442000, Accepted moves so far: 238599
# Move 443000, Accepted moves so far: 239129
# Move 444000, Accepted moves so far: 239687
# Move 445000, Accepted moves so far: 240234
# Move 446000, Accepted moves so far: 240764
# Move 447000, Accepted moves so far: 241310
# Move 448000, Accepted moves so far: 241867
# Move 449000, Accepted moves so far: 242419
# Move 450000, Accepted moves so far: 242988
# Move 451000, Accepted moves so far: 243534
# Move 452000, Accepted moves so far: 244077
# Move 453000, Accepted moves so far: 244642
# Move 454000, Accepted moves so far: 245171
# Move 455000, Accepted moves so far: 245696
# Move 456000, Accepted moves so far: 246248
# Move 457000, Accepted moves so far: 246814
# Move 458000, Accepted moves so far: 247375
# Move 459000, Accepted moves so far: 247917
# Move 460000, Accepted moves so far: 248429
# Move 461000, Accepted moves so far: 248971
# Move 462000, Accepted moves so far: 249529
# Move 463000, Accepted moves so far: 250082
# Move 464000, Accepted moves so far: 250615
# Move 465000, Accepted moves so far: 251153
# Move 466000, Accepted moves so far: 251679
# Move 467000, Accepted moves so far: 252197
# Move 468000, Accepted moves so far: 252739
# Move 469000, Accepted moves so far: 253282
# Move 470000, Accepted moves so far: 253824
# Move 471000, Accepted moves so far: 254382
# Move 472000, Accepted moves so far: 254954
# Move 473000, Accepted moves so far: 255508
# Move 474000, Accepted moves so far: 256057
# Move 475000, Accepted moves so far: 256598
# Move 476000, Accepted moves so far: 257144
# Move 477000, Accepted moves so far: 257708
# Move 478000, Accepted moves so far: 258232
# Move 479000, Accepted moves so far: 258816
# Move 480000, Accepted moves so far: 259346
# Move 481000, Accepted moves so far: 259899
# Move 482000, Accepted moves so far: 260448
# Move 483000, Accepted moves so far: 261011
# Move 484000, Accepted moves so far: 261542
# Move 485000, Accepted moves so far: 262098
# Move 486000, Accepted moves so far: 262644
# Move 487000, Accepted moves so far: 263211
# Move 488000, Accepted moves so far: 263748
# Move 489000, Accepted moves so far: 264309
# Move 490000, Accepted moves so far: 264843
# Move 491000, Accepted moves so far: 265365
# Move 492000, Accepted moves so far: 265913
# Move 493000, Accepted moves so far: 266464
# Move 494000, Accepted moves so far: 266994
# Move 495000, Accepted moves so far: 267534
# Move 496000, Accepted moves so far: 268071
# Move 497000, Accepted moves so far: 268621
# Move 498000, Accepted moves so far: 269160
# Move 499000, Accepted moves so far: 269692
# Move 500000, Accepted moves so far: 270222
# Move 501000, Accepted moves so far: 270791
# Move 502000, Accepted moves so far: 271342
# Move 503000, Accepted moves so far: 271912
# Move 504000, Accepted moves so far: 272457
# Move 505000, Accepted moves so far: 272985
# Move 506000, Accepted moves so far: 273498
# Move 507000, Accepted moves so far: 274030
# Move 508000, Accepted moves so far: 274562
# Move 509000, Accepted moves so far: 275111
# Move 510000, Accepted moves so far: 275644
# Move 511000, Accepted moves so far: 276185
# Move 512000, Accepted moves so far: 276699
# Move 513000, Accepted moves so far: 277236
# Move 514000, Accepted moves so far: 277767
# Move 515000, Accepted moves so far: 278313
# Move 516000, Accepted moves so far: 278859
# Move 517000, Accepted moves so far: 279421
# Move 518000, Accepted moves so far: 279965
# Move 519000, Accepted moves so far: 280479
# Move 520000, Accepted moves so far: 281006
# Move 521000, Accepted moves so far: 281547
# Move 522000, Accepted moves so far: 282104
# Move 523000, Accepted moves so far: 282636
# Move 524000, Accepted moves so far: 283189
# Move 525000, Accepted moves so far: 283756
# Move 526000, Accepted moves so far: 284322
# Move 527000, Accepted moves so far: 284880
# Move 528000, Accepted moves so far: 285413
# Move 529000, Accepted moves so far: 285952
# Move 530000, Accepted moves so far: 286537
# Move 531000, Accepted moves so far: 287066
# Move 532000, Accepted moves so far: 287595
# Move 533000, Accepted moves so far: 288118
# Move 534000, Accepted moves so far: 288672
# Move 535000, Accepted moves so far: 289233
# Move 536000, Accepted moves so far: 289786
# Move 537000, Accepted moves so far: 290326
# Move 538000, Accepted moves so far: 290848
# Move 539000, Accepted moves so far: 291396
# Move 540000, Accepted moves so far: 291916
# Move 541000, Accepted moves so far: 292424
# Move 542000, Accepted moves so far: 292985
# Move 543000, Accepted moves so far: 293499
# Move 544000, Accepted moves so far: 294042
# Move 545000, Accepted moves so far: 294551
# Move 546000, Accepted moves so far: 295093
# Move 547000, Accepted moves so far: 295647
# Move 548000, Accepted moves so far: 296163
# Move 549000, Accepted moves so far: 296711
# Move 550000, Accepted moves so far: 297276
# Move 551000, Accepted moves so far: 297834
# Move 552000, Accepted moves so far: 298369
# Move 553000, Accepted moves so far: 298930
# Move 554000, Accepted moves so far: 299447
# Move 555000, Accepted moves so far: 300013
# Move 556000, Accepted moves so far: 300579
# Move 557000, Accepted moves so far: 301146
# Move 558000, Accepted moves so far: 301709
# Move 559000, Accepted moves so far: 302255
# Move 560000, Accepted moves so far: 302815
# Move 561000, Accepted moves so far: 303328
# Move 562000, Accepted moves so far: 303882
# Move 563000, Accepted moves so far: 304441
# Move 564000, Accepted moves so far: 304984
# Move 565000, Accepted moves so far: 305550
# Move 566000, Accepted moves so far: 306101
# Move 567000, Accepted moves so far: 306656
# Move 568000, Accepted moves so far: 307216
# Move 569000, Accepted moves so far: 307756
# Move 570000, Accepted moves so far: 308315
# Move 571000, Accepted moves so far: 308860
# Move 572000, Accepted moves so far: 309398
# Move 573000, Accepted moves so far: 309900
# Move 574000, Accepted moves so far: 310432
# Move 575000, Accepted moves so far: 310968
# Move 576000, Accepted moves so far: 311525
# Move 577000, Accepted moves so far: 312059
# Move 578000, Accepted moves so far: 312605
# Move 579000, Accepted moves so far: 313162
# Move 580000, Accepted moves so far: 313698
# Move 581000, Accepted moves so far: 314239
# Move 582000, Accepted moves so far: 314757
# Move 583000, Accepted moves so far: 315292
# Move 584000, Accepted moves so far: 315830
# Move 585000, Accepted moves so far: 316381
# Move 586000, Accepted moves so far: 316917
# Move 587000, Accepted moves so far: 317458
# Move 588000, Accepted moves so far: 318000
# Move 589000, Accepted moves so far: 318519
# Move 590000, Accepted moves so far: 319084
# Move 591000, Accepted moves so far: 319615
# Move 592000, Accepted moves so far: 320175
# Move 593000, Accepted moves so far: 320724
# Move 594000, Accepted moves so far: 321251
# Move 595000, Accepted moves so far: 321802
# Move 596000, Accepted moves so far: 322346
# Move 597000, Accepted moves so far: 322872
# Move 598000, Accepted moves so far: 323405
# Move 599000, Accepted moves so far: 323949
# Move 600000, Accepted moves so far: 324485
# Move 601000, Accepted moves so far: 325007
# Move 602000, Accepted moves so far: 325496
# Move 603000, Accepted moves so far: 326026
# Move 604000, Accepted moves so far: 326586
# Move 605000, Accepted moves so far: 327160
# Move 606000, Accepted moves so far: 327728
# Move 607000, Accepted moves so far: 328277
# Move 608000, Accepted moves so far: 328820
# Move 609000, Accepted moves so far: 329363
# Move 610000, Accepted moves so far: 329908
# Move 611000, Accepted moves so far: 330452
# Move 612000, Accepted moves so far: 330975
# Move 613000, Accepted moves so far: 331474
# Move 614000, Accepted moves so far: 332015
# Move 615000, Accepted moves so far: 332521
# Move 616000, Accepted moves so far: 333043
# Move 617000, Accepted moves so far: 333556
# Move 618000, Accepted moves so far: 334065
# Move 619000, Accepted moves so far: 334612
# Move 620000, Accepted moves so far: 335184
# Move 621000, Accepted moves so far: 335729
# Move 622000, Accepted moves so far: 336288
# Move 623000, Accepted moves so far: 336835
# Move 624000, Accepted moves so far: 337397
# Move 625000, Accepted moves so far: 337952
# Move 626000, Accepted moves so far: 338513
# Move 627000, Accepted moves so far: 339058
# Move 628000, Accepted moves so far: 339598
# Move 629000, Accepted moves so far: 340161
# Move 630000, Accepted moves so far: 340696
# Move 631000, Accepted moves so far: 341256
# Move 632000, Accepted moves so far: 341810
# Move 633000, Accepted moves so far: 342337
# Move 634000, Accepted moves so far: 342876
# Move 635000, Accepted moves so far: 343404
# Move 636000, Accepted moves so far: 343967
# Move 637000, Accepted moves so far: 344531
# Move 638000, Accepted moves so far: 345065
# Move 639000, Accepted moves so far: 345608
# Move 640000, Accepted moves so far: 346160
# Move 641000, Accepted moves so far: 346696
# Move 642000, Accepted moves so far: 347226
# Move 643000, Accepted moves so far: 347771
# Move 644000, Accepted moves so far: 348337
# Move 645000, Accepted moves so far: 348872
# Move 646000, Accepted moves so far: 349417
# Move 647000, Accepted moves so far: 349961
# Move 648000, Accepted moves so far: 350497
# Move 649000, Accepted moves so far: 351049
# Move 650000, Accepted moves so far: 351584
# Move 651000, Accepted moves so far: 352138
# Move 652000, Accepted moves so far: 352692
# Move 653000, Accepted moves so far: 353239
# Move 654000, Accepted moves so far: 353800
# Move 655000, Accepted moves so far: 354337
# Move 656000, Accepted moves so far: 354909
# Move 657000, Accepted moves so far: 355461
# Move 658000, Accepted moves so far: 356012
# Move 659000, Accepted moves so far: 356545
# Move 660000, Accepted moves so far: 357109
# Move 661000, Accepted moves so far: 357622
# Move 662000, Accepted moves so far: 358133
# Move 663000, Accepted moves so far: 358683
# Move 664000, Accepted moves so far: 359204
# Move 665000, Accepted moves so far: 359715
# Move 666000, Accepted moves so far: 360248
# Move 667000, Accepted moves so far: 360787
# Move 668000, Accepted moves so far: 361339
# Move 669000, Accepted moves so far: 361874
# Move 670000, Accepted moves so far: 362386
# Move 671000, Accepted moves so far: 362906
# Move 672000, Accepted moves so far: 363466
# Move 673000, Accepted moves so far: 363998
# Move 674000, Accepted moves so far: 364541
# Move 675000, Accepted moves so far: 365069
# Move 676000, Accepted moves so far: 365646
# Move 677000, Accepted moves so far: 366179
# Move 678000, Accepted moves so far: 366715
# Move 679000, Accepted moves so far: 367262
# Move 680000, Accepted moves so far: 367813
# Move 681000, Accepted moves so far: 368344
# Move 682000, Accepted moves so far: 368872
# Move 683000, Accepted moves so far: 369415
# Move 684000, Accepted moves so far: 369986
# Move 685000, Accepted moves so far: 370522
# Move 686000, Accepted moves so far: 371065
# Move 687000, Accepted moves so far: 371611
# Move 688000, Accepted moves so far: 372169
# Move 689000, Accepted moves so far: 372730
# Move 690000, Accepted moves so far: 373270
# Move 691000, Accepted moves so far: 373799
# Move 692000, Accepted moves so far: 374352
# Move 693000, Accepted moves so far: 374881
# Move 694000, Accepted moves so far: 375426
# Move 695000, Accepted moves so far: 375997
# Move 696000, Accepted moves so far: 376542
# Move 697000, Accepted moves so far: 377074
# Move 698000, Accepted moves so far: 377630
# Move 699000, Accepted moves so far: 378183
# Move 700000, Accepted moves so far: 378725
# Move 701000, Accepted moves so far: 379295
# Move 702000, Accepted moves so far: 379858
# Move 703000, Accepted moves so far: 380389
# Move 704000, Accepted moves so far: 380925
# Move 705000, Accepted moves so far: 381475
# Move 706000, Accepted moves so far: 381994
# Move 707000, Accepted moves so far: 382546
# Move 708000, Accepted moves so far: 383099
# Move 709000, Accepted moves so far: 383662
# Move 710000, Accepted moves so far: 384221
# Move 711000, Accepted moves so far: 384757
# Move 712000, Accepted moves so far: 385326
# Move 713000, Accepted moves so far: 385847
# Move 714000, Accepted moves so far: 386433
# Move 715000, Accepted moves so far: 386961
# Move 716000, Accepted moves so far: 387498
# Move 717000, Accepted moves so far: 388021
# Move 718000, Accepted moves so far: 388557
# Move 719000, Accepted moves so far: 389075
# Move 720000, Accepted moves so far: 389641
# Move 721000, Accepted moves so far: 390176
# Move 722000, Accepted moves so far: 390689
# Move 723000, Accepted moves so far: 391243
# Move 724000, Accepted moves so far: 391763
# Move 725000, Accepted moves so far: 392297
# Move 726000, Accepted moves so far: 392830
# Move 727000, Accepted moves so far: 393395
# Move 728000, Accepted moves so far: 393926
# Move 729000, Accepted moves so far: 394463
# Move 730000, Accepted moves so far: 395014
# Move 731000, Accepted moves so far: 395564
# Move 732000, Accepted moves so far: 396127
# Move 733000, Accepted moves so far: 396666
# Move 734000, Accepted moves so far: 397195
# Move 735000, Accepted moves so far: 397729
# Move 736000, Accepted moves so far: 398281
# Move 737000, Accepted moves so far: 398820
# Move 738000, Accepted moves so far: 399399
# Move 739000, Accepted moves so far: 399932
# Move 740000, Accepted moves so far: 400480
# Move 741000, Accepted moves so far: 400993
# Move 742000, Accepted moves so far: 401517
# Move 743000, Accepted moves so far: 402067
# Move 744000, Accepted moves so far: 402589
# Move 745000, Accepted moves so far: 403147
# Move 746000, Accepted moves so far: 403690
# Move 747000, Accepted moves so far: 404243
# Move 748000, Accepted moves so far: 404768
# Move 749000, Accepted moves so far: 405302
# Move 750000, Accepted moves so far: 405849
# Move 751000, Accepted moves so far: 406407
# Move 752000, Accepted moves so far: 406954
# Move 753000, Accepted moves so far: 407512
# Move 754000, Accepted moves so far: 408059
# Move 755000, Accepted moves so far: 408585
# Move 756000, Accepted moves so far: 409143
# Move 757000, Accepted moves so far: 409701
# Move 758000, Accepted moves so far: 410235
# Move 759000, Accepted moves so far: 410773
# Move 760000, Accepted moves so far: 411294
# Move 761000, Accepted moves so far: 411834
# Move 762000, Accepted moves so far: 412358
# Move 763000, Accepted moves so far: 412910
# Move 764000, Accepted moves so far: 413460
# Move 765000, Accepted moves so far: 414009
# Move 766000, Accepted moves so far: 414561
# Move 767000, Accepted moves so far: 415114
# Move 768000, Accepted moves so far: 415646
# Move 769000, Accepted moves so far: 416173
# Move 770000, Accepted moves so far: 416727
# Move 771000, Accepted moves so far: 417242
# Move 772000, Accepted moves so far: 417791
# Move 773000, Accepted moves so far: 418331
# Move 774000, Accepted moves so far: 418877
# Move 775000, Accepted moves so far: 419399
# Move 776000, Accepted moves so far: 419936
# Move 777000, Accepted moves so far: 420469
# Move 778000, Accepted moves so far: 421007
# Move 779000, Accepted moves so far: 421561
# Move 780000, Accepted moves so far: 422125
# Move 781000, Accepted moves so far: 422648
# Move 782000, Accepted moves so far: 423194
# Move 783000, Accepted moves so far: 423736
# Move 784000, Accepted moves so far: 424307
# Move 785000, Accepted moves so far: 424864
# Move 786000, Accepted moves so far: 425405
# Move 787000, Accepted moves so far: 425948
# Move 788000, Accepted moves so far: 426489
# Move 789000, Accepted moves so far: 427037
# Move 790000, Accepted moves so far: 427586
# Move 791000, Accepted moves so far: 428113
# Move 792000, Accepted moves so far: 428668
# Move 793000, Accepted moves so far: 429219
# Move 794000, Accepted moves so far: 429769
# Move 795000, Accepted moves so far: 430281
# Move 796000, Accepted moves so far: 430853
# Move 797000, Accepted moves so far: 431381
# Move 798000, Accepted moves so far: 431869
# Move 799000, Accepted moves so far: 432415
# Move 800000, Accepted moves so far: 432996
# Move 801000, Accepted moves so far: 433550
# Move 802000, Accepted moves so far: 434104
# Move 803000, Accepted moves so far: 434680
# Move 804000, Accepted moves so far: 435207
# Move 805000, Accepted moves so far: 435765
# Move 806000, Accepted moves so far: 436290
# Move 807000, Accepted moves so far: 436820
# Move 808000, Accepted moves so far: 437387
# Move 809000, Accepted moves so far: 437932
# Move 810000, Accepted moves so far: 438468
# Move 811000, Accepted moves so far: 438996
# Move 812000, Accepted moves so far: 439526
# Move 813000, Accepted moves so far: 440074
# Move 814000, Accepted moves so far: 440605
# Move 815000, Accepted moves so far: 441147
# Move 816000, Accepted moves so far: 441713
# Move 817000, Accepted moves so far: 442263
# Move 818000, Accepted moves so far: 442794
# Move 819000, Accepted moves so far: 443344
# Move 820000, Accepted moves so far: 443877
# Move 821000, Accepted moves so far: 444436
# Move 822000, Accepted moves so far: 444983
# Move 823000, Accepted moves so far: 445540
# Move 824000, Accepted moves so far: 446069
# Move 825000, Accepted moves so far: 446622
# Move 826000, Accepted moves so far: 447171
# Move 827000, Accepted moves so far: 447726
# Move 828000, Accepted moves so far: 448311
# Move 829000, Accepted moves so far: 448879
# Move 830000, Accepted moves so far: 449430
# Move 831000, Accepted moves so far: 449982
# Move 832000, Accepted moves so far: 450549
# Move 833000, Accepted moves so far: 451101
# Move 834000, Accepted moves so far: 451641
# Move 835000, Accepted moves so far: 452208
# Move 836000, Accepted moves so far: 452746
# Move 837000, Accepted moves so far: 453290
# Move 838000, Accepted moves so far: 453823
# Move 839000, Accepted moves so far: 454363
# Move 840000, Accepted moves so far: 454905
# Move 841000, Accepted moves so far: 455461
# Move 842000, Accepted moves so far: 456015
# Move 843000, Accepted moves so far: 456561
# Move 844000, Accepted moves so far: 457099
# Move 845000, Accepted moves so far: 457660
# Move 846000, Accepted moves so far: 458208
# Move 847000, Accepted moves so far: 458754
# Move 848000, Accepted moves so far: 459295
# Move 849000, Accepted moves so far: 459775
# Move 850000, Accepted moves so far: 460341
# Move 851000, Accepted moves so far: 460875
# Move 852000, Accepted moves so far: 461455
# Move 853000, Accepted moves so far: 461989
# Move 854000, Accepted moves so far: 462508
# Move 855000, Accepted moves so far: 463074
# Move 856000, Accepted moves so far: 463615
# Move 857000, Accepted moves so far: 464178
# Move 858000, Accepted moves so far: 464728
# Move 859000, Accepted moves so far: 465285
# Move 860000, Accepted moves so far: 465844
# Move 861000, Accepted moves so far: 466400
# Move 862000, Accepted moves so far: 466955
# Move 863000, Accepted moves so far: 467471
# Move 864000, Accepted moves so far: 468010
# Move 865000, Accepted moves so far: 468540
# Move 866000, Accepted moves so far: 469091
# Move 867000, Accepted moves so far: 469615
# Move 868000, Accepted moves so far: 470145
# Move 869000, Accepted moves so far: 470701
# Move 870000, Accepted moves so far: 471268
# Move 871000, Accepted moves so far: 471803
# Move 872000, Accepted moves so far: 472330
# Move 873000, Accepted moves so far: 472888
# Move 874000, Accepted moves so far: 473438
# Move 875000, Accepted moves so far: 473977
# Move 876000, Accepted moves so far: 474518
# Move 877000, Accepted moves so far: 475046
# Move 878000, Accepted moves so far: 475580
# Move 879000, Accepted moves so far: 476130
# Move 880000, Accepted moves so far: 476698
# Move 881000, Accepted moves so far: 477258
# Move 882000, Accepted moves so far: 477801
# Move 883000, Accepted moves so far: 478343
# Move 884000, Accepted moves so far: 478903
# Move 885000, Accepted moves so far: 479451
# Move 886000, Accepted moves so far: 480000
# Move 887000, Accepted moves so far: 480568
# Move 888000, Accepted moves so far: 481130
# Move 889000, Accepted moves so far: 481658
# Move 890000, Accepted moves so far: 482220
# Move 891000, Accepted moves so far: 482773
# Move 892000, Accepted moves so far: 483299
# Move 893000, Accepted moves so far: 483816
# Move 894000, Accepted moves so far: 484356
# Move 895000, Accepted moves so far: 484869
# Move 896000, Accepted moves so far: 485397
# Move 897000, Accepted moves so far: 485943
# Move 898000, Accepted moves so far: 486508
# Move 899000, Accepted moves so far: 487072
# Move 900000, Accepted moves so far: 487620
# Move 901000, Accepted moves so far: 488179
# Move 902000, Accepted moves so far: 488736
# Move 903000, Accepted moves so far: 489278
# Move 904000, Accepted moves so far: 489833
# Move 905000, Accepted moves so far: 490368
# Move 906000, Accepted moves so far: 490925
# Move 907000, Accepted moves so far: 491480
# Move 908000, Accepted moves so far: 492031
# Move 909000, Accepted moves so far: 492567
# Move 910000, Accepted moves so far: 493121
# Move 911000, Accepted moves so far: 493650
# Move 912000, Accepted moves so far: 494180
# Move 913000, Accepted moves so far: 494726
# Move 914000, Accepted moves so far: 495277
# Move 915000, Accepted moves so far: 495840
# Move 916000, Accepted moves so far: 496382
# Move 917000, Accepted moves so far: 496904
# Move 918000, Accepted moves so far: 497465
# Move 919000, Accepted moves so far: 498038
# Move 920000, Accepted moves so far: 498585
# Move 921000, Accepted moves so far: 499129
# Move 922000, Accepted moves so far: 499668
# Move 923000, Accepted moves so far: 500215
# Move 924000, Accepted moves so far: 500757
# Move 925000, Accepted moves so far: 501313
# Move 926000, Accepted moves so far: 501865
# Move 927000, Accepted moves so far: 502435
# Move 928000, Accepted moves so far: 503000
# Move 929000, Accepted moves so far: 503527
# Move 930000, Accepted moves so far: 504039
# Move 931000, Accepted moves so far: 504559
# Move 932000, Accepted moves so far: 505101
# Move 933000, Accepted moves so far: 505630
# Move 934000, Accepted moves so far: 506176
# Move 935000, Accepted moves so far: 506728
# Move 936000, Accepted moves so far: 507278
# Move 937000, Accepted moves so far: 507805
# Move 938000, Accepted moves so far: 508365
# Move 939000, Accepted moves so far: 508923
# Move 940000, Accepted moves so far: 509475
# Move 941000, Accepted moves so far: 510026
# Move 942000, Accepted moves so far: 510575
# Move 943000, Accepted moves so far: 511098
# Move 944000, Accepted moves so far: 511630
# Move 945000, Accepted moves so far: 512176
# Move 946000, Accepted moves so far: 512702
# Move 947000, Accepted moves so far: 513262
# Move 948000, Accepted moves so far: 513795
# Move 949000, Accepted moves so far: 514324
# Move 950000, Accepted moves so far: 514869
# Move 951000, Accepted moves so far: 515394
# Move 952000, Accepted moves so far: 515936
# Move 953000, Accepted moves so far: 516490
# Move 954000, Accepted moves so far: 517030
# Move 955000, Accepted moves so far: 517589
# Move 956000, Accepted moves so far: 518152
# Move 957000, Accepted moves so far: 518711
# Move 958000, Accepted moves so far: 519251
# Move 959000, Accepted moves so far: 519800
# Move 960000, Accepted moves so far: 520332
# Move 961000, Accepted moves so far: 520856
# Move 962000, Accepted moves so far: 521410
# Move 963000, Accepted moves so far: 521935
# Move 964000, Accepted moves so far: 522503
# Move 965000, Accepted moves so far: 523057
# Move 966000, Accepted moves so far: 523599
# Move 967000, Accepted moves so far: 524141
# Move 968000, Accepted moves so far: 524689
# Move 969000, Accepted moves so far: 525240
# Move 970000, Accepted moves so far: 525781
# Move 971000, Accepted moves so far: 526306
# Move 972000, Accepted moves so far: 526847
# Move 973000, Accepted moves so far: 527375
# Move 974000, Accepted moves so far: 527915
# Move 975000, Accepted moves so far: 528468
# Move 976000, Accepted moves so far: 529008
# Move 977000, Accepted moves so far: 529542
# Move 978000, Accepted moves so far: 530106
# Move 979000, Accepted moves so far: 530644
# Move 980000, Accepted moves so far: 531183
# Move 981000, Accepted moves so far: 531697
# Move 982000, Accepted moves so far: 532229
# Move 983000, Accepted moves so far: 532791
# Move 984000, Accepted moves so far: 533322
# Move 985000, Accepted moves so far: 533854
# Move 986000, Accepted moves so far: 534386
# Move 987000, Accepted moves so far: 534942
# Move 988000, Accepted moves so far: 535475
# Move 989000, Accepted moves so far: 536022
# Move 990000, Accepted moves so far: 536568
# Move 991000, Accepted moves so far: 537078
# Move 992000, Accepted moves so far: 537617
# Move 993000, Accepted moves so far: 538173
# Move 994000, Accepted moves so far: 538699
# Move 995000, Accepted moves so far: 539245
# Move 996000, Accepted moves so far: 539747
# Move 997000, Accepted moves so far: 540261
# Move 998000, Accepted moves so far: 540809
# Move 999000, Accepted moves so far: 541355
# Move 1000000, Accepted moves so far: 541892
# Move 1001000, Accepted moves so far: 542447
# Move 1002000, Accepted moves so far: 543002
# Move 1003000, Accepted moves so far: 543550
# Move 1004000, Accepted moves so far: 544094
# Move 1005000, Accepted moves so far: 544636
# Move 1006000, Accepted moves so far: 545146
# Move 1007000, Accepted moves so far: 545676
# Move 1008000, Accepted moves so far: 546242
# Move 1009000, Accepted moves so far: 546790
# Move 1010000, Accepted moves so far: 547318
# Move 1011000, Accepted moves so far: 547849
# Move 1012000, Accepted moves so far: 548404
# Move 1013000, Accepted moves so far: 548976
# Move 1014000, Accepted moves so far: 549517
# Move 1015000, Accepted moves so far: 550064
# Move 1016000, Accepted moves so far: 550584
# Move 1017000, Accepted moves so far: 551152
# Move 1018000, Accepted moves so far: 551706
# Move 1019000, Accepted moves so far: 552250
# Move 1020000, Accepted moves so far: 552794
# Move 1021000, Accepted moves so far: 553312
# Move 1022000, Accepted moves so far: 553843
# Move 1023000, Accepted moves so far: 554384
# Move 1024000, Accepted moves so far: 554965
# Move 1025000, Accepted moves so far: 555520
# Move 1026000, Accepted moves so far: 556073
# Move 1027000, Accepted moves so far: 556601
# Move 1028000, Accepted moves so far: 557138
# Move 1029000, Accepted moves so far: 557700
# Move 1030000, Accepted moves so far: 558214
# Move 1031000, Accepted moves so far: 558760
# Move 1032000, Accepted moves so far: 559314
# Move 1033000, Accepted moves so far: 559835
# Move 1034000, Accepted moves so far: 560349
# Move 1035000, Accepted moves so far: 560876
# Move 1036000, Accepted moves so far: 561442
# Move 1037000, Accepted moves so far: 562007
# Move 1038000, Accepted moves so far: 562567
# Move 1039000, Accepted moves so far: 563070
# Move 1040000, Accepted moves so far: 563605
# Move 1041000, Accepted moves so far: 564111
# Move 1042000, Accepted moves so far: 564660
# Move 1043000, Accepted moves so far: 565190
# Move 1044000, Accepted moves so far: 565732
# Move 1045000, Accepted moves so far: 566258
# Move 1046000, Accepted moves so far: 566797
# Move 1047000, Accepted moves so far: 567343
# Move 1048000, Accepted moves so far: 567885
# Move 1049000, Accepted moves so far: 568415
# Move 1050000, Accepted moves so far: 568951
# Move 1051000, Accepted moves so far: 569488
# Move 1052000, Accepted moves so far: 570005
# Move 1053000, Accepted moves so far: 570527
# Move 1054000, Accepted moves so far: 571065
# Move 1055000, Accepted moves so far: 571607
# Move 1056000, Accepted moves so far: 572144
# Move 1057000, Accepted moves so far: 572707
# Move 1058000, Accepted moves so far: 573228
# Move 1059000, Accepted moves so far: 573764
# Move 1060000, Accepted moves so far: 574312
# Move 1061000, Accepted moves so far: 574881
# Move 1062000, Accepted moves so far: 575395
# Move 1063000, Accepted moves so far: 575948
# Move 1064000, Accepted moves so far: 576504
# Move 1065000, Accepted moves so far: 577042
# Move 1066000, Accepted moves so far: 577599
# Move 1067000, Accepted moves so far: 578140
# Move 1068000, Accepted moves so far: 578696
# Move 1069000, Accepted moves so far: 579244
# Move 1070000, Accepted moves so far: 579788
# Move 1071000, Accepted moves so far: 580320
# Move 1072000, Accepted moves so far: 580836
# Move 1073000, Accepted moves so far: 581381
# Move 1074000, Accepted moves so far: 581933
# Move 1075000, Accepted moves so far: 582491
# Move 1076000, Accepted moves so far: 583055
# Move 1077000, Accepted moves so far: 583580
# Move 1078000, Accepted moves so far: 584143
# Move 1079000, Accepted moves so far: 584694
# Move 1080000, Accepted moves so far: 585257
# Move 1081000, Accepted moves so far: 585796
# Move 1082000, Accepted moves so far: 586335
# Move 1083000, Accepted moves so far: 586871
# Move 1084000, Accepted moves so far: 587430
# Move 1085000, Accepted moves so far: 587964
# Move 1086000, Accepted moves so far: 588498
# Move 1087000, Accepted moves so far: 589033
# Move 1088000, Accepted moves so far: 589574
# Move 1089000, Accepted moves so far: 590120
# Move 1090000, Accepted moves so far: 590656
# Move 1091000, Accepted moves so far: 591191
# Move 1092000, Accepted moves so far: 591722
# Move 1093000, Accepted moves so far: 592251
# Move 1094000, Accepted moves so far: 592790
# Move 1095000, Accepted moves so far: 593334
# Move 1096000, Accepted moves so far: 593881
# Move 1097000, Accepted moves so far: 594416
# Move 1098000, Accepted moves so far: 594981
# Move 1099000, Accepted moves so far: 595554
# Move 1100000, Accepted moves so far: 596124
# Move 1101000, Accepted moves so far: 596676
# Move 1102000, Accepted moves so far: 597231
# Move 1103000, Accepted moves so far: 597793
# Move 1104000, Accepted moves so far: 598328
# Move 1105000, Accepted moves so far: 598883
# Move 1106000, Accepted moves so far: 599440
# Move 1107000, Accepted moves so far: 599972
# Move 1108000, Accepted moves so far: 600543
# Move 1109000, Accepted moves so far: 601072
# Move 1110000, Accepted moves so far: 601596
# Move 1111000, Accepted moves so far: 602162
# Move 1112000, Accepted moves so far: 602702
# Move 1113000, Accepted moves so far: 603225
# ...
# Move 9645000, Accepted moves so far: 5348141
# Move 9646000, Accepted moves so far: 5348671
# Move 9647000, Accepted moves so far: 5349241
# Move 9648000, Accepted moves so far: 5349791
# Move 9649000, Accepted moves so far: 5350331
# Move 9650000, Accepted moves so far: 5350895
# Move 9651000, Accepted moves so far: 5351473
# Move 9652000, Accepted moves so far: 5352052
# Move 9653000, Accepted moves so far: 5352622
# Move 9654000, Accepted moves so far: 5353194
# Move 9655000, Accepted moves so far: 5353727
# Move 9656000, Accepted moves so far: 5354278
# Move 9657000, Accepted moves so far: 5354858
# Move 9658000, Accepted moves so far: 5355426
# Move 9659000, Accepted moves so far: 5355990
# Move 9660000, Accepted moves so far: 5356563
# Move 9661000, Accepted moves so far: 5357114
# Move 9662000, Accepted moves so far: 5357670
# Move 9663000, Accepted moves so far: 5358198
# Move 9664000, Accepted moves so far: 5358745
# Move 9665000, Accepted moves so far: 5359299
# Move 9666000, Accepted moves so far: 5359853
# Move 9667000, Accepted moves so far: 5360422
# Move 9668000, Accepted moves so far: 5360946
# Move 9669000, Accepted moves so far: 5361495
# Move 9670000, Accepted moves so far: 5362031
# Move 9671000, Accepted moves so far: 5362607
# Move 9672000, Accepted moves so far: 5363160
# Move 9673000, Accepted moves so far: 5363707
# Move 9674000, Accepted moves so far: 5364260
# Move 9675000, Accepted moves so far: 5364833
# Move 9676000, Accepted moves so far: 5365391
# Move 9677000, Accepted moves so far: 5365948
# Move 9678000, Accepted moves so far: 5366488
# Move 9679000, Accepted moves so far: 5367043
# Move 9680000, Accepted moves so far: 5367610
# Move 9681000, Accepted moves so far: 5368175
# Move 9682000, Accepted moves so far: 5368711
# Move 9683000, Accepted moves so far: 5369280
# Move 9684000, Accepted moves so far: 5369813
# Move 9685000, Accepted moves so far: 5370386
# Move 9686000, Accepted moves so far: 5370930
# Move 9687000, Accepted moves so far: 5371460
# Move 9688000, Accepted moves so far: 5372010
# Move 9689000, Accepted moves so far: 5372555
# Move 9690000, Accepted moves so far: 5373093
# Move 9691000, Accepted moves so far: 5373645
# Move 9692000, Accepted moves so far: 5374208
# Move 9693000, Accepted moves so far: 5374758
# Move 9694000, Accepted moves so far: 5375330
# Move 9695000, Accepted moves so far: 5375877
# Move 9696000, Accepted moves so far: 5376426
# Move 9697000, Accepted moves so far: 5376989
# Move 9698000, Accepted moves so far: 5377544
# Move 9699000, Accepted moves so far: 5378094
# Move 9700000, Accepted moves so far: 5378642
# Move 9701000, Accepted moves so far: 5379194
# Move 9702000, Accepted moves so far: 5379723
# Move 9703000, Accepted moves so far: 5380282
# Move 9704000, Accepted moves so far: 5380849
# Move 9705000, Accepted moves so far: 5381404
# Move 9706000, Accepted moves so far: 5381958
# Move 9707000, Accepted moves so far: 5382510
# Move 9708000, Accepted moves so far: 5383048
# Move 9709000, Accepted moves so far: 5383597
# Move 9710000, Accepted moves so far: 5384170
# Move 9711000, Accepted moves so far: 5384758
# Move 9712000, Accepted moves so far: 5385307
# Move 9713000, Accepted moves so far: 5385883
# Move 9714000, Accepted moves so far: 5386438
# Move 9715000, Accepted moves so far: 5386960
# Move 9716000, Accepted moves so far: 5387510
# Move 9717000, Accepted moves so far: 5388084
# Move 9718000, Accepted moves so far: 5388630
# Move 9719000, Accepted moves so far: 5389202
# Move 9720000, Accepted moves so far: 5389742
# Move 9721000, Accepted moves so far: 5390291
# Move 9722000, Accepted moves so far: 5390833
# Move 9723000, Accepted moves so far: 5391397
# Move 9724000, Accepted moves so far: 5391961
# Move 9725000, Accepted moves so far: 5392506
# Move 9726000, Accepted moves so far: 5393059
# Move 9727000, Accepted moves so far: 5393594
# Move 9728000, Accepted moves so far: 5394155
# Move 9729000, Accepted moves so far: 5394729
# Move 9730000, Accepted moves so far: 5395292
# Move 9731000, Accepted moves so far: 5395858
# Move 9732000, Accepted moves so far: 5396417
# Move 9733000, Accepted moves so far: 5396990
# Move 9734000, Accepted moves so far: 5397537
# Move 9735000, Accepted moves so far: 5398073
# Move 9736000, Accepted moves so far: 5398616
# Move 9737000, Accepted moves so far: 5399183
# Move 9738000, Accepted moves so far: 5399724
# Move 9739000, Accepted moves so far: 5400287
# Move 9740000, Accepted moves so far: 5400855
# Move 9741000, Accepted moves so far: 5401435
# Move 9742000, Accepted moves so far: 5402007
# Move 9743000, Accepted moves so far: 5402551
# Move 9744000, Accepted moves so far: 5403098
# Move 9745000, Accepted moves so far: 5403647
# Move 9746000, Accepted moves so far: 5404180
# Move 9747000, Accepted moves so far: 5404732
# Move 9748000, Accepted moves so far: 5405290
# Move 9749000, Accepted moves so far: 5405866
# Move 9750000, Accepted moves so far: 5406444
# Move 9751000, Accepted moves so far: 5407017
# Move 9752000, Accepted moves so far: 5407586
# Move 9753000, Accepted moves so far: 5408127
# Move 9754000, Accepted moves so far: 5408680
# Move 9755000, Accepted moves so far: 5409233
# Move 9756000, Accepted moves so far: 5409785
# Move 9757000, Accepted moves so far: 5410333
# Move 9758000, Accepted moves so far: 5410885
# Move 9759000, Accepted moves so far: 5411459
# Move 9760000, Accepted moves so far: 5412041
# Move 9761000, Accepted moves so far: 5412585
# Move 9762000, Accepted moves so far: 5413140
# Move 9763000, Accepted moves so far: 5413690
# Move 9764000, Accepted moves so far: 5414215
# Move 9765000, Accepted moves so far: 5414806
# Move 9766000, Accepted moves so far: 5415371
# Move 9767000, Accepted moves so far: 5415949
# Move 9768000, Accepted moves so far: 5416503
# Move 9769000, Accepted moves so far: 5417069
# Move 9770000, Accepted moves so far: 5417614
# Move 9771000, Accepted moves so far: 5418160
# Move 9772000, Accepted moves so far: 5418730
# Move 9773000, Accepted moves so far: 5419293
# Move 9774000, Accepted moves so far: 5419844
# Move 9775000, Accepted moves so far: 5420411
# Move 9776000, Accepted moves so far: 5420981
# Move 9777000, Accepted moves so far: 5421534
# Move 9778000, Accepted moves so far: 5422098
# Move 9779000, Accepted moves so far: 5422656
# Move 9780000, Accepted moves so far: 5423230
# Move 9781000, Accepted moves so far: 5423785
# Move 9782000, Accepted moves so far: 5424349
# Move 9783000, Accepted moves so far: 5424914
# Move 9784000, Accepted moves so far: 5425466
# Move 9785000, Accepted moves so far: 5426024
# Move 9786000, Accepted moves so far: 5426607
# Move 9787000, Accepted moves so far: 5427138
# Move 9788000, Accepted moves so far: 5427712
# Move 9789000, Accepted moves so far: 5428304
# Move 9790000, Accepted moves so far: 5428873
# Move 9791000, Accepted moves so far: 5429396
# Move 9792000, Accepted moves so far: 5429946
# Move 9793000, Accepted moves so far: 5430495
# Move 9794000, Accepted moves so far: 5431032
# Move 9795000, Accepted moves so far: 5431587
# Move 9796000, Accepted moves so far: 5432158
# Move 9797000, Accepted moves so far: 5432728
# Move 9798000, Accepted moves so far: 5433291
# Move 9799000, Accepted moves so far: 5433850
# Move 9800000, Accepted moves so far: 5434392
# Move 9801000, Accepted moves so far: 5434923
# Move 9802000, Accepted moves so far: 5435511
# Move 9803000, Accepted moves so far: 5436091
# Move 9804000, Accepted moves so far: 5436644
# Move 9805000, Accepted moves so far: 5437230
# Move 9806000, Accepted moves so far: 5437772
# Move 9807000, Accepted moves so far: 5438340
# Move 9808000, Accepted moves so far: 5438898
# Move 9809000, Accepted moves so far: 5439490
# Move 9810000, Accepted moves so far: 5440067
# Move 9811000, Accepted moves so far: 5440607
# Move 9812000, Accepted moves so far: 5441143
# Move 9813000, Accepted moves so far: 5441706
# Move 9814000, Accepted moves so far: 5442313
# Move 9815000, Accepted moves so far: 5442880
# Move 9816000, Accepted moves so far: 5443426
# Move 9817000, Accepted moves so far: 5444017
# Move 9818000, Accepted moves so far: 5444563
# Move 9819000, Accepted moves so far: 5445125
# Move 9820000, Accepted moves so far: 5445668
# Move 9821000, Accepted moves so far: 5446226
# Move 9822000, Accepted moves so far: 5446818
# Move 9823000, Accepted moves so far: 5447380
# Move 9824000, Accepted moves so far: 5447951
# Move 9825000, Accepted moves so far: 5448524
# Move 9826000, Accepted moves so far: 5449095
# Move 9827000, Accepted moves so far: 5449680
# Move 9828000, Accepted moves so far: 5450238
# Move 9829000, Accepted moves so far: 5450822
# Move 9830000, Accepted moves so far: 5451399
# Move 9831000, Accepted moves so far: 5451960
# Move 9832000, Accepted moves so far: 5452520
# Move 9833000, Accepted moves so far: 5453080
# Move 9834000, Accepted moves so far: 5453661
# Move 9835000, Accepted moves so far: 5454226
# Move 9836000, Accepted moves so far: 5454790
# Move 9837000, Accepted moves so far: 5455348
# Move 9838000, Accepted moves so far: 5455894
# Move 9839000, Accepted moves so far: 5456461
# Move 9840000, Accepted moves so far: 5457024
# Move 9841000, Accepted moves so far: 5457623
# Move 9842000, Accepted moves so far: 5458173
# Move 9843000, Accepted moves so far: 5458751
# Move 9844000, Accepted moves so far: 5459341
# Move 9845000, Accepted moves so far: 5459904
# Move 9846000, Accepted moves so far: 5460509
# Move 9847000, Accepted moves so far: 5461078
# Move 9848000, Accepted moves so far: 5461604
# Move 9849000, Accepted moves so far: 5462182
# Move 9850000, Accepted moves so far: 5462746
# Move 9851000, Accepted moves so far: 5463281
# Move 9852000, Accepted moves so far: 5463827
# Move 9853000, Accepted moves so far: 5464386
# Move 9854000, Accepted moves so far: 5464966
# Move 9855000, Accepted moves so far: 5465510
# Move 9856000, Accepted moves so far: 5466102
# Move 9857000, Accepted moves so far: 5466683
# Move 9858000, Accepted moves so far: 5467246
# Move 9859000, Accepted moves so far: 5467795
# Move 9860000, Accepted moves so far: 5468371
# Move 9861000, Accepted moves so far: 5468934
# Move 9862000, Accepted moves so far: 5469483
# Move 9863000, Accepted moves so far: 5470033
# Move 9864000, Accepted moves so far: 5470620
# Move 9865000, Accepted moves so far: 5471202
# Move 9866000, Accepted moves so far: 5471749
# Move 9867000, Accepted moves so far: 5472317
# Move 9868000, Accepted moves so far: 5472895
# Move 9869000, Accepted moves so far: 5473458
# Move 9870000, Accepted moves so far: 5474027
# Move 9871000, Accepted moves so far: 5474580
# Move 9872000, Accepted moves so far: 5475144
# Move 9873000, Accepted moves so far: 5475707
# Move 9874000, Accepted moves so far: 5476263
# Move 9875000, Accepted moves so far: 5476817
# Move 9876000, Accepted moves so far: 5477369
# Move 9877000, Accepted moves so far: 5477920
# Move 9878000, Accepted moves so far: 5478482
# Move 9879000, Accepted moves so far: 5479046
# Move 9880000, Accepted moves so far: 5479592
# Move 9881000, Accepted moves so far: 5480137
# Move 9882000, Accepted moves so far: 5480705
# Move 9883000, Accepted moves so far: 5481263
# Move 9884000, Accepted moves so far: 5481823
# Move 9885000, Accepted moves so far: 5482383
# Move 9886000, Accepted moves so far: 5482978
# Move 9887000, Accepted moves so far: 5483546
# Move 9888000, Accepted moves so far: 5484099
# Move 9889000, Accepted moves so far: 5484660
# Move 9890000, Accepted moves so far: 5485193
# Move 9891000, Accepted moves so far: 5485768
# Move 9892000, Accepted moves so far: 5486336
# Move 9893000, Accepted moves so far: 5486911
# Move 9894000, Accepted moves so far: 5487465
# Move 9895000, Accepted moves so far: 5488023
# Move 9896000, Accepted moves so far: 5488588
# Move 9897000, Accepted moves so far: 5489152
# Move 9898000, Accepted moves so far: 5489710
# Move 9899000, Accepted moves so far: 5490299
# Move 9900000, Accepted moves so far: 5490867
# Move 9901000, Accepted moves so far: 5491425
# Move 9902000, Accepted moves so far: 5491975
# Move 9903000, Accepted moves so far: 5492553
# Move 9904000, Accepted moves so far: 5493131
# Move 9905000, Accepted moves so far: 5493664
# Move 9906000, Accepted moves so far: 5494224
# Move 9907000, Accepted moves so far: 5494772
# Move 9908000, Accepted moves so far: 5495340
# Move 9909000, Accepted moves so far: 5495891
# Move 9910000, Accepted moves so far: 5496452
# Move 9911000, Accepted moves so far: 5497017
# Move 9912000, Accepted moves so far: 5497603
# Move 9913000, Accepted moves so far: 5498168
# Move 9914000, Accepted moves so far: 5498724
# Move 9915000, Accepted moves so far: 5499293
# Move 9916000, Accepted moves so far: 5499859
# Move 9917000, Accepted moves so far: 5500424
# Move 9918000, Accepted moves so far: 5500959
# Move 9919000, Accepted moves so far: 5501501
# Move 9920000, Accepted moves so far: 5502098
# Move 9921000, Accepted moves so far: 5502651
# Move 9922000, Accepted moves so far: 5503217
# Move 9923000, Accepted moves so far: 5503798
# Move 9924000, Accepted moves so far: 5504334
# Move 9925000, Accepted moves so far: 5504909
# Move 9926000, Accepted moves so far: 5505487
# Move 9927000, Accepted moves so far: 5506026
# Move 9928000, Accepted moves so far: 5506598
# Move 9929000, Accepted moves so far: 5507170
# Move 9930000, Accepted moves so far: 5507722
# Move 9931000, Accepted moves so far: 5508286
# Move 9932000, Accepted moves so far: 5508881
# Move 9933000, Accepted moves so far: 5509443
# Move 9934000, Accepted moves so far: 5510002
# Move 9935000, Accepted moves so far: 5510567
# Move 9936000, Accepted moves so far: 5511129
# Move 9937000, Accepted moves so far: 5511702
# Move 9938000, Accepted moves so far: 5512285
# Move 9939000, Accepted moves so far: 5512829
# Move 9940000, Accepted moves so far: 5513358
# Move 9941000, Accepted moves so far: 5513937
# Move 9942000, Accepted moves so far: 5514503
# Move 9943000, Accepted moves so far: 5515097
# Move 9944000, Accepted moves so far: 5515657
# Move 9945000, Accepted moves so far: 5516240
# Move 9946000, Accepted moves so far: 5516824
# Move 9947000, Accepted moves so far: 5517379
# Move 9948000, Accepted moves so far: 5517958
# Move 9949000, Accepted moves so far: 5518542
# Move 9950000, Accepted moves so far: 5519123
# Move 9951000, Accepted moves so far: 5519701
# Move 9952000, Accepted moves so far: 5520255
# Move 9953000, Accepted moves so far: 5520818
# Move 9954000, Accepted moves so far: 5521379
# Move 9955000, Accepted moves so far: 5521952
# Move 9956000, Accepted moves so far: 5522504
# Move 9957000, Accepted moves so far: 5523081
# Move 9958000, Accepted moves so far: 5523685
# Move 9959000, Accepted moves so far: 5524247
# Move 9960000, Accepted moves so far: 5524814
# Move 9961000, Accepted moves so far: 5525383
# Move 9962000, Accepted moves so far: 5525964
# Move 9963000, Accepted moves so far: 5526523
# Move 9964000, Accepted moves so far: 5527080
# Move 9965000, Accepted moves so far: 5527637
# Move 9966000, Accepted moves so far: 5528185
# Move 9967000, Accepted moves so far: 5528738
# Move 9968000, Accepted moves so far: 5529325
# Move 9969000, Accepted moves so far: 5529861
# Move 9970000, Accepted moves so far: 5530435
# Move 9971000, Accepted moves so far: 5531001
# Move 9972000, Accepted moves so far: 5531591
# Move 9973000, Accepted moves so far: 5532177
# Move 9974000, Accepted moves so far: 5532746
# Move 9975000, Accepted moves so far: 5533313
# Move 9976000, Accepted moves so far: 5533871
# Move 9977000, Accepted moves so far: 5534431
# Move 9978000, Accepted moves so far: 5535006
# Move 9979000, Accepted moves so far: 5535562
# Move 9980000, Accepted moves so far: 5536117
# Move 9981000, Accepted moves so far: 5536702
# Move 9982000, Accepted moves so far: 5537248
# Move 9983000, Accepted moves so far: 5537788
# Move 9984000, Accepted moves so far: 5538377
# Move 9985000, Accepted moves so far: 5538934
# Move 9986000, Accepted moves so far: 5539478
# Move 9987000, Accepted moves so far: 5540009
# Move 9988000, Accepted moves so far: 5540569
# Move 9989000, Accepted moves so far: 5541125
# Move 9990000, Accepted moves so far: 5541677
# Move 9991000, Accepted moves so far: 5542241
# Move 9992000, Accepted moves so far: 5542799
# Move 9993000, Accepted moves so far: 5543378
# Move 9994000, Accepted moves so far: 5543942
# Move 9995000, Accepted moves so far: 5544510
# Move 9996000, Accepted moves so far: 5545080
# Move 9997000, Accepted moves so far: 5545662
# Move 9998000, Accepted moves so far: 5546212
# Move 9999000, Accepted moves so far: 5546731

# %%
plt.figure()
from matplotlib.patches import Circle

fig, ax = plt.subplots()
ax.set_aspect('equal')

for h in positions_heads:
    ax.add_patch(Circle(h, r_head, fill=True, fc = 'red', alpha =1))

for tail in positions_tails:
    for t in tail:
        ax.add_patch(Circle(t, r_carbon, fill=True, fc = 'orange'))
for w in positions_water:
    ax.add_patch(Circle(w, r_water, fill=True, fc = 'blue'))

ax.set_xlim(0, L)
ax.set_ylim(0, L) #this does work for no overlaps on graph
plt.savefig('trial_1.png')
#trial 1 is 10,000,000 moves with 1000 particles

# %%
#if metropolis algorithm is working - need to figure out what to calculate to show micelle formation 
#calculate pair correlation function for phospholipids should see peaks where there are clusters of micelles
def phospholipid_pair_correlation_2D(positions, r_water, r_head, r_carbon, L, bins):
    #positions is list positions = [heads, tails, water]
    #calculate pair correlation function for phospholipid heads and tails separately
    #only consider head - head interactions and tail - tail interactions for pair correlation function calculations
    #bins is number of bins for pair correlation function calculation
    #calculate g(r) for heads
    head_positions = np.array(positions[0])
    tail_positions = np.array(positions[1]).reshape(-1, 2) # reshape tail positions to be a list of all tail particle positions
    r_head_head, g_r_head_head = pair_correlation_2D(head_positions, r_head*2, L, bins)
    r_tail_tail, g_r_tail_tail = pair_correlation_2D(tail_positions, r_carbon*2, L, bins)
    return r_head_head, g_r_head_head, r_tail_tail, g_r_tail_tail

#plot the positions found above 
positions = [positions_heads, positions_tails, positions_water]
r_head_head, g_r_head_head, r_tail_tail, g_r_tail_tail = phospholipid_pair_correlation_2D(positions, r_water, r_head, r_carbon, L, bins=95)
plt.figure()
plt.plot(r_head_head, g_r_head_head, color = 'red', linewidth = 0.6, label = 'Head-Head g(r)')
plt.plot(r_tail_tail, g_r_tail_tail, color = 'orange', linewidth = 0.6, label = 'Tail-Tail g(r)')
plt.xlabel('Distance r')
plt.ylabel('g(r)')
plt.legend()
plt.savefig('phospholipid_g(r)_10000_moves.png')
# Out:
# /tmp/ipykernel_28206/2515550907.py:18: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
